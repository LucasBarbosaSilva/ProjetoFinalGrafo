# %% [markdown]
# # Projeto Final da Disciplina de Grafos - UFAL 2022.2
# By: Lucas Barbosa Leite Silva

# %% [markdown]
# ## Conhecendo do Problema
# Utilizaremos um dataset provido pela Agência Nacional de Aviação Civil (ANAC). Este data set está disponível gratuitamente no site da ANAC (https://www.anac.gov.br/acesso-a-informacao/dados-abertos/areas-de-atuacao/voos-e-operacoes-aereas/dados-estatisticos-do-transporte-aereo) e contém registros de voos que ocorreram no Brasil desde do ano 2000. <br>
# A ideia original é:
# - Montar um grafo contendo as rotas;
# - Cada rota terá um conjunto de pesos: custo em reais da rota para a empresa por passageiro, tempo para realizar aquela rota e quantidade de conexões;
# - Gerar uma ávore geradora mínima das rotas, a fim de conectar todos os vértices com o menor peso possível;
# - Utilizar a busca em profundidade para ir de um ponto a outro do grafo com o menor custo (heurístico);

# %% [markdown]
# ## Preparação dos Dados

# %% [markdown]
# ### Importando planilha

# %%
pip install pandas

# %%
import pandas as pd

# %%
planilha = pd.read_csv(
    'Dados_Estatisticos.csv', 
    sep=';'
  )

# %% [markdown]
# ### Visualizando os Dados

# %%
planilha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966166 entries, 0 to 966165
# Data columns (total 38 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   EMPRESA_SIGLA                    966166 non-null  object
#  1   EMPRESA_NOME                     966166 non-null  object
#  2   EMPRESA_NACIONALIDADE            966166 non-null  object
#  3   ANO                              966166 non-null  int64
#  4   MES                              966166 non-null  int64
#  5   AEROPORTO_DE_ORIGEM_SIGLA        960952 non-null  object
#  6   AEROPORTO_DE_ORIGEM_NOME         960952 non-null  object
#  7   AEROPORTO_DE_ORIGEM_UF           827939 non-null  object
#  8   AEROPORTO_DE_ORIGEM_REGIAO       827939 non-null  object
#  9   AEROPORTO_DE_ORIGEM_PAIS         960952 non-null  object
#  10  AEROPORTO_DE_ORIGEM_CONTINENTE   960952 non-null  object
#  11  AEROPORTO_DE_DESTINO_SIGLA       966166 non-null  object
#  12  AEROPORTO_DE_DESTINO_NOME        966166 non-null  object
#  13  AEROPORTO_DE_DESTINO_UF          824751 non-null  object
#  14  AEROPORTO_DE_DESTINO_REGIAO      824751 non-null  object
#  15  AEROPORTO_DE_DESTINO_PAIS        966166 non-null  object
#  16  AEROPORTO_DE_DESTINO_CONTINENTE  966166 non-null  object
#  17  NATUREZA                         966166 non-null  object
#  18  GRUPO_DE_VOO                     966164 non-null  object
#  19  PASSAGEIROS_PAGOS                920688 non-null  float64
#  20  PASSAGEIROS_GRATIS               920688 non-null  float64
#  21  CARGA_PAGA_KG                    920688 non-null  float64
#  22  CARGA_GRATIS_KG                  920688 non-null  float64
#  23  CORREIO_KG                       920688 non-null  float64
#  24  ASK                              740861 non-null  float64
#  25  RPK                              741335 non-null  float64
#  26  ATK                              740861 non-null  float64
#  27  RTK                              740849 non-null  float64
#  28  COMBUSTIVEL_LITROS               647666 non-null  float64
#  29  DISTANCIA_VOADA_KM               740861 non-null  float64
#  30  DECOLAGENS                       741401 non-null  float64
#  31  CARGA_PAGA_KM                    741335 non-null  float64
#  32  CARGA_GRATIS_KM                  740849 non-null  float64
#  33  CORREIO_KM                       741335 non-null  float64
#  34  ASSENTOS                         741400 non-null  float64
#  35  PAYLOAD                          741400 non-null  float64
#  36  HORAS_VOADAS                     740883 non-null  object
#  37  BAGAGEM_KG                       792937 non-null  float64
# dtypes: float64(18), int64(2), object(18)
# memory usage: 280.1+ MB

# %%
planilha.head()
# Out:
#   EMPRESA_SIGLA             EMPRESA_NOME EMPRESA_NACIONALIDADE   ANO  MES
# 0           AAL  AMERICAN AIRLINES, INC.           ESTRANGEIRA  2000    1  \
# 1           AAL  AMERICAN AIRLINES, INC.           ESTRANGEIRA  2000    1
# 2           AAL  AMERICAN AIRLINES, INC.           ESTRANGEIRA  2000    1
# 3           AAL  AMERICAN AIRLINES, INC.           ESTRANGEIRA  2000    1
# 4           AAL  AMERICAN AIRLINES, INC.           ESTRANGEIRA  2000    1
#
#   AEROPORTO_DE_ORIGEM_SIGLA    AEROPORTO_DE_ORIGEM_NOME
# 0                      KDFW  DALLAS & FORT WORTH, TEXAS  \
# 1                      KJFK          NEW YORK, NEW YORK
# 2                      KJFK          NEW YORK, NEW YORK
# 3                      KMIA              MIAMI, FLORIDA
# 4                      KMIA              MIAMI, FLORIDA
#
#   AEROPORTO_DE_ORIGEM_UF AEROPORTO_DE_ORIGEM_REGIAO
# 0                    NaN                        NaN  \
# 1                    NaN                        NaN
# 2                    NaN                        NaN
# 3                    NaN                        NaN
# 4                    NaN                        NaN
#
#     AEROPORTO_DE_ORIGEM_PAIS  ... COMBUSTIVEL_LITROS DISTANCIA_VOADA_KM
# 0  ESTADOS UNIDOS DA AMÉRICA  ...                NaN           247320.0  \
# 1  ESTADOS UNIDOS DA AMÉRICA  ...                NaN           224141.0
# 2  ESTADOS UNIDOS DA AMÉRICA  ...                NaN           222256.0
# 3  ESTADOS UNIDOS DA AMÉRICA  ...                NaN                NaN
# 4  ESTADOS UNIDOS DA AMÉRICA  ...                NaN           208227.0
#
#   DECOLAGENS CARGA_PAGA_KM CARGA_GRATIS_KM   CORREIO_KM ASSENTOS    PAYLOAD
# 0       30.0  8.068900e+08             0.0     601812.0   6330.0  1050000.0  \
# 1       29.0  3.715020e+08             0.0   62094800.0   6119.0   464000.0
# 2       29.0  1.494460e+09             0.0   15174700.0   6119.0  1015000.0
# 3        NaN           NaN             NaN          NaN      NaN        NaN
# 4       31.0  8.119980e+08      46495100.0  230689000.0   6541.0  1077000.0
#
#   HORAS_VOADAS  BAGAGEM_KG
# 0       409,08         NaN
# 1        418,1         NaN
# 2        411,5         NaN
# 3          NaN         NaN
# 4        491,8         NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Aplicando Filtros

# %%
planilha = planilha[
    (planilha["AEROPORTO_DE_ORIGEM_PAIS"]=="BRASIL") & 
    (planilha["AEROPORTO_DE_DESTINO_PAIS"]=="BRASIL") &
    (planilha["ANO"] == 2023)
]

# %%
planilha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7318 entries, 955925 to 966043
# Data columns (total 38 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   EMPRESA_SIGLA                    7318 non-null   object
#  1   EMPRESA_NOME                     7318 non-null   object
#  2   EMPRESA_NACIONALIDADE            7318 non-null   object
#  3   ANO                              7318 non-null   int64
#  4   MES                              7318 non-null   int64
#  5   AEROPORTO_DE_ORIGEM_SIGLA        7318 non-null   object
#  6   AEROPORTO_DE_ORIGEM_NOME         7318 non-null   object
#  7   AEROPORTO_DE_ORIGEM_UF           7318 non-null   object
#  8   AEROPORTO_DE_ORIGEM_REGIAO       7318 non-null   object
#  9   AEROPORTO_DE_ORIGEM_PAIS         7318 non-null   object
#  10  AEROPORTO_DE_ORIGEM_CONTINENTE   7318 non-null   object
#  11  AEROPORTO_DE_DESTINO_SIGLA       7318 non-null   object
#  12  AEROPORTO_DE_DESTINO_NOME        7318 non-null   object
#  13  AEROPORTO_DE_DESTINO_UF          7318 non-null   object
#  14  AEROPORTO_DE_DESTINO_REGIAO      7318 non-null   object
#  15  AEROPORTO_DE_DESTINO_PAIS        7318 non-null   object
#  16  AEROPORTO_DE_DESTINO_CONTINENTE  7318 non-null   object
#  17  NATUREZA                         7318 non-null   object
#  18  GRUPO_DE_VOO                     7318 non-null   object
#  19  PASSAGEIROS_PAGOS                7283 non-null   float64
#  20  PASSAGEIROS_GRATIS               7283 non-null   float64
#  21  CARGA_PAGA_KG                    7283 non-null   float64
#  22  CARGA_GRATIS_KG                  7283 non-null   float64
#  23  CORREIO_KG                       7283 non-null   float64
#  24  ASK                              7023 non-null   float64
#  25  RPK                              7023 non-null   float64
#  26  ATK                              7023 non-null   float64
#  27  RTK                              7023 non-null   float64
#  28  COMBUSTIVEL_LITROS               7025 non-null   float64
#  29  DISTANCIA_VOADA_KM               7023 non-null   float64
#  30  DECOLAGENS                       7025 non-null   float64
#  31  CARGA_PAGA_KM                    7023 non-null   float64
#  32  CARGA_GRATIS_KM                  7023 non-null   float64
#  33  CORREIO_KM                       7023 non-null   float64
#  34  ASSENTOS                         7025 non-null   float64
#  35  PAYLOAD                          7025 non-null   float64
#  36  HORAS_VOADAS                     7025 non-null   object
#  37  BAGAGEM_KG                       7283 non-null   float64
# dtypes: float64(18), int64(2), object(18)
# memory usage: 2.2+ MB

# %% [markdown]
# ### Selecionando colunas

# %%
planilha = planilha[['ANO','AEROPORTO_DE_ORIGEM_SIGLA','AEROPORTO_DE_ORIGEM_NOME','AEROPORTO_DE_ORIGEM_UF','AEROPORTO_DE_DESTINO_SIGLA','AEROPORTO_DE_DESTINO_NOME', 'AEROPORTO_DE_DESTINO_UF','COMBUSTIVEL_LITROS', 'DISTANCIA_VOADA_KM', 'HORAS_VOADAS', 'DECOLAGENS','PASSAGEIROS_PAGOS']]

# %%
display(planilha)
# Out:
#          ANO AEROPORTO_DE_ORIGEM_SIGLA AEROPORTO_DE_ORIGEM_NOME
# 955925  2023                      SBSV                 SALVADOR  \
# 955926  2023                      SBSV                 SALVADOR
# 955927  2023                      SIRI                    MARAÚ
# 955928  2023                      SNCL                    CAIRU
# 955929  2023                      SBSV                 SALVADOR
# ...      ...                       ...                      ...
# 966039  2023                      SBGR                GUARULHOS
# 966040  2023                      SBPA             PORTO ALEGRE
# 966041  2023                      SBRF                   RECIFE
# 966042  2023                      SBVT                  VITÓRIA
# 966043  2023                      SBVT                  VITÓRIA
#
#        AEROPORTO_DE_ORIGEM_UF AEROPORTO_DE_DESTINO_SIGLA
# 955925                     BA                       SIRI  \
# 955926                     BA                       SNCL
# 955927                     BA                       SBSV
# 955928                     BA                       SBSV
# 955929                     BA                       SBSV
# ...                       ...                        ...
# 966039                     SP                       SBVT
# 966040                     RS                       SBGR
# 966041                     PE                       SBGL
# 966042                     ES                       SBGR
# 966043                     ES                       SBGR
#
#        AEROPORTO_DE_DESTINO_NOME AEROPORTO_DE_DESTINO_UF  COMBUSTIVEL_LITROS
# 955925                     MARAÚ                      BA              1160.0  \
# 955926                     CAIRU                      BA              4736.0
# 955927                  SALVADOR                      BA              1160.0
# 955928                  SALVADOR                      BA              4736.0
# 955929                  SALVADOR                      BA                74.0
# ...                          ...                     ...                 ...
# 966039                   VITÓRIA                      ES                 NaN
# 966040                 GUARULHOS                      SP            192510.0
# 966041            RIO DE JANEIRO                      RJ              7517.0
# 966042                 GUARULHOS                      SP              4134.0
# 966043                 GUARULHOS                      SP            140982.0
#
#         DISTANCIA_VOADA_KM HORAS_VOADAS  DECOLAGENS  PASSAGEIROS_PAGOS
# 955925              1290.0        5,285        10.0               29.0
# 955926              5312.0         24,4        64.0              253.0
# 955927              1290.0        5,299        10.0               54.0
# 955928              5312.0       25,268        64.0              457.0
# 955929                 NaN          1,2         1.0                4.0
# ...                    ...          ...         ...                ...
# 966039                 NaN          NaN         NaN                0.0
# 966040             19918.0      39,1333        23.0                0.0
# 966041              1859.0      2,88333         1.0                0.0
# 966042               730.0      1,66667         1.0                0.0
# 966043             16790.0         35,6        23.0                0.0
#
# [7318 rows x 12 columns]

# %% [markdown]
# ### Removendo ruídos

# %%
planilha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7318 entries, 955925 to 966043
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ANO                         7318 non-null   int64
#  1   AEROPORTO_DE_ORIGEM_SIGLA   7318 non-null   object
#  2   AEROPORTO_DE_ORIGEM_NOME    7318 non-null   object
#  3   AEROPORTO_DE_ORIGEM_UF      7318 non-null   object
#  4   AEROPORTO_DE_DESTINO_SIGLA  7318 non-null   object
#  5   AEROPORTO_DE_DESTINO_NOME   7318 non-null   object
#  6   AEROPORTO_DE_DESTINO_UF     7318 non-null   object
#  7   COMBUSTIVEL_LITROS          7025 non-null   float64
#  8   DISTANCIA_VOADA_KM          7023 non-null   float64
#  9   HORAS_VOADAS                7025 non-null   object
#  10  DECOLAGENS                  7025 non-null   float64
#  11  PASSAGEIROS_PAGOS           7283 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 743.2+ KB

# %%
planilha = planilha.dropna(how="any", axis=0)

# %%
planilha['DECOLAGENS'] = pd.to_numeric(planilha["DECOLAGENS"], downcast='integer')

# %%
planilha['PASSAGEIROS_PAGOS'] = pd.to_numeric(planilha["PASSAGEIROS_PAGOS"], downcast='integer')

# %%
planilha['HORAS_VOADAS'] = planilha['HORAS_VOADAS'].str.replace(",", ".").astype(float)

# %%
remove = planilha.loc[
    (planilha['PASSAGEIROS_PAGOS'] == 0.0)
]
planilha = planilha.drop(remove.index)

# %%
display(planilha)
planilha.info()
# Out:
#          ANO AEROPORTO_DE_ORIGEM_SIGLA AEROPORTO_DE_ORIGEM_NOME
# 955925  2023                      SBSV                 SALVADOR  \
# 955926  2023                      SBSV                 SALVADOR
# 955927  2023                      SIRI                    MARAÚ
# 955928  2023                      SNCL                    CAIRU
# 955930  2023                      SBSV                 SALVADOR
# ...      ...                       ...                      ...
# 965723  2023                      SBVT                  VITÓRIA
# 965724  2023                      SBVT                  VITÓRIA
# 965725  2023                      SBVT                  VITÓRIA
# 965727  2023                      SBZM                   GOIANÁ
# 965728  2023                      SBZM                   GOIANÁ
#
#        AEROPORTO_DE_ORIGEM_UF AEROPORTO_DE_DESTINO_SIGLA
# 955925                     BA                       SIRI  \
# 955926                     BA                       SNCL
# 955927                     BA                       SBSV
# 955928                     BA                       SBSV
# 955930                     BA                       SIRI
# ...                       ...                        ...
# 965723                     ES                       SBRJ
# 965724                     ES                       SBSP
# 965725                     ES                       SBSP
# 965727                     MG                       SBGR
# 965728                     MG                       SBGR
#
#        AEROPORTO_DE_DESTINO_NOME AEROPORTO_DE_DESTINO_UF  COMBUSTIVEL_LITROS
# 955925                     MARAÚ                      BA              1160.0  \
# 955926                     CAIRU                      BA              4736.0
# 955927                  SALVADOR                      BA              1160.0
# 955928                  SALVADOR                      BA              4736.0
# 955930                     MARAÚ                      BA               760.0
# ...                          ...                     ...                 ...
# 965723            RIO DE JANEIRO                      RJ            346761.0
# 965724                 SÃO PAULO                      SP             29419.0
# 965725                 SÃO PAULO                      SP            804521.0
# 965727                 GUARULHOS                      SP              3289.0
# 965728                 GUARULHOS                      SP             91514.0
#
#         DISTANCIA_VOADA_KM  HORAS_VOADAS  DECOLAGENS  PASSAGEIROS_PAGOS
# 955925              1290.0        5.2850          10                 29
# 955926              5312.0       24.4000          64                253
# 955927              1290.0        5.2990          10                 54
# 955928              5312.0       25.2680          64                457
# 955930              1032.0        3.6990           8                 39
# ...                    ...           ...         ...                ...
# 965723             54051.0      137.2330         129              11263
# 965724              5292.0       11.4833           7                634
# 965725            138348.0      291.6830         183              18873
# 965727               401.0        1.3500           1                 85
# 965728             12030.0       34.4000          30               2620
#
# [5270 rows x 12 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 5270 entries, 955925 to 965728
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ANO                         5270 non-null   int64
#  1   AEROPORTO_DE_ORIGEM_SIGLA   5270 non-null   object
#  2   AEROPORTO_DE_ORIGEM_NOME    5270 non-null   object
#  3   AEROPORTO_DE_ORIGEM_UF      5270 non-null   object
#  4   AEROPORTO_DE_DESTINO_SIGLA  5270 non-null   object
#  5   AEROPORTO_DE_DESTINO_NOME   5270 non-null   object
#  6   AEROPORTO_DE_DESTINO_UF     5270 non-null   object
#  7   COMBUSTIVEL_LITROS          5270 non-null   float64
#  8   DISTANCIA_VOADA_KM          5270 non-null   float64
#  9   HORAS_VOADAS                5270 non-null   float64
#  10  DECOLAGENS                  5270 non-null   int16
#  11  PASSAGEIROS_PAGOS           5270 non-null   int32
# dtypes: float64(3), int16(1), int32(1), int64(1), object(6)
# memory usage: 483.8+ KB

# %% [markdown]
# ## Modelando Problema

# %% [markdown]
# #### Construir meu grafo:
# - Usando dicionário
# - Chave: coluna AEROPORTO_DE_ORIGEM_SIGLA - AEROPORTO_DE_ORIGEM_UF
# - E os valores serão um dicionário contendo o par AEROPORTO_DE_DESTINO_SIGLA - AEROPORTO_DE_DESTINO_NOME.
#     - O valor do dicionário vai ser um outro dicionário onde as chaves vão ser DECOLAGENS e o valor será o peso da aresta: uma tupla contendo o preço em reais e o tempo de voo.
#
# ##### Calcular o custo da seguinte forma:
# - **Peso:** (Custo de tempo + custo de combustivel) / Passageiros Pagos
# - **Custo de tempo:** Horas voadas * (precoHoraPiloto + precoHoraCoPiloto + precoHoraComissario * 3 + Custo de manutenção por hora)
# - **Custo de combustivel:** Combustível * preço do combustível
# - Arrendondar o preço da melhor forma
#
# ##### Definindo custos
# - **Piloto:** Salario: 18000; Horas de voo mesais: 85. Preço por hora: ~ R$212,00
# - **Copiloto:** Salario: 16000; Horas de voo mesais: 85. Preço por hora: ~ R$ 189,00
# - **Comissário de bordo:** Salário 4000, horas mesais trabalhadas 80). Preço por hora: ~ R$ 50,00
# - Custo de manutenção da aeronave: Preço por hora: R$ 150,00
# - Custo do combustível: 5,3 por  litro
#
# Exemplo do grafo:<br>
# {<br>
# &ensp;&ensp;"SBSV - BA": {<br>
# &ensp;&ensp;&ensp;&ensp;"SIRI - BA":{<br>
# &ensp;&ensp;&ensp;&ensp;&ensp;"10": (279, 5,6)<br>
# &ensp;&ensp;&ensp;&ensp;},<br>
# &ensp;&ensp;&ensp;&ensp;"SNCL - BA":{<br>
# &ensp;&ensp;&ensp;&ensp;&ensp;"64": 135<br>
# &ensp;&ensp;&ensp;&ensp;}<br>
# &ensp;&ensp;"SIRI - BA":{<br>
# &ensp;&ensp;&ensp;&ensp;"SBSV - BA":{<br>
# &ensp;&ensp;&ensp;&ensp;&ensp;"10": 150<br>
# &ensp;&ensp;&ensp;&ensp;}<br>
# &ensp;&ensp;}<br>
# }<br>

# %%
# variaveis de custo
horaPiloto = 212.0
horaCopiloto = 189.0
horaComissario = 50.0
horaManutencaoAeronave = 150.0
custoLitroCombustivel = 5.3

# %%
class Grafo:
    grafo = None
    quantidadeArestas = 0
    quantidadeVertices = 0
    aeroportos = None
    def __init__(self):
        self.grafo = {}
        self.aeroportos = {}

    def adicionarRota(self, origem, nomeOrigem, destino, nomeDestino, label, peso, tempo):
        #existe origem?
        if(origem in self.grafo):
        #sim
            #existe destino?
            if(destino in self.grafo[origem]):
            #sim
                #existe label?
                if(label in self.grafo[origem][destino]):
                    #sim
                    #fazer a média
                    novoPeso = round(peso + self.grafo[origem][destino][label][0]/2)
                    novoTempo = round(tempo + self.grafo[origem][destino][label][1]/2)
                    self.grafo[origem][destino][label] = (novoPeso, novoTempo)
                    self.quantidadeArestas+=1
                #nao
                else:
                    #adicionar a label
                    self.grafo[origem][destino][label] = (peso, tempo)
                    self.quantidadeArestas+=1
            #nao
            else:
                #adicionar "destino" : {"label" : peso}
                self.grafo[origem][destino] = {label : (peso, tempo)}
                self.quantidadeArestas+=1
        #nao
        else:
            #adicionar [origem] = {"destino" : {"label" : peso}}
            self.grafo[origem] = {destino : {label : (peso, tempo)}}
            self.aeroportos[origem] = nomeOrigem
            self.quantidadeArestas+=1
            self.quantidadeVertices+=1
        if(not(destino in self.grafo)):
            self.grafo[destino] = {}
            self.aeroportos[destino] = nomeDestino
            self.quantidadeVertices+=1

    
    def __str__(self):
        string = ""
        for origem in self.grafo.keys():
            string += origem+":"+"\n"
            for destino in self.grafo[origem].keys():
                string += "     "+destino+":"+"\n"
                for label, peso in self.grafo[origem][destino].items():
                    string +="         "+str(label)+": "+str(peso)+"\n"
        return string

# %%
grafo = Grafo()

# %%
for index, row in planilha.iterrows():
    AEROPORTO_DE_ORIGEM_SIGLA = row["AEROPORTO_DE_ORIGEM_SIGLA"]
    AEROPORTO_DE_ORIGEM_NOME = row["AEROPORTO_DE_ORIGEM_NOME"]
    AEROPORTO_DE_DESTINO_SIGLA = row["AEROPORTO_DE_DESTINO_SIGLA"]
    AEROPORTO_DE_DESTINO_NOME = row["AEROPORTO_DE_DESTINO_NOME"]
    AEROPORTO_DE_ORIGEM_UF = row["AEROPORTO_DE_ORIGEM_UF"]
    AEROPORTO_DE_DESTINO_UF = row["AEROPORTO_DE_DESTINO_UF"]
    COMBUSTIVEL_LITROS = row["COMBUSTIVEL_LITROS"]
    DISTANCIA_VOADA_KM = row["DISTANCIA_VOADA_KM"]
    HORAS_VOADAS = row["HORAS_VOADAS"]
    DECOLAGENS = row["DECOLAGENS"]
    PASSAGEIROS_PAGOS = row["PASSAGEIROS_PAGOS"]

    origem = AEROPORTO_DE_ORIGEM_SIGLA + " - " +AEROPORTO_DE_ORIGEM_UF
    destino = AEROPORTO_DE_DESTINO_SIGLA + " - " + AEROPORTO_DE_DESTINO_UF
    label = DECOLAGENS
    custoHoras = HORAS_VOADAS*(horaPiloto + horaCopiloto + (horaComissario*3) + horaManutencaoAeronave)
    custoCombustivel = COMBUSTIVEL_LITROS * custoLitroCombustivel
    peso = round( (custoHoras + custoCombustivel) / PASSAGEIROS_PAGOS)

    grafo.adicionarRota(origem=origem, nomeOrigem=AEROPORTO_DE_ORIGEM_NOME, destino=destino, nomeDestino=AEROPORTO_DE_DESTINO_NOME, label=label, peso=peso, tempo=HORAS_VOADAS)

# %%
print(str(grafo))
# Out:
# SBSV - BA:
#      SIRI - BA:
#          10: (340, 5.285)
#          8: (170, 3.699)
#          7: (362, 3.666)
#      SNCL - BA:
#          64: (167, 24.4)
#          52: (127, 20.549)
#          31: (112, 11.301)
#      SBBR - DF:
#          1: (251, 1.73333)
#          90: (165, 174.183)
#          3: (168, 5.75)
#          73: (169, 141.433)
#          86: (168, 169.233)
#          4: (177, 7.35)
#          58: (188, 107.133)
#          56: (183, 104.567)
#          2: (194, 3.75)
#          63: (211, 118.567)
#      SBCF - MG:
#          20: (217, 37.0667)
#          111: (191, 189.183)
#          9: (260, 16.5833)
#          102: (179, 169.033)
#          3: (254, 6.66667)
#          110: (196, 184.117)
#          57: (167, 101.767)
#          4: (173, 6.85)
#          46: (155, 78.9)
#          40: (175, 71.95)
#          1: (321, 2.78333)
#      SBCY - MT:
#          4: (331, 11.2833)
#          3: (293, 8.55)
#          5: (297, 14.5333)
#          1: (290, 2.83333)
#      SBFI - PR:
#          14: (485, 45.8667)
#          7: (340, 22.75)
#          1: (336, 3.43333)
#      SBGO - GO:
#          15: (184, 29.5167)
#          2: (419, 4.08333)
#          12: (232, 24.7333)
#          27: (185, 55.6167)
#          3: (212, 6.3)
#          8: (200, 16.7667)
#          23: (179, 47.85)
#      SBIL - BA:
#          26: (143, 20.75)
#          21: (124, 16.4333)
#          27: (116, 20.8833)
#          13: (104, 9.81667)
#          22: (128, 19.9833)
#          1: (61, 0.933333)
#          17: (85, 15.5333)
#      SBKP - SP:
#          140: (235, 336.967)
#          5: (326, 11.9333)
#          124: (234, 292.833)
#          136: (261, 324.75)
#          11: (279, 26.0167)
#          31: (216, 78.6833)
#          6: (220, 14.0667)
#          23: (225, 55.6167)
#          24: (220, 59.0167)
#          2: (21968, 6.48333)
#      SBMK - MG:
#          12: (251, 23.9667)
#          7: (301, 14.05)
#          3: (308, 9)
#      SBPS - BA:
#          55: (142, 54.2833)
#          2: (120, 2.01667)
#          27: (129, 25.4333)
#          31: (139, 30.2)
#          15: (95, 16.2)
#          1: (158, 2)
#          22: (155, 28.2)
#          14: (112, 18.35)
#      SBRF - PE:
#          3: (152, 5.9)
#          121: (157, 155.15)
#          5: (158, 7.78333)
#          106: (163, 135.767)
#          2: (185, 3.75)
#          118: (185, 149.433)
#          57: (105, 76.6334)
#          14: (126, 18.05)
#          23: (100, 31.35)
#          32: (114, 43.0667)
#      SBRJ - RJ:
#          30: (232, 64.2333)
#          2: (328, 6)
#          4: (249, 8.26667)
#          139: (245, 298.833)
#          118: (232, 255.133)
#          141: (225, 302.45)
#          5: (215, 10.6167)
#          64: (251, 135.883)
#          57: (238, 121.283)
#          60: (246, 124.867)
#      SBRP - SP:
#          4: (216, 8.56667)
#          1: (316, 2.6)
#      SBSR - SP:
#          4: (374, 9.46667)
#      SBUL - MG:
#          4: (393, 13)
#      SBVC - BA:
#          26: (140, 24.75)
#          21: (120, 19.35)
#          27: (116, 24.5167)
#          12: (108, 11.8333)
#          3: (102, 3.53333)
#          18: (175, 21.4833)
#          1: (83, 1.11667)
#          14: (111, 17.25)
#      SBGR - SP:
#          1: (345, 2.51667)
#          14: (225, 35.3833)
#          121: (217, 298.033)
#          2: (5210, 7)
#          110: (218, 272.233)
#          3: (205, 7.48333)
#          103: (225, 256.133)
#          11: (250, 27.4167)
#          144: (251, 345.117)
#          133: (248, 316.833)
#          6: (265, 14.2167)
#          132: (259, 317.033)
#      SBCT - PR:
#          18: (273, 49.8167)
#          3: (265, 8.41667)
#      SBFL - SC:
#          10: (339, 29.8667)
#          5: (301, 14.8667)
#      SBFZ - CE:
#          89: (154, 157.9)
#          59: (158, 106.067)
#          49: (153, 88.25)
#          3: (138, 5.15)
#          35: (266, 90)
#          1: (166, 1.66667)
#          36: (179, 62.45)
#      SBGL - RJ:
#          12: (217, 26.0167)
#          34: (217, 74.4667)
#          25: (193, 53.5833)
#          16: (216, 35.5667)
#          1: (558, 4)
#          10: (174, 21.0833)
#      SBJP - PB:
#          30: (115, 44.5833)
#          3: (132, 4.31667)
#          18: (105, 26.9833)
#          21: (121, 31.45)
#      SBMG - PR:
#          2: (346, 5.58333)
#      SBMO - AL:
#          31: (84, 34.5167)
#          19: (80, 20.8333)
#          28: (77, 31.0167)
#      SBPA - RS:
#          22: (374, 77.5833)
#          4: (357, 13.7667)
#      SBSG - RN:
#          5: (143, 7.9)
#          32: (139, 49.95)
#          20: (134, 31.9)
#          30: (143, 46.9333)
#      SBSL - MA:
#          27: (208, 55.5333)
#          12: (218, 25.2167)
#          18: (199, 38.45)
#          1: (390, 3.26667)
#      SBSP - SP:
#          12: (235, 29.5333)
#          229: (235, 575.45)
#          1: (273, 3.1)
#          204: (237, 513.417)
#          255: (234, 653.983)
#          7: (208, 17.1833)
#          123: (270, 305.067)
#          131: (276, 324.683)
#          6: (240, 14.8667)
#          164: (277, 407.333)
#      SBVT - ES:
#          23: (163, 36.9667)
#          31: (156, 48.2833)
#          2: (159, 3.35)
#          25: (234, 60)
#      SBAR - SE:
#          11: (96, 8.35)
#          22: (126, 20.0667)
#          1: (70, 0.883333)
#          18: (116, 16.3333)
#      SBKG - PB:
#          2: (208, 2.65)
#          19: (242, 25.8167)
#          27: (214, 36.05)
#      SBLE - BA:
#          6: (124, 6.86667)
#          2: (97, 2.18333)
#          7: (213, 12)
#      SNBR - BA:
#          15: (192, 29.8333)
#          2: (336, 3.93333)
#          11: (213, 21.7667)
#          1: (220, 1.86667)
#          16: (168, 32.5)
#      SBUF - BA:
#          7: (187, 8.68333)
#          3: (122, 3.68333)
#          4: (135, 4.98333)
#      SNTF - BA:
#          10: (262, 24)
#          8: (246, 12.2)
# SIRI - BA:
#      SBSV - BA:
#          10: (183, 5.299)
#          7: (430, 6)
#      SNCL - BA:
#          1: (337, 0.567)
# SNCL - BA:
#      SBSV - BA:
#          64: (94, 25.268)
#          51: (108, 20.035)
#          31: (95, 12.598)
# SBAC - CE:
#      SBFZ - CE:
#          11: (527, 8.76667)
#          7: (926, 9)
# SBFZ - CE:
#      SBAC - CE:
#          11: (2215, 8.46667)
#          7: (2848, 8)
#      SBJE - CE:
#          27: (411, 29.9833)
#          22: (416, 24.2)
#          25: (397, 28.9333)
#          5: (171, 4.73333)
#          8: (798, 11)
#      SBMS - RN:
#          4: (884, 7)
#          3: (316, 3.23333)
#      SNIG - CE:
#          4: (3915, 5.41667)
#          3: (1411, 3.98333)
#          5: (2003, 6.85)
#      SNOB - CE:
#          10: (2158, 11.3333)
#          8: (1238, 8.06667)
#      SNWS - CE:
#          6: (1800, 7.61667)
#          4: (3344, 8)
#      SWBE - CE:
#          6: (514, 7.78333)
#          3: (755, 4.15)
#          2: (1347, 2.65)
#      SBGR - SP:
#          1: (21, 3.367)
#          106: (365, 376.433)
#          94: (382, 334.3)
#          101: (376, 361.15)
#          13: (342, 44.7)
#          198: (361, 679.517)
#          4: (525, 14.5)
#          174: (370, 593.4)
#          8: (387, 26.8)
#          202: (394, 691.017)
#      SBBE - PA:
#          60: (255, 116.283)
#          55: (272, 106.133)
#          57: (295, 110.533)
#          31: (170, 60.8333)
#          24: (163, 47.3667)
#          16: (172, 31.6833)
#          5: (1011, 13.65)
#          4: (852, 16)
#          2: (342, 6)
#          29: (330, 85)
#          28: (207, 54.6833)
#      SBCF - MG:
#          2: (431, 8)
#          36: (272, 101.967)
#          29: (262, 78.0667)
#          35: (289, 95.15)
#          16: (294, 45.2667)
#          8: (313, 23.9667)
#      SBCY - MT:
#          4: (484, 13.7167)
#          6: (381, 20.5)
#          2: (510, 6.73333)
#      SBGL - RJ:
#          1: (528, 5)
#          24: (307, 81.0)
#          85: (300, 283.583)
#          90: (285, 293.15)
#          88: (314, 285.717)
#          3: (320, 9.36667)
#          29: (487, 142)
#          28: (331, 91.5333)
#      SBGO - GO:
#          4: (340, 11.2833)
#          1: (656, 2.86667)
#          8: (272, 22.1167)
#          3: (308, 8.4)
#      SBJU - CE:
#          2: (249, 1.88333)
#          1: (365, 0.9)
#          25: (171, 30.2333)
#          24: (314, 43)
#      SBKP - SP:
#          80: (305, 277.883)
#          57: (295, 197.25)
#          66: (334, 227.05)
#          1: (394, 4.15)
#      SBPA - RS:
#          4: (507, 18.15)
#          8: (479, 36.45)
#          1: (411, 4.56667)
#      SBRF - PE:
#          3: (220, 6)
#          141: (134, 180.883)
#          2: (91, 2.36667)
#          118: (134, 148.717)
#          134: (136, 166.75)
#          34: (106, 43.7667)
#          29: (112, 38.4)
#          26: (113, 33.3167)
#          42: (130, 51.8333)
#          44: (152, 53.3167)
#          1: (161, 1.18333)
#          41: (137, 49.5833)
#      SBRP - SP:
#          5: (296, 15.9833)
#      SBSR - SP:
#          5: (366, 16.6)
#      SBTE - PI:
#          22: (200, 25.0)
#          7: (197, 7.53333)
#          13: (203, 14.9)
#          3: (171, 3.23333)
#          49: (137, 53.8833)
#          48: (175, 52.6)
#          2: (334, 2.0)
#          55: (167, 60.1167)
#      SBUL - MG:
#          5: (292, 15.05)
#          4: (956, 18)
#      SBAE - SP:
#          1: (33766, 4.55)
#      SBMA - PA:
#          1: (1468, 3.01667)
#      SBBR - DF:
#          27: (248, 72.5)
#          54: (243, 147.567)
#          38: (236, 104.183)
#          48: (236, 130.25)
#          6: (265, 15.75)
#          100: (275, 265.317)
#          92: (273, 242.467)
#          3: (250, 7.75)
#          94: (284, 248.633)
#      SBEG - AM:
#          30: (562, 153)
#          26: (321, 90.5167)
#          2: (350, 6.8)
#          29: (350, 98.9667)
#          28: (363, 95.05)
#          1: (397, 3.38333)
#      SBSP - SP:
#          4: (343, 14.5)
#          111: (334, 403.25)
#          3: (596, 16)
#          76: (337, 276.267)
#          2: (321, 7.36667)
#          54: (319, 195.117)
#          6: (376, 20.7167)
#          86: (374, 309.45)
#          82: (392, 294.983)
#          83: (391, 296.2)
#      SBSV - BA:
#          88: (151, 160.833)
#          1: (175, 1.71667)
#          59: (145, 106.283)
#          50: (153, 91.85)
#          3: (174, 5.3)
#          36: (265, 94)
#          35: (173, 60.2)
#          2: (363, 3.7)
#      SBFZ - CE:
#          1: (91, 0.983333)
#      SBPB - PI:
#          8: (360, 8.63333)
#          4: (502, 7)
#      SBMO - AL:
#          2: (262, 2.51667)
#          29: (227, 38.6833)
#          28: (212, 37.55)
#          1: (150, 1.28333)
#          30: (155, 40.3833)
#      SBSG - RN:
#          3: (145, 3.05)
#          41: (213, 59)
#          1: (116, 0.983333)
#          43: (129, 42.1333)
#      SBSL - MA:
#          5: (154, 6.25)
#          54: (150, 68.9833)
#          53: (177, 68.1333)
#          2: (202, 2.68333)
#          56: (190, 73.0667)
#      SBVT - ES:
#          2: (359, 5.28333)
#          29: (482, 121)
#          28: (322, 76.5)
#          1: (403, 2.68333)
# SBBE - PA:
#      SBMD - PA:
#          19: (1322, 33.3833)
#          17: (1191, 30.8)
#          20: (989, 36.25)
#      SBSN - PA:
#          11: (773, 28.6833)
#          12: (1374, 31.2833)
#          14: (840, 37.9833)
#          57: (159, 76.1666)
#          49: (157, 65.3833)
#          50: (164, 66.6667)
#          26: (187, 35.95)
#          21: (204, 29.7167)
#          27: (210, 39.2167)
#      SNEB - PA:
#          11: (371, 12.7167)
#          15: (659, 17.1)
#          23: (513, 25.9333)
#      SNSM - PA:
#          8: (4101, 10)
#          7: (2860, 6.16667)
#      SNVS - PA:
#          5: (243, 5.0)
#          24: (499, 24.6667)
#          8: (325, 13)
#          22: (786, 34)
#      SBTU - PA:
#          6: (1921, 8.03333)
#          8: (879, 10.3833)
#      SBBV - RR:
#          15: (726, 51)
#          17: (471, 37.7667)
#      SBCF - MG:
#          1: (2777, 5)
#          61: (243, 191.8)
#          56: (257, 171.983)
#          73: (291, 220.833)
#      SBCJ - PA:
#          27: (213, 31.9)
#          24: (242, 28.2833)
#          28: (226, 33.4)
#      SBEG - AM:
#          3: (812, 10)
#          81: (513, 251)
#          69: (341, 141.983)
#          11: (2070, 22.5667)
#          17: (177, 36.8667)
#          15: (184, 32.3667)
#          5: (912, 18)
#          4: (802, 17)
#      SBFZ - CE:
#          59: (307, 112.0)
#          56: (320, 104.233)
#          58: (297, 108.0)
#          30: (172, 56.0833)
#          25: (163, 47.3333)
#          16: (170, 30.0833)
#          4: (2297, 20)
#          2: (126, 3.75)
#          28: (369, 92)
#          3: (309, 5.43333)
#      SBGL - RJ:
#          1: (712, 4.28333)
#          13: (387, 47.3833)
#          26: (367, 93.2333)
#          25: (327, 89.1667)
#      SBHT - PA:
#          30: (106, 31.9667)
#          28: (127, 29.65)
#          29: (137, 30.65)
#      SBKP - SP:
#          61: (297, 216.933)
#          55: (307, 195.067)
#          78: (440, 272.2)
#      SBMA - PA:
#          52: (136, 56.7833)
#          44: (147, 45.5667)
#          53: (133, 56.1667)
#      SBMQ - AP:
#          60: (77, 54.15)
#          57: (86, 51.0667)
#          63: (105, 57.25)
#          1: (195, 1)
#          55: (82, 52.3)
#          44: (88, 42.5167)
#          43: (89, 40.6333)
#          2: (89, 1.88333)
#          13: (105, 11.1)
#          12: (205, 16)
#      SBRF - PE:
#          60: (317, 152.283)
#          53: (383, 133.033)
#          61: (401, 151.95)
#      SBSL - MA:
#          58: (306, 91)
#          52: (174, 55.2)
#      SBCT - PR:
#          1: (62750, 4.21667)
#      SBPV - RO:
#          1: (128, 3.35)
#      SBBR - DF:
#          59: (244, 155.167)
#          1: (1006, 4)
#          51: (247, 133.983)
#          56: (466, 214)
#          4: (271, 10.2333)
#          57: (291, 147.7)
#          53: (310, 137.217)
#          2: (324, 5.25)
#      SBGR - SP:
#          30: (341, 112.317)
#          19: (339, 70.05)
#          40: (343, 148.233)
#          8: (355, 28.5)
#          116: (374, 420.483)
#          80: (394, 290.917)
#          3: (403, 10.65)
#          91: (395, 325.733)
# SBMD - PA:
#      SBBE - PA:
#          11: (1141, 22.3833)
#          8: (2916, 17.8167)
#          10: (2827, 21.0667)
#      SNYA - PA:
#          10: (462, 7)
#          9: (340, 4.15)
# SBSN - PA:
#      SBBE - PA:
#          11: (1816, 58)
#          57: (164, 77.0667)
#          48: (174, 64.6333)
#          49: (172, 66.2167)
#          25: (137, 35.8)
#          21: (178, 30.1833)
#          28: (183, 40.4333)
#      SBEG - AM:
#          4: (1114, 14)
#          3: (959, 6.46667)
#          23: (132, 28.8833)
#          13: (119, 16.5667)
#          21: (188, 26.7)
#      SBIH - PA:
#          11: (468, 18)
#          10: (314, 11.2)
#      SBCF - MG:
#          11: (498, 36.7833)
#      SBBR - DF:
#          2: (292, 5.03333)
#          29: (303, 75.1167)
#          28: (339, 71.65)
#          1: (338, 2.63333)
#          30: (411, 76.35)
# SNEB - PA:
#      SBBE - PA:
#          10: (533, 10.65)
#          15: (616, 15.5167)
#          23: (533, 24.6)
# SNSM - PA:
#      SBBE - PA:
#          8: (9610, 10)
#          7: (8497, 5.96667)
# SNVS - PA:
#      SBBE - PA:
#          5: (201, 5.66667)
#          14: (874, 14.55)
#          8: (349, 13)
#          11: (1032, 19)
#      SNMZ - PA:
#          10: (1984, 13)
#          11: (996, 9.71667)
# SBBG - RS:
#      SBPA - RS:
#          10: (1859, 12.7833)
#          13: (1770, 17.3833)
#          17: (647, 22.05)
# SBPA - RS:
#      SBBG - RS:
#          10: (916, 14.4167)
#          13: (1847, 19.2833)
#          17: (775, 24.7333)
#      SSCN - RS:
#          11: (697, 6.83333)
#          10: (1493, 6.2)
#          12: (1883, 7.93333)
#      SSLT - RS:
#          8: (2927, 15.9167)
#          5: (3384, 9.11667)
#          4: (11236, 7.66667)
#      SSSC - RS:
#          10: (1778, 7.46667)
#          9: (1182, 7.08333)
#          12: (1425, 9.41667)
#      SSZR - RS:
#          8: (1934, 14.8)
#          7: (1502, 12.5333)
#      SBCF - MG:
#          36: (207, 77.2)
#          44: (231, 93.7)
#          3: (399, 6.8)
#          49: (228, 104.3)
#          6: (318, 13.15)
#      SBCH - SC:
#          12: (173, 15.1167)
#      SBCT - PR:
#          3: (271, 7)
#          87: (163, 98.9333)
#          1: (286, 2)
#          81: (169, 94.7334)
#          2: (131, 3.13333)
#          103: (141, 118.5)
#          31: (119, 36.05)
#          22: (115, 25.4333)
#          35: (151, 42.35)
#          29: (146, 33.2)
#          28: (167, 32.2333)
#          30: (163, 33.3)
#      SBFI - PR:
#          27: (161, 47.3)
#          24: (294, 47)
#          18: (169, 23.4)
#      SBFL - SC:
#          31: (153, 28.3)
#          26: (137, 24.6833)
#          36: (132, 33.3167)
#          16: (99, 15.8667)
#          13: (141, 13.1833)
#          10: (217, 9.9)
#      SBFZ - CE:
#          4: (535, 17.1333)
#          8: (467, 34.35)
#          1: (438, 4.8)
#      SBGL - RJ:
#          2: (394, 8)
#          1: (401, 4)
#          6: (357, 14.4667)
#          3: (155, 6.7)
#      SBGR - SP:
#          131: (204, 238.133)
#          106: (261, 193.317)
#          138: (233, 254.15)
#          22: (244, 38.5167)
#          99: (174, 180.533)
#          119: (183, 217.4)
#          1: (204, 1.8)
#          140: (180, 252.833)
#          18: (188, 30.4667)
#          256: (199, 439.433)
#          2: (216, 3.38333)
#          238: (225, 409.517)
#          12: (210, 22.1)
#          253: (206, 435.217)
#      SBKP - SP:
#          243: (147, 396.167)
#          2: (838, 6)
#          232: (182, 378.55)
#          1: (172, 1.78333)
#          257: (169, 421.083)
#      SBMO - AL:
#          4: (838, 23)
#          5: (381, 18.9833)
#      SBNF - SC:
#          12: (121, 15.7833)
#          2: (152, 2.08333)
#      SBNM - RS:
#          17: (125, 20.6167)
#          24: (144, 29.2333)
#          31: (160, 36.85)
#      SBPK - RS:
#          16: (126, 21)
#          22: (102, 19.5)
#      SBPS - BA:
#          3: (720, 13)
#          4: (498, 19)
#          1: (280, 2.66667)
#      SBRF - PE:
#          43: (420, 171.567)
#          2: (461, 8.55)
#          1: (352, 4.01667)
#          17: (415, 68.2333)
#          4: (497, 16.2167)
#      SBRJ - RJ:
#          55: (177, 102.55)
#          73: (175, 137.283)
#          88: (186, 161.85)
#          132: (199, 248.633)
#          102: (208, 195.5)
#          136: (206, 256.367)
#          2: (367, 6)
#          41: (203, 73.4667)
#          44: (241, 81.3833)
#          52: (244, 94.2333)
#      SBSM - RS:
#          24: (136, 23.6667)
#          25: (161, 25.6167)
#          29: (141, 28.5833)
#      SBUG - RS:
#          14: (198, 24.2667)
#          18: (204, 30.3833)
#          22: (203, 36.1667)
#      SBBR - DF:
#          1: (967, 4)
#          6: (508, 23)
#          60: (237, 150.617)
#          54: (262, 135.7)
#          58: (252, 145.95)
#          84: (341, 205.817)
#          70: (351, 168.133)
#          2: (380, 4.96667)
#          88: (334, 212.75)
#      SBRP - SP:
#          1: (8296, 2.9)
#      SBPF - RS:
#          1: (91, 1.18333)
#      SBSP - SP:
#          30: (180, 47.8833)
#          7: (196, 10.85)
#          379: (178, 602.583)
#          330: (186, 537.25)
#          345: (186, 570.034)
#          13: (175, 20.6833)
#          208: (179, 322.183)
#          213: (209, 333.467)
#          10: (218, 15.9167)
#          267: (223, 424.533)
#      SBCG - MS:
#          4: (209, 7.61667)
#      SBSG - RN:
#          12: (448, 51.7667)
#          8: (541, 34.4667)
#          4: (535, 16.9667)
#      SBSV - BA:
#          22: (314, 72.8833)
#          4: (299, 13.5333)
# SBBW - MT:
#      SBCY - MT:
#          8: (1192, 15.3)
#          9: (989, 15.0)
#          16: (1156, 28.7)
# SBCY - MT:
#      SBBW - MT:
#          8: (1145, 14.3)
#          9: (979, 16.9333)
#          16: (1028, 30.4167)
#      SBJI - RO:
#          3: (1399, 11.2667)
#          1: (998, 3)
#          25: (184, 37.25)
#          21: (211, 31.85)
#          26: (253, 38.95)
#      SSOU - MT:
#          6: (1800, 26)
#          10: (1308, 30.2)
#      SWHP - MT:
#          8: (899, 16.0333)
#          6: (1445, 19)
#      SBAT - MT:
#          22: (166, 27.4833)
#          20: (189, 25.0)
#          25: (207, 30.95)
#      SBBR - DF:
#          50: (431, 83.3667)
#          40: (272, 65.7667)
#          48: (336, 116)
#          28: (154, 46.4333)
#          22: (161, 35.9667)
#          17: (160, 28.0167)
#          4: (200, 6.46667)
#          58: (209, 94.5167)
#          2: (201, 3.21667)
#          56: (187, 89.3333)
#      SBCF - MG:
#          33: (447, 109)
#          46: (307, 99.6333)
#      SBCG - MS:
#          18: (174, 20.85)
#          17: (369, 29)
#      SBCH - SC:
#          4: (484, 8.35)
#      SBCT - PR:
#          54: (295, 112.033)
#          27: (269, 56.45)
#          31: (281, 63.9333)
#          4: (197, 7.9)
#      SBFI - PR:
#          8: (364, 15.5833)
#      SBFL - SC:
#          8: (759, 19.1667)
#      SBFZ - CE:
#          4: (515, 13.2833)
#          6: (358, 20.25)
#          2: (315, 6.63333)
#      SBGL - RJ:
#          1: (350, 2.66667)
#          2: (748, 6.71667)
#      SBGO - GO:
#          49: (276, 70.5167)
#          40: (282, 56.6667)
#          52: (238, 73.6)
#      SBGR - SP:
#          128: (250, 286.85)
#          115: (262, 256.117)
#          110: (228, 244.033)
#          89: (225, 208.467)
#          66: (221, 151.25)
#          69: (214, 159.933)
#          7: (233, 15.0833)
#          93: (234, 205.25)
#          1: (146, 2.25)
#          78: (245, 170.983)
#          4: (266, 8.58333)
#          82: (238, 178.65)
#      SBKP - SP:
#          1: (634, 2.15)
#          118: (201, 243.817)
#          125: (199, 258.333)
#          149: (195, 305.25)
#      SBLO - PR:
#          1: (421, 2.63333)
#          4: (190, 6.75)
#      SBMO - AL:
#          4: (347, 13.3167)
#          1: (321, 3.25)
#          2: (311, 6.76667)
#      SBNF - SC:
#          13: (456, 30.4167)
#          6: (219, 14.3167)
#      SBPS - BA:
#          4: (1002, 10.8833)
#          1: (624, 2.75)
#      SBPV - RO:
#          1: (241, 1.98333)
#          35: (169, 64.1833)
#          46: (188, 84.9333)
#          48: (216, 89.6667)
#      SBRF - PE:
#          12: (351, 41.2667)
#          1: (298, 3.45)
#      SBRJ - RJ:
#          26: (426, 99)
#          21: (359, 53.8667)
#      SBSG - RN:
#          4: (515, 14.4833)
#      SBSI - MT:
#          1: (151, 1)
#          50: (95, 48.9667)
#          28: (89, 27.5667)
#          31: (105, 31.15)
#          8: (132, 7.56667)
#      SBSO - MT:
#          20: (108, 18.35)
#          19: (119, 17.1167)
#          23: (123, 20.85)
#      SBSV - BA:
#          4: (370, 11.6833)
#          2: (237, 5.85)
#          5: (319, 14.95)
#          1: (318, 3.01667)
#      SBVH - RO:
#          23: (144, 27.4)
#          18: (144, 19.65)
#          21: (180, 23.4)
#      SSKW - RO:
#          25: (164, 33.9833)
#          20: (177, 27.15)
#          24: (218, 32.9167)
#      SBSR - SP:
#          1: (336, 2.16667)
#      SBMG - PR:
#          4: (273, 6.3)
#      SBSP - SP:
#          30: (247, 67.65)
#          6: (252, 12.45)
#          74: (276, 159.783)
#          65: (278, 139.467)
#          3: (290, 6.51667)
#          73: (270, 158.367)
# SBCF - MG:
#      SBVG - MG:
#          12: (344, 17.9667)
#          10: (396, 14.0333)
#          13: (361, 18.0333)
#      SBZM - MG:
#          10: (280, 13.0)
#          6: (451, 7.73333)
#          11: (318, 13.6167)
#          1: (90, 1.01667)
#      SNPD - MG:
#          7: (500, 11.45)
#          9: (347, 12.3833)
#          11: (353, 15.7667)
#      SNTO - MG:
#          11: (430, 17.4)
#          10: (340, 15.0333)
#          12: (370, 18.3)
#      SNZR - MG:
#          7: (1084, 13.5667)
#          8: (908, 15.6333)
#          11: (1261, 20.1333)
#      SBAR - SE:
#          19: (205, 38.05)
#          4: (384, 12)
#      SBBE - PA:
#          1: (525, 3.05)
#          62: (248, 186.517)
#          56: (266, 167.133)
#          73: (315, 223.733)
#      SBBR - DF:
#          1: (264, 3)
#          95: (183, 129.917)
#          131: (224, 175.2)
#          152: (227, 209.0)
#          67: (209, 130)
#          48: (125, 65.1167)
#          62: (129, 82.8833)
#          5: (124, 6.45)
#          73: (139, 92.45)
#          64: (161, 81.6)
#          2: (174, 2.68333)
#      SBCB - RJ:
#          19: (157, 22.2833)
#          29: (157, 42.6)
#          3: (201, 3.1)
#          20: (136, 27.3667)
#          26: (111, 37.5333)
#      SBCJ - PA:
#          29: (272, 72.6)
#          24: (332, 59.4)
#          31: (294, 79.0167)
#          13: (343, 31.9333)
#          12: (700, 45)
#          5: (470, 13.0833)
#      SBCN - GO:
#          3: (159, 3.4)
#      SBCT - PR:
#          1: (1121, 2.41667)
#          33: (127, 54.0)
#          48: (174, 79.2333)
#          6: (158, 9.58333)
#          52: (169, 84.1)
#      SBCY - MT:
#          34: (280, 75.4833)
#          46: (289, 100.75)
#          31: (288, 68.9)
#      SBFI - PR:
#          11: (280, 22.85)
#          1: (232, 2.16667)
#      SBFL - SC:
#          27: (396, 74)
#          24: (216, 44.05)
#          4: (184, 7.0)
#      SBFZ - CE:
#          3: (249, 8.5)
#          36: (323, 99.3)
#          29: (380, 79.4)
#          35: (334, 95.7333)
#          16: (291, 45.4667)
#          2: (282, 5.63333)
#          7: (279, 19.25)
#      SBGL - RJ:
#          3: (179, 4.36667)
#          2: (184, 4)
#          1: (160, 2)
#          4: (106, 5.81667)
#          6: (133, 7.13333)
#      SBGO - GO:
#          87: (169, 120.033)
#          100: (206, 140.733)
#          107: (187, 150.133)
#      SBGR - SP:
#          1: (729, 2)
#          135: (121, 174.917)
#          138: (130, 176.05)
#          6: (118, 7.46667)
#          152: (129, 190.75)
#          91: (113, 116.833)
#          82: (120, 105.333)
#          108: (114, 137.983)
#          18: (144, 23.35)
#          222: (140, 269.533)
#          3: (175, 4.16667)
#          184: (159, 218.683)
#          9: (186, 11.0667)
#          195: (140, 234.4)
#      SBGV - MG:
#          52: (61, 48.1833)
#          46: (59, 40.1833)
#          4: (81, 3.7)
#          53: (61, 46.1)
#      SBIL - BA:
#          24: (202, 34.55)
#          26: (171, 37.55)
#          4: (224, 5.86667)
#          28: (177, 40.4667)
#          1: (144, 1.35)
#          31: (184, 43.2833)
#      SBIP - MG:
#          2: (120, 2)
#          112: (55, 87.3666)
#          114: (53, 88.05)
#          137: (53, 100.1)
#      SBIZ - MA:
#          20: (639, 72)
#          26: (403, 63.8833)
#      SBJE - CE:
#          18: (301, 49.85)
#          15: (389, 42.6833)
#          17: (402, 47.4667)
#      SBJP - PB:
#          32: (297, 82.3167)
#          9: (304, 23.55)
#          4: (440, 18)
#          11: (368, 45)
#      SBKP - SP:
#          9: (280, 18)
#          262: (107, 327.267)
#          277: (131, 348.2)
#          4: (168, 5.53333)
#          308: (120, 376.283)
#          1: (234, 2.08333)
#      SBLE - BA:
#          12: (275, 28.4333)
#          8: (283, 18.6333)
#          9: (263, 21.5833)
#      SBMA - PA:
#          25: (383, 64.35)
#          23: (453, 57.9667)
#          27: (564, 69.8667)
#      SBMK - MG:
#          1: (320, 1.06667)
#          92: (112, 115.4)
#          98: (110, 121.283)
#          109: (104, 132.333)
#      SBMO - AL:
#          34: (264, 76.6167)
#          2: (424, 7)
#          8: (324, 31)
#          10: (174, 22.2333)
#          12: (202, 26.8833)
#          9: (188, 20.1167)
#          6: (212, 14.0667)
#      SBNF - SC:
#          15: (248, 26.0333)
#      SBPA - RS:
#          39: (277, 89.4833)
#          4: (246, 9.26667)
#          41: (271, 92.9)
#          7: (375, 15.8333)
#          45: (285, 100.9)
#          6: (350, 14.05)
#      SBPS - BA:
#          20: (243, 26.15)
#          60: (141, 77.1)
#          4: (292, 5.08333)
#          61: (162, 80.1833)
#          59: (151, 74.55)
#          22: (106, 28.7667)
#          31: (117, 39.2167)
#          16: (146, 30)
#          54: (136, 70.1167)
#          53: (145, 66.7333)
#      SBRF - PE:
#          24: (332, 59.5667)
#          123: (262, 301.217)
#          112: (295, 275.417)
#          119: (271, 287.283)
#          1: (241, 2.46667)
#          14: (225, 34.85)
#          2: (212, 4.71667)
#          12: (241, 31.2)
#          3: (224, 7.66667)
#      SBRJ - RJ:
#          20: (167, 21.2)
#          159: (140, 181.333)
#          2: (190, 3)
#          143: (158, 163.75)
#          166: (135, 183.517)
#          111: (101, 124.983)
#          85: (105, 95.9)
#          108: (106, 116.667)
#          4: (123, 4.38333)
#          82: (132, 88.7)
#          1: (308, 1.03333)
#          71: (134, 76.2833)
#          86: (129, 88.55)
#      SBRP - SP:
#          25: (148, 35.6833)
#          12: (187, 18.9)
#      SBSG - RN:
#          21: (390, 56.55)
#          9: (287, 24.2167)
#          15: (427, 61)
#          14: (243, 38.9667)
#          20: (288, 54.8333)
#          5: (272, 14.0167)
#          12: (298, 33.55)
#          4: (244, 10.9333)
#          7: (266, 18.9333)
#      SBSL - MA:
#          57: (309, 154.55)
#          28: (265, 75.3667)
#          5: (553, 13.8)
#          31: (284, 84.8167)
#      SBSN - PA:
#          11: (480, 35.7333)
#      SBSP - SP:
#          134: (179, 181.65)
#          2: (476, 4)
#          150: (229, 206.6)
#          192: (205, 268.0)
#          174: (131, 241.833)
#          204: (142, 282.667)
#          249: (135, 336.05)
#          16: (157, 19.8833)
#          205: (171, 264.633)
#          1: (331, 1.05)
#          189: (187, 243.833)
#          7: (170, 9.15)
#          233: (160, 296.0)
#      SBSR - SP:
#          32: (185, 57.7333)
#          5: (185, 9.28333)
#      SBSV - BA:
#          15: (401, 28.2333)
#          115: (211, 195.917)
#          9: (345, 17.1333)
#          102: (223, 173.317)
#          3: (285, 9)
#          110: (197, 185.033)
#          56: (146, 96.2)
#          47: (152, 80.5333)
#          39: (159, 67.0167)
#      SBTC - BA:
#          5: (114, 7.03333)
#          4: (194, 5.43333)
#          2: (196, 2.71667)
#      SBTE - PI:
#          1: (936, 3.9)
#      SBUL - MG:
#          115: (135, 181.283)
#          109: (136, 168.283)
#          139: (137, 210.25)
#      SBUR - MG:
#          30: (180, 64)
#          27: (130, 40.95)
#      SBVC - BA:
#          26: (179, 32.8167)
#          22: (185, 28.55)
#          27: (220, 34.3833)
#      SBVT - ES:
#          128: (152, 133.867)
#          123: (154, 133.833)
#          2: (124, 2.05)
#          140: (139, 148.017)
#          1: (190, 1.08333)
#      SNBR - BA:
#          29: (294, 102)
#          26: (183, 61.5167)
#      SNGI - BA:
#          17: (170, 32.1333)
#          18: (188, 33.8167)
#          30: (228, 56.6333)
#      SBPJ - TO:
#          1: (347, 2.0)
#          18: (249, 34.5)
#      SBCF - MG:
#          2: (369, 3.9)
# SBVG - MG:
#      SBCF - MG:
#          12: (284, 16.3667)
#          10: (469, 13.55)
#          13: (333, 17.3167)
# SBZM - MG:
#      SBCF - MG:
#          10: (322, 13.6667)
#          6: (502, 7.25)
#          11: (453, 14.7833)
#          1: (160, 1.65)
#      SBKP - SP:
#          1: (1059, 1.55)
#          44: (131, 70.4333)
#          54: (152, 83.6833)
#          58: (136, 88.7833)
#      SBSP - SP:
#          6: (152, 8.06667)
#          39: (223, 60.1667)
#          40: (153, 64.2833)
#          34: (152, 52.8833)
#      SBGR - SP:
#          1: (280, 2)
#          2: (178, 2.25)
#          29: (172, 32.0)
#          28: (182, 31.1667)
#          30: (194, 34.4)
# SNPD - MG:
#      SBCF - MG:
#          7: (369, 9.5)
#          9: (425, 11.25)
#          11: (327, 13.9)
# SNTO - MG:
#      SBCF - MG:
#          11: (330, 18.4333)
#          10: (337, 14.2333)
#          12: (370, 17.6833)
# SNZR - MG:
#      SBCF - MG:
#          7: (722, 12.9833)
#          8: (756, 14.05)
#          11: (1674, 19.0833)
# SBCP - RJ:
#      SBRJ - RJ:
#          17: (258, 20.65)
#          36: (405, 44.7333)
#          46: (360, 54.1)
#      SBKP - SP:
#          22: (251, 42.35)
#          16: (266, 30.75)
#          19: (227, 34.8833)
# SBRJ - RJ:
#      SBCP - RJ:
#          17: (326, 20.5833)
#          36: (380, 41.4167)
#          46: (366, 54.0667)
#      SBJD - SP:
#          11: (1004, 21.5667)
#          10: (1926, 28)
#      SBME - RJ:
#          18: (309, 15.6333)
#          37: (454, 34.2833)
#          45: (434, 42.1667)
#      SBBR - DF:
#          54: (156, 96.8833)
#          80: (200, 139.983)
#          106: (258, 185.883)
#          5: (215, 9.56667)
#          131: (207, 236.75)
#          143: (229, 262.417)
#          178: (227, 324.483)
#          15: (223, 27.25)
#          221: (232, 380.367)
#          1: (257, 1.73333)
#          209: (263, 358.967)
#          7: (236, 12.0833)
#          231: (251, 400.3)
#      SBCF - MG:
#          18: (148, 18.6667)
#          160: (143, 169.1)
#          2: (216, 3)
#          150: (154, 157.867)
#          174: (151, 181.217)
#          111: (103, 119.617)
#          86: (99, 94.6167)
#          109: (112, 119.917)
#          5: (126, 5.48333)
#          82: (127, 86.6833)
#          1: (152, 1.25)
#          74: (127, 76.0667)
#          87: (132, 89.6667)
#      SBCT - PR:
#          56: (116, 76.3)
#          2: (297, 4)
#          87: (137, 123.417)
#          108: (159, 148.233)
#          8: (148, 11.0667)
#          109: (147, 153.317)
#          63: (153, 92.1333)
#          77: (158, 109.883)
#          29: (178, 39.1833)
#          28: (165, 37.9833)
#          1: (168, 1.41667)
#          41: (181, 55.65)
#      SBCY - MT:
#          25: (232, 63.0)
#          24: (296, 61.7833)
#          27: (311, 68.3833)
#      SBFL - SC:
#          24: (142, 35.1)
#          27: (173, 40.3333)
#          20: (135, 30.3333)
#          26: (138, 38.7)
#          8: (180, 11.7)
#          83: (187, 127.283)
#          69: (178, 107.033)
#          92: (187, 137.183)
#          4: (247, 6.86667)
#          40: (289, 87)
#          2: (350, 4.28333)
#          47: (188, 67.8)
#      SBGO - GO:
#          52: (145, 88.4)
#          45: (174, 78.1667)
#          53: (431, 160)
#          6: (272, 11.0333)
#          57: (225, 96.7)
#          2: (240, 3.58333)
#      SBGR - SP:
#          67: (180, 72.1667)
#          91: (196, 101.233)
#          113: (191, 125.717)
#          152: (110, 171.667)
#          133: (122, 152.6)
#          156: (121, 180.533)
#          16: (131, 19.6667)
#          187: (125, 198.75)
#          3: (105, 3.6)
#          173: (129, 183.867)
#          10: (122, 11.8167)
#          195: (131, 206.533)
#      SBIL - BA:
#          26: (207, 43.6167)
#      SBKP - SP:
#          1: (112, 1.33333)
#          233: (156, 278.483)
#          3: (176, 3.58333)
#          244: (170, 298.783)
#          282: (178, 333.317)
#          74: (164, 96.0)
#          63: (181, 83.2167)
#          83: (175, 103.567)
#      SBMK - MG:
#          1: (2364, 1.85)
#      SBMO - AL:
#          26: (299, 65.6833)
#          4: (485, 17)
#      SBNF - SC:
#          22: (194, 33.2833)
#          88: (166, 130.7)
#          56: (174, 84.8)
#          70: (162, 103.0)
#      SBPA - RS:
#          57: (187, 111.95)
#          72: (181, 143.0)
#          89: (210, 174.617)
#          136: (245, 278.3)
#          1: (352, 2.45)
#          104: (244, 213.917)
#          138: (241, 280.383)
#          2: (244, 6)
#          41: (233, 80.0833)
#          44: (254, 85.0833)
#          52: (268, 100.85)
#      SBPS - BA:
#          17: (162, 26.4167)
#          4: (313, 11)
#          27: (177, 41.4667)
#          2: (197, 3.06667)
#          15: (205, 22.1)
#          16: (215, 23.9333)
#          20: (216, 29.5167)
#      SBRF - PE:
#          23: (320, 63.0333)
#          120: (274, 329.517)
#          106: (296, 297.15)
#          123: (286, 335.083)
#      SBRP - SP:
#          2: (8494, 3.71667)
#          1: (2635, 3)
#          29: (228, 51.5)
#          26: (182, 46.6)
#          3: (408, 5.36667)
#          28: (176, 49.1833)
#      SBSP - SP:
#          278: (229, 306.467)
#          254: (220, 286.633)
#          327: (181, 370.367)
#          505: (119, 581.233)
#          464: (128, 546.083)
#          545: (125, 633.016)
#          44: (145, 48.1833)
#          600: (157, 649.1)
#          1: (88, 1.23333)
#          569: (154, 626.55)
#          24: (156, 27.1833)
#          626: (162, 693.234)
#      SBSV - BA:
#          29: (271, 56.5333)
#          2: (332, 6)
#          4: (241, 8.16667)
#          135: (237, 275.767)
#          118: (237, 245.617)
#          141: (229, 289.45)
#          5: (243, 10.2333)
#          65: (256, 125.783)
#          59: (251, 117.933)
#          60: (254, 118.25)
#      SBVT - ES:
#          2: (172, 2.01667)
#          27: (198, 28.3333)
#          47: (190, 49.65)
#          61: (213, 63.5667)
#          6: (112, 6.08333)
#          76: (119, 81.8333)
#          73: (127, 80.0833)
#          96: (129, 106.85)
#          9: (194, 9.31667)
#          128: (165, 127.25)
#          115: (169, 114.517)
#          5: (133, 4.7)
#          130: (160, 131.183)
#      SBCX - RS:
#          13: (235, 24.6667)
#      SBFI - PR:
#          4: (230, 7.9)
#      SBRJ - RJ:
#          2: (422, 3.91667)
#          4: (347, 8.7)
#          3: (280, 6.0)
# SBCT - PR:
#      SBJD - SP:
#          6: (715, 9.53333)
#          7: (454, 11.0333)
#          8: (769, 12.3333)
#      SSGY - PR:
#          13: (1986, 30.1667)
#          8: (3941, 18.7667)
#          12: (3988, 27.0167)
#      SSUM - PR:
#          13: (840, 26.2833)
#          10: (816, 21.5)
#          12: (957, 24.2667)
#      SSUV - PR:
#          10: (17176, 16)
#          12: (1720, 12.2333)
#      SSVL - PR:
#          11: (5513, 11.9667)
#          7: (3512, 7.58333)
#          12: (5981, 12.9333)
#      SBCA - PR:
#          47: (141, 66.9667)
#          50: (170, 71.7167)
#          53: (130, 73.6167)
#      SBCF - MG:
#          32: (119, 49.4167)
#          49: (166, 73.5)
#          6: (195, 8.85)
#          52: (154, 78.15)
#      SBCG - MS:
#          24: (190, 36.4833)
#          3: (174, 4.33333)
#          22: (208, 33.0667)
#          27: (244, 39.8833)
#      SBCY - MT:
#          56: (290, 120.933)
#          26: (281, 56.2833)
#          31: (303, 66.6833)
#          4: (224, 8.76667)
#      SBFI - PR:
#          55: (201, 64.7167)
#          51: (162, 61.1833)
#          57: (172, 67.3334)
#          3: (239, 3.58333)
#          29: (159, 33.5833)
#          22: (169, 25.05)
#          20: (154, 22.75)
#      SBFL - SC:
#          30: (81, 28.8333)
#          1: (88, 0.783333)
#      SBGL - RJ:
#          1: (342, 3)
#          3: (179, 5.63333)
#      SBGR - SP:
#          47: (167, 52.6167)
#          95: (189, 108.4)
#          117: (186, 133.617)
#          90: (94, 104.1)
#          79: (98, 90.7167)
#          102: (101, 119.717)
#          14: (137, 15.4667)
#          202: (136, 220.4)
#          177: (133, 191.917)
#          7: (126, 7.61667)
#          192: (127, 208.383)
#      SBKP - SP:
#          2: (504, 6)
#          205: (80, 213.967)
#          173: (87, 178.283)
#          213: (80, 225.75)
#      SBLO - PR:
#          50: (183, 57.4167)
#          64: (177, 76.3167)
#          62: (122, 72.0333)
#      SBMG - PR:
#          60: (153, 75.8833)
#          69: (191, 91.2667)
#          71: (125, 91.7667)
#      SBPA - RS:
#          3: (171, 4.71667)
#          88: (210, 105.017)
#          1: (323, 1.8)
#          80: (167, 93.9167)
#          2: (256, 4)
#          102: (144, 122.983)
#          30: (202, 52)
#          23: (102, 27.0833)
#          33: (131, 39.1167)
#          29: (191, 32.6667)
#          28: (167, 31.1333)
#      SBPO - PR:
#          16: (131, 19.4833)
#          19: (133, 22.8)
#          27: (129, 32.05)
#      SBPS - BA:
#          4: (284, 8.98333)
#      SBRJ - RJ:
#          56: (124, 78.5167)
#          1: (248, 2)
#          86: (135, 119.367)
#          108: (158, 148.5)
#          8: (138, 10.55)
#          106: (138, 145.65)
#          63: (136, 90.0)
#          78: (145, 107.533)
#          2: (159, 2.73333)
#          27: (143, 35.1833)
#          28: (148, 35.4167)
#          41: (159, 51.8)
#      SBSG - RN:
#          3: (575, 10.9)
#          2: (372, 7.1)
#          8: (627, 45)
#          4: (365, 14.7333)
#      SBSP - SP:
#          29: (158, 32.0667)
#          184: (115, 193.767)
#          200: (124, 218.35)
#          247: (115, 273.983)
#          16: (215, 16.1)
#          214: (175, 220.2)
#          2: (358, 3.11667)
#          198: (164, 200.95)
#          10: (175, 10.9333)
#          223: (143, 230.833)
#      SBBR - DF:
#          58: (170, 114.633)
#          44: (338, 124)
#          51: (170, 99.3167)
#          4: (271, 7.75)
#          57: (244, 108.067)
#          1: (262, 1.73333)
#          47: (227, 87.1667)
#      SBMO - AL:
#          12: (299, 38.55)
#          3: (398, 9.41667)
#      SBSV - BA:
#          19: (260, 50.8667)
#          3: (255, 8.1)
#      SBCT - PR:
#          1: (204, 1.93333)
#      SBRB - AC:
#          1: (1196, 4.08333)
#      SBMH - PR:
#          1: (330, 1.03333)
# SBJD - SP:
#      SBCT - PR:
#          7: (628, 17)
#          8: (922, 12.8333)
#      SBJR - RJ:
#          3: (1205, 5.26667)
#          4: (1294, 6.46667)
#      SBRJ - RJ:
#          12: (1591, 21.2667)
#          10: (776, 17.1667)
#          8: (1320, 12.75)
#      SBSP - SP:
#          5: (5566, 7)
# SSGY - PR:
#      SBCT - PR:
#          13: (1352, 27.15)
#          8: (3399, 15.85)
#          12: (2832, 24.5667)
# SSUM - PR:
#      SBCT - PR:
#          13: (849, 24.4333)
#          10: (850, 17.8667)
#          12: (773, 21.4167)
# SSUV - PR:
#      SBCT - PR:
#          10: (14263, 10.1167)
#          12: (2083, 11.65)
# SSVL - PR:
#      SBCT - PR:
#          11: (3138, 11.0167)
#          7: (1824, 6.38333)
#          12: (1079, 11.5833)
# SBJI - RO:
#      SBCY - MT:
#          3: (7163, 9.61667)
#          1: (189, 1.38333)
#          25: (204, 36.2667)
#          21: (240, 30.8167)
#          26: (244, 37.8667)
#      SBPV - RO:
#          1: (989, 1.41667)
# SSOU - MT:
#      SWJN - MT:
#          6: (550, 4.75)
#          10: (430, 9.06667)
#          4: (199, 3.08333)
# SWHP - MT:
#      SBCY - MT:
#          8: (2015, 16.2667)
#          6: (2365, 17)
# SBEG - AM:
#      SBMY - AM:
#          9: (432, 14.0333)
#          8: (476, 11.9)
#          10: (418, 14.9667)
#      SBSN - PA:
#          4: (909, 10.45)
#          3: (2143, 12)
#          23: (146, 29.25)
#          13: (148, 15.9333)
#          22: (212, 27.5333)
#      SBTF - AM:
#          11: (861, 36)
#          10: (409, 21.1333)
#          1: (304, 4)
#          16: (208, 18.9167)
#          14: (189, 16.7)
#          17: (244, 19.8833)
#      SWBC - AM:
#          7: (471, 12.25)
#          9: (1753, 23)
#      SWBR - AM:
#          10: (890, 9.2)
#          8: (635, 6.93333)
#          7: (683, 6.06667)
#      SWKO - AM:
#          11: (808, 26)
#          10: (479, 16.1833)
#      SWLB - AM:
#          4: (2891, 17)
#          3: (1095, 8.56667)
#      SWMW - AM:
#          4: (924, 5.25)
#          8: (1364, 10.65)
#          10: (677, 12.2333)
#      SWYN - AM:
#          9: (557, 17.8667)
#          10: (713, 20.2833)
#          11: (514, 22.2667)
#      SBBE - PA:
#          55: (220, 113.717)
#          1: (604, 3.43333)
#          49: (228, 101.417)
#          57: (251, 119.65)
#          17: (195, 37.05)
#          15: (201, 32.75)
#          4: (756, 18)
#          5: (196, 10.0667)
#      SBBV - RR:
#          2: (157, 3.98333)
#          30: (266, 57)
#          28: (144, 35.6)
#      SBIH - PA:
#          13: (120, 18.7833)
#          11: (165, 16.2167)
#          14: (165, 20.6667)
#          10: (332, 21)
#          8: (323, 10.9833)
#      SBKP - SP:
#          9: (4307, 34.95)
#          175: (869, 660.533)
#          19: (3523, 73.05)
#          156: (842, 588.917)
#          16: (6031, 60.7833)
#          152: (835, 571.8)
#      SBPV - RO:
#          56: (181, 78.7)
#          1: (390, 3)
#          48: (137, 66.7833)
#          54: (166, 74.9833)
#          30: (178, 43.95)
#          3: (203, 4.28333)
#          12: (188, 16.7833)
#          6: (156, 8.56667)
#      SBRF - PE:
#          30: (284, 117.217)
#          25: (328, 95.9333)
#          31: (333, 120.15)
#      SBTB - PA:
#          13: (190, 17.7667)
#          1: (235, 1.26667)
#          10: (185, 12.8167)
#          9: (194, 12.3)
#      SBTT - AM:
#          30: (270, 54.15)
#          1: (284, 1.88333)
#          25: (272, 45.1667)
#          28: (308, 52.1833)
#      SBUA - AM:
#          3: (188, 4.68333)
#          5: (202, 7.91667)
#          2: (239, 3.16667)
#          7: (285, 11.5333)
#          1: (189, 2.35)
#          6: (299, 10.0333)
#      SWEI - AM:
#          9: (312, 26.1167)
#          8: (464, 36)
#      SWPI - AM:
#          22: (165, 21.5333)
#          1: (155, 0.916667)
#          14: (139, 12.9833)
#          2: (186, 1.73333)
#          16: (141, 14.35)
#          4: (235, 4.43333)
#          5: (158, 6.35)
#          6: (196, 7.01667)
#      SBMQ - AP:
#          1: (416, 2.88333)
#      SBBR - DF:
#          2: (480, 8)
#          53: (258, 158.333)
#          38: (288, 113.983)
#          50: (280, 148.533)
#          4: (276, 11.8333)
#          57: (291, 167.05)
#          56: (307, 162.0)
#          60: (304, 173.2)
#      SBEG - AM:
#          1: (1006, 6)
#          2: (121, 1.43333)
#      SBFZ - CE:
#          30: (556, 154)
#          26: (532, 132)
#          1: (596, 5)
#          2: (325, 6.71667)
#          29: (349, 99.15)
#      SBGL - RJ:
#          17: (388, 69.9833)
#          13: (399, 53.1667)
#          8: (354, 32.1)
#      SBGR - SP:
#          30: (352, 119.9)
#          22: (357, 87.1333)
#          25: (385, 101.317)
#          8: (417, 30.2)
#          105: (423, 407.033)
#          1: (137, 3.91667)
#          97: (452, 372.117)
#          4: (611, 15.7833)
#          106: (458, 408.5)
#      SBRB - AC:
#          19: (192, 37.4833)
#          1: (360, 3)
#          10: (181, 18.4)
#          12: (242, 24.2167)
#      SBUY - AM:
#          44: (205, 74.0333)
#          43: (188, 72.4833)
#          47: (179, 79.2)
#      SWCA - AM:
#          1: (354, 1.88333)
#          12: (367, 24.0333)
#          11: (218, 22.7)
#          9: (246, 18.35)
#      SBCF - MG:
#          1: (47, 3.91667)
# SBMY - AM:
#      SBEG - AM:
#          9: (328, 14.1)
#          8: (816, 12.2667)
#          10: (515, 14.75)
# SBTF - AM:
#      SWTP - AM:
#          9: (1150, 20)
#          10: (1428, 15.8333)
#      SBEG - AM:
#          1: (343, 2)
#          25: (229, 29.6833)
#          23: (274, 27.15)
#          18: (241, 19.0333)
#      SBUY - AM:
#          1: (70, 0.666667)
# SWBC - AM:
#      SBEG - AM:
#          7: (652, 10.9667)
#          9: (1398, 23)
# SWBR - AM:
#      SBEG - AM:
#          10: (457, 9.43333)
#          8: (786, 7.9)
#          7: (689, 6.43333)
# SWKO - AM:
#      SBEG - AM:
#          13: (934, 21.5333)
#          12: (1030, 20.6167)
#          14: (723, 22.65)
#          3: (2421, 3.26667)
#          4: (2410, 7)
# SWLB - AM:
#      SBPV - RO:
#          4: (2603, 6)
#          3: (1289, 2.6)
#      SWKO - AM:
#          2: (1617, 3.21667)
#          3: (2884, 9)
# SWMW - AM:
#      SBEG - AM:
#          4: (1205, 4.96667)
#          8: (1091, 10.35)
#          10: (726, 12.1333)
# SWYN - AM:
#      SBEG - AM:
#          9: (415, 18.4833)
#          10: (852, 20.05)
#          11: (696, 21.7)
# SBJE - CE:
#      SBFZ - CE:
#          28: (609, 32.3333)
#          21: (829, 24.0333)
#          25: (552, 30.0167)
#          13: (260, 10.75)
#          12: (692, 15)
#      SBPB - PI:
#          21: (844, 16.0833)
#          20: (4471, 15.8167)
#          24: (628, 18.95)
#          6: (13543, 3.63333)
#          9: (5717, 5.6)
#          8: (21408, 5.23333)
#          7: (10423, 4.41667)
#      SBCF - MG:
#          17: (265, 49.1167)
#          15: (323, 41.9167)
#          8: (195, 22.4833)
#      SBGL - RJ:
#          1: (55098, 3.73333)
#      SBKP - SP:
#          8: (240, 28.4)
#          2: (486, 7.06667)
#          5: (215, 17.8833)
#      SBGR - SP:
#          1: (311, 3.76667)
#          24: (311, 85.45)
#          18: (332, 64.4667)
#          20: (319, 71.8)
#          3: (288, 10.7167)
#          42: (382, 146.35)
#          29: (391, 101.283)
#          19: (422, 67.95)
#      SBSP - SP:
#          8: (354, 29.1333)
#      SBTE - PI:
#          1: (1447, 1.7)
# SBMS - RN:
#      SBFZ - CE:
#          3: (3008, 5)
#      SBSG - RN:
#          4: (584, 7)
#          3: (432, 3.63333)
#      SBRF - PE:
#          29: (113, 37.4167)
#          19: (119, 24.5)
#          22: (133, 27.7333)
# SNIG - CE:
#      SBFZ - CE:
#          4: (633, 5.23333)
#          3: (2008, 4.28333)
#          5: (5003, 6.75)
# SNOB - CE:
#      SBFZ - CE:
#          10: (740, 10.4333)
#          8: (1082, 8.26667)
# SNWS - CE:
#      SBFZ - CE:
#          6: (559, 7.61667)
#          4: (1527, 8)
# SWBE - CE:
#      SBFZ - CE:
#          6: (537, 7.46667)
#          3: (719, 3.98333)
#          2: (792, 2.53333)
# SBIH - PA:
#      SBTB - PA:
#          12: (1384, 16.1167)
#          6: (1106, 7.01667)
#      SNRJ - PA:
#          4: (872, 4.3)
#          9: (1680, 9.18333)
#      SBEG - AM:
#          13: (106, 17.9167)
#          11: (128, 15.3333)
#          14: (139, 19.8333)
#          8: (404, 20)
#      SWPI - AM:
#          2: (6349, 1.38333)
# SBTB - PA:
#      SNOX - PA:
#          12: (1085, 5.71667)
#          10: (3081, 4.61667)
#          11: (413, 5.48333)
#      SBEG - AM:
#          13: (198, 16.0)
#          1: (205, 0.95)
#          10: (172, 12.9333)
#          9: (168, 11.8333)
# SBJR - RJ:
#      SBJD - SP:
#          2: (2496, 3.41667)
#          5: (6519, 8.81667)
#      SBSP - SP:
#          111: (637, 186.7)
#          123: (1073, 211.383)
#          167: (600, 284.2)
# SBSP - SP:
#      SBJD - SP:
#          5: (2910, 7)
#      SBJR - RJ:
#          109: (737, 170.1)
#          123: (823, 184.45)
#          169: (529, 262.383)
#      SBCF - MG:
#          125: (185, 158.567)
#          142: (208, 178.617)
#          185: (180, 230.7)
#          174: (118, 223.167)
#          203: (132, 269.25)
#          251: (132, 331.383)
#          14: (185, 17.2333)
#          208: (155, 251.2)
#          1: (198, 1.08333)
#          187: (164, 226.683)
#          7: (204, 8.4)
#          229: (148, 278.433)
#      SBGL - RJ:
#          3: (610, 5.46667)
#          1: (676, 2)
#          5: (193, 8.76667)
#          7: (303, 14.65)
#          2: (218, 4)
#          11: (163, 15.7833)
#      SBMO - AL:
#          19: (264, 56.3333)
#          31: (266, 91.9333)
#          29: (286, 88.0833)
#          25: (264, 74.9)
#          3: (310, 8.36667)
#          58: (325, 165.567)
#          1: (395, 3.05)
#          44: (331, 127.083)
#          34: (318, 95.6667)
#      SBPS - BA:
#          25: (311, 47.4667)
#          87: (181, 169.533)
#          16: (184, 31.0167)
#          11: (207, 21.3)
#          6: (206, 11.6333)
#          94: (203, 178.8)
#          82: (213, 157.117)
#          3: (280, 6.05)
#          69: (214, 131.717)
#      SBRF - PE:
#          122: (343, 377.133)
#          109: (383, 344.65)
#          124: (290, 383.533)
#          13: (264, 41.1)
#          186: (273, 592.133)
#          147: (290, 472.217)
#          169: (280, 542.0)
# ...
#      SBGO - GO:
#          13: (296, 22.75)
#      SBKP - SP:
#          140: (182, 230.85)
#          120: (205, 195.583)
#          136: (238, 224.367)
#      SBRF - PE:
#          26: (360, 57.9667)
#          1: (290, 2.25)
#      SBRJ - RJ:
#          1: (260, 1.36667)
#          28: (191, 30.2)
#          48: (208, 54.0167)
#          60: (204, 63.55)
#          6: (271, 9)
#          76: (123, 84.4833)
#          73: (148, 83.5333)
#          99: (141, 107.983)
#          9: (171, 9.58333)
#          125: (181, 133.267)
#          112: (182, 121.767)
#          129: (172, 137.233)
#      SBGR - SP:
#          47: (148, 73.4333)
#          46: (148, 72.2833)
#          60: (149, 96.0834)
#          10: (213, 15.9)
#          123: (214, 182.833)
#          2: (265, 3.71667)
#          100: (213, 148.917)
#          4: (122, 6.56667)
#          114: (222, 170.583)
#      SBSP - SP:
#          7: (342, 17)
#          124: (170, 200.383)
#          80: (181, 131.65)
#          103: (171, 168.65)
#          11: (205, 17.1333)
#          178: (234, 280.75)
#          159: (247, 249.817)
#          183: (237, 291.683)
#      SBSV - BA:
#          22: (147, 33.1667)
#          31: (137, 46.3667)
#          2: (130, 2.68333)
#          24: (212, 54)
#      SBVT - ES:
#          2: (446, 5.05)
#      SBBR - DF:
#          2: (233, 3.48333)
#          51: (386, 127)
#          43: (247, 70.5167)
#          1: (268, 1.66667)
#      SBFZ - CE:
#          2: (242, 5.33333)
#          28: (525, 115)
#          1: (313, 2.68333)
#          30: (330, 81.15)
# SNBR - BA:
#      SBCF - MG:
#          29: (284, 96)
#          26: (170, 57.4)
#      SBBR - DF:
#          21: (152, 31.95)
#          2: (331, 3.05)
#          18: (157, 28.15)
#          22: (146, 34.1333)
#      SBLE - BA:
#          5: (526, 6.15)
#          6: (34182, 7.21667)
#      SBSV - BA:
#          16: (186, 30.8667)
#          1: (267, 1.96667)
#          12: (151, 23.7833)
#          15: (157, 29.35)
# SNGI - BA:
#      SBCF - MG:
#          17: (136, 28.4833)
#          18: (171, 30.1667)
#          30: (198, 48.9)
# SBCG - MS:
#      SBCR - MS:
#          4: (367, 3.61667)
#      SBCT - PR:
#          23: (316, 50)
#          2: (247, 2.9)
#          27: (235, 38.6333)
#      SBCY - MT:
#          21: (182, 23.6)
#          19: (238, 21.7333)
#          23: (265, 26.2167)
#      SBKP - SP:
#          117: (122, 186.0)
#          1: (301, 1.46667)
#          101: (123, 158.433)
#          119: (129, 188.6)
#      SBFL - SC:
#          6: (132, 10.2)
#      SBGL - RJ:
#          6: (159, 11.8167)
#          1: (165, 1.95)
#      SBGR - SP:
#          30: (154, 52.4833)
#          20: (182, 34.6167)
#          36: (174, 63.3833)
#          6: (196, 9.96667)
#          90: (215, 153.817)
#          78: (212, 131.583)
#          5: (204, 9.48333)
#          82: (217, 140.067)
#      SBPA - RS:
#          4: (168, 7.08333)
#          2: (1193, 3.83333)
#      SBPS - BA:
#          1: (225, 2.48333)
#      SBSP - SP:
#          109: (165, 181.783)
#          100: (183, 171.75)
#          1: (276, 1.73333)
#          107: (173, 184.15)
#          3: (174, 4.8)
#          58: (187, 95.75)
#          57: (208, 93.2)
#          2: (214, 3.28333)
#          72: (219, 117.317)
#      SBBR - DF:
#          4: (244, 6.2)
#          57: (240, 89.5834)
#          1: (346, 2)
#          41: (239, 63.9167)
#          54: (218, 83.4)
# SBCR - MS:
#      SBCG - MS:
#          4: (121, 3.2)
#          1: (255, 1.23333)
#      SBKP - SP:
#          1: (34, 1.93333)
# SBCH - SC:
#      SBCY - MT:
#          5: (392, 10.7333)
#      SBFL - SC:
#          25: (118, 31.7667)
#          1: (72, 0.966667)
#          20: (95, 18.9667)
#          27: (76, 25.55)
#      SBKP - SP:
#          77: (145, 109.95)
#          75: (120, 106.267)
#          79: (108, 111.367)
#      SBNF - SC:
#          11: (181, 13.5)
#      SBPA - RS:
#          12: (200, 14.0833)
#      SBGR - SP:
#          62: (149, 96.85)
#          50: (148, 80.7167)
#          53: (136, 84.4833)
#          1: (291, 2)
#          35: (211, 54.6167)
#          29: (254, 45.0)
#          39: (194, 60.0667)
# SBLO - PR:
#      SBCT - PR:
#          50: (159, 50.1167)
#          64: (139, 65.2667)
#          62: (116, 61.05)
#      SBCY - MT:
#          1: (304, 2.58333)
#          6: (173, 10.3167)
#      SBKP - SP:
#          118: (103, 158.683)
#          98: (117, 124.2)
#          89: (103, 117.6)
#      SBMO - AL:
#          4: (600, 19)
#      SBPS - BA:
#          5: (249, 11.1667)
#          4: (451, 9.11667)
#      SBGR - SP:
#          46: (110, 54.3167)
#          2: (191, 2.4)
#          39: (113, 46.5167)
#          48: (117, 58.7667)
#          5: (167, 5.71667)
#          69: (167, 77.1833)
#          52: (147, 58.4833)
#          3: (150, 3.21667)
#          80: (150, 89.6167)
#      SBSP - SP:
#          2: (206, 2.01667)
#          29: (192, 31.7667)
#          30: (192, 33.55)
#          1: (241, 0.916667)
#          41: (153, 47.25)
# SBMG - PR:
#      SBCT - PR:
#          60: (162, 69.6333)
#          68: (152, 78.2167)
#          71: (121, 83.0667)
#      SBKP - SP:
#          115: (118, 177.933)
#          1: (115, 1.48333)
#          101: (122, 153.017)
#          88: (114, 134.817)
#      SBPS - BA:
#          4: (488, 9.23333)
#          1: (799, 2.36667)
#      SBRP - SP:
#          1: (236, 2.56667)
#      SBCY - MT:
#          4: (147, 6.58333)
#      SBGR - SP:
#          85: (120, 112.717)
#          69: (125, 94.65)
#          74: (114, 101.2)
#          2: (169, 2.76667)
#          29: (166, 40.4167)
#          28: (161, 37.0167)
#          1: (79, 1.36667)
#          35: (168, 46.2)
#      SBSV - BA:
#          2: (308, 5.75)
#      SBSP - SP:
#          6: (159, 7.63333)
# SBPO - PR:
#      SBCT - PR:
#          16: (113, 17.25)
#          19: (145, 20.7)
#          27: (117, 29.5)
# SBCX - RS:
#      SBKP - SP:
#          25: (203, 38.9667)
#          21: (234, 32.45)
#          5: (206, 10.8167)
#          19: (210, 29.8167)
#      SBGR - SP:
#          1: (332, 3)
#          47: (179, 77.4333)
#          35: (176, 57.1)
#          39: (166, 62.85)
#          2: (209, 3.21667)
#          29: (210, 45.25)
#          27: (207, 43.2167)
#          30: (199, 49.3833)
#      SBGL - RJ:
#          1: (361, 1.88333)
#      SBRJ - RJ:
#          12: (217, 20.7667)
#      SBSP - SP:
#          1: (521, 1.46667)
#          6: (145, 8.98333)
# SBSI - MT:
#      SBCY - MT:
#          52: (129, 52.8667)
#          29: (102, 30.5333)
#          1: (109, 0.883333)
#          30: (100, 31.1667)
#          8: (228, 8.03333)
#      SBKP - SP:
#          3: (334, 7.23333)
#          23: (205, 54.5333)
#          24: (218, 57.3833)
#          27: (218, 65.1167)
#      SBGR - SP:
#          31: (345, 81.3)
#          18: (292, 48.0)
#          26: (256, 67.0333)
#      SBBR - DF:
#          3: (274, 4.65)
#          28: (229, 46.15)
#          1: (380, 3)
#          27: (220, 43.8)
#          30: (207, 48.85)
# SBSO - MT:
#      SBCY - MT:
#          19: (170, 25)
#          23: (117, 20.3333)
# SBVH - RO:
#      SBCY - MT:
#          22: (145, 24.8167)
#          18: (169, 19.75)
#          21: (169, 22.9)
# SSKW - RO:
#      SBCY - MT:
#          1: (268, 2)
#          25: (183, 34.0667)
#          18: (207, 24.1667)
#          24: (201, 32.0167)
# SBDB - MS:
#      SBKP - SP:
#          30: (714, 50.7)
#          14: (773, 23.6)
#          16: (664, 27.1167)
#      SBSP - SP:
#          9: (312, 26)
#          8: (208, 14.7)
# SBDN - SP:
#      SBKP - SP:
#          87: (130, 120.017)
#          1: (129, 1.36667)
#          70: (137, 95.9667)
#          83: (146, 114.2)
#      SBMO - AL:
#          4: (492, 19)
#      SBPS - BA:
#          4: (530, 15)
#      SBRF - PE:
#          4: (360, 13.25)
#      SBRP - SP:
#          1: (2809, 2.3)
#      SBGR - SP:
#          26: (123, 33.4)
#          2: (244, 4)
#          29: (160, 34.4667)
#          27: (250, 31.2833)
#          1: (411, 1.2)
#          30: (209, 37.0667)
#      SBSP - SP:
#          20: (131, 25.8667)
#          30: (133, 36.45)
# SBTT - AM:
#      SBEG - AM:
#          1: (419, 1.66667)
#          29: (289, 51.4667)
#          26: (341, 46.4167)
#          35: (392, 68.1333)
# SBUA - AM:
#      SBEG - AM:
#          3: (210, 4.18333)
#          5: (199, 7.0)
#          2: (254, 2.73333)
#          7: (333, 10.3833)
#          1: (200, 2.35)
#          6: (272, 8.71667)
# SWEI - AM:
#      SBTT - AM:
#          7: (867, 6.18333)
# SWPI - AM:
#      SBEG - AM:
#          22: (117, 18.5333)
#          1: (174, 1.05)
#          13: (133, 11.2333)
#          2: (135, 1.7)
#          16: (127, 13.4667)
#          6: (459, 10)
#          7: (187, 7.88333)
# SBFE - BA:
#      SBRF - PE:
#          19: (183, 34.1167)
#          18: (209, 31.6333)
#          20: (213, 34.3833)
# SBNM - RS:
#      SBFL - SC:
#          8: (138, 12.7333)
#      SBPA - RS:
#          16: (96, 18.3333)
#          24: (150, 27.9833)
#          31: (143, 35.9333)
#      SBGR - SP:
#          13: (358, 35)
#          12: (225, 22.3167)
# SBPF - RS:
#      SBFL - SC:
#          12: (86, 14.4)
#      SBKP - SP:
#          56: (324, 127)
#          3: (156, 5.98333)
#          30: (185, 43.5833)
#      SBGR - SP:
#          1: (724, 3)
#          22: (206, 36.1333)
#          18: (215, 29.3)
#          24: (181, 38.35)
#          3: (242, 5.16667)
#      SBPA - RS:
#          1: (77, 0.916667)
#      SBGL - RJ:
#          1: (390, 2.71667)
# SBPK - RS:
#      SBFL - SC:
#          8: (196, 12.7167)
#      SBPA - RS:
#          16: (116, 19)
#          22: (111, 18.2667)
#      SBGR - SP:
#          17: (241, 35.05)
#          15: (279, 30.6)
#          16: (285, 32.6667)
# SBSM - RS:
#      SBFL - SC:
#          12: (169, 18.3333)
#      SBPA - RS:
#          24: (109, 19.65)
#          25: (129, 21.8)
#          29: (134, 24.4167)
#      SBSP - SP:
#          13: (404, 33.7333)
#          12: (398, 30.9833)
#          10: (301, 26.0167)
# SBUG - RS:
#      SBFL - SC:
#          12: (255, 26.1)
#      SBPA - RS:
#          14: (162, 20.9667)
#          18: (176, 27.75)
#          22: (207, 33.1167)
#      SBSM - RS:
#          9: (176, 8.71667)
#          12: (142, 11.8167)
#          10: (115, 10.0833)
#      SBSP - SP:
#          4: (369, 12.7)
#          5: (851, 15.0667)
# SBFN - PE:
#      SBRF - PE:
#          103: (111, 156.767)
#          92: (110, 139.05)
#          22: (133, 32.9)
#          136: (120, 204.167)
#          162: (130, 245.7)
#          2: (690, 2.96667)
#          54: (176, 78.8)
#          47: (149, 70.3333)
#          14: (365, 20.3333)
#      SBSG - RN:
#          4: (182, 9)
#      SBMO - AL:
#          1: (333, 2.6)
# SBJU - CE:
#      SBFZ - CE:
#          2: (171, 2.13333)
#          26: (181, 30.65)
#          24: (272, 43)
#      SBKP - SP:
#          30: (217, 90.6667)
#          28: (239, 83.9)
#          1: (319, 3.03333)
#          29: (250, 89.0333)
#      SBRF - PE:
#          3: (364, 5)
#          26: (230, 41)
#          22: (143, 22.5)
#      SBGR - SP:
#          5: (284, 15.2833)
#          57: (269, 175.167)
#          38: (394, 173)
#          2: (544, 9)
#          29: (510, 128)
#          27: (330, 80.2667)
# SBPJ - TO:
#      SBBR - DF:
#          1: (528, 3)
#          38: (140, 50.9333)
#          35: (141, 46.3333)
#          36: (136, 47.2833)
#          2: (161, 2.51667)
#          29: (149, 38.1167)
#          28: (152, 36.5833)
#          30: (143, 39.3)
#      SBGO - GO:
#          28: (164, 37.7)
#          27: (192, 36.1667)
#          29: (206, 38.25)
#          5: (158, 7.08333)
#      SBKP - SP:
#          23: (254, 53.75)
#          47: (286, 109.333)
#          28: (303, 64.0333)
#      SBRF - PE:
#          14: (240, 31.7333)
#      SBCF - MG:
#          1: (306, 2.0)
#          17: (231, 30.9167)
#      SBGR - SP:
#          15: (385, 55)
#          13: (240, 30.9)
#          4: (281, 9.56667)
#          58: (301, 137.2)
#          49: (346, 116.9)
#          2: (379, 4.43333)
#          60: (308, 140.4)
# SBJA - SC:
#      SBKP - SP:
#          25: (158, 47.4167)
#          26: (188, 49.2)
#          30: (203, 56.3167)
#      SBGR - SP:
#          2: (199, 4.01667)
#      SBSP - SP:
#          2: (354, 4)
#          26: (173, 31.9667)
#          30: (182, 40.9667)
#          37: (185, 49.15)
# SBJV - SC:
#      SBKP - SP:
#          117: (118, 162.617)
#          101: (127, 134.617)
#          115: (112, 154.633)
#      SBPS - BA:
#          4: (1072, 9.21667)
#          1: (1562, 2.26667)
#      SBGR - SP:
#          1: (222, 2)
#          25: (226, 47)
#          23: (122, 27.4333)
#          27: (128, 33.2833)
#          2: (159, 2.35)
#          28: (154, 33.6333)
#          30: (136, 36.0)
#      SBSP - SP:
#          13: (104, 12.3833)
#          11: (128, 10.7)
#          1: (111, 1.03333)
#          21: (123, 20.95)
# SBKG - PB:
#      SBRF - PE:
#          52: (49, 31.4333)
#          2: (69, 1.11667)
#          35: (83, 32)
#      SBGR - SP:
#          26: (404, 84.4167)
#      SBSV - BA:
#          2: (532, 2.63333)
#          19: (176, 25.5333)
#          27: (196, 37.1667)
# SBML - SP:
#      SBKP - SP:
#          29: (112, 29.4167)
#          24: (114, 24.5833)
#          4: (146, 4.36667)
#          31: (95, 30.1333)
#      SBRP - SP:
#          1: (146, 1.06667)
# SBPG - PR:
#      SBKP - SP:
#          11: (101, 13.9167)
#          13: (115, 16.4333)
#          22: (137, 28.0667)
# SBPL - PE:
#      SBKP - SP:
#          1: (7894, 2.65)
#          29: (194, 75.4167)
#          28: (237, 72.8667)
#          31: (303, 81.4667)
#      SBRF - PE:
#          1: (247, 1.23333)
#          26: (155, 34.3167)
#          39: (170, 51.8)
#          53: (188, 68.8333)
#      SWKQ - PI:
#          5: (4850, 4.43333)
#          3: (3020, 4)
#      SBGR - SP:
#          17: (360, 70)
#          44: (259, 120.817)
#          27: (271, 73.7667)
#          3: (282, 7.8)
#          49: (282, 130.25)
#          37: (280, 98.85)
#          2: (272, 5.03333)
#          52: (306, 137.783)
# SBPP - MS:
#      SBCF - MG:
#          1: (180, 2.43333)
#      SBKP - SP:
#          29: (149, 45.85)
#          26: (140, 39.85)
#          31: (147, 48.5833)
# SBRD - MT:
#      SBKP - SP:
#          1: (687, 1.68333)
#          14: (238, 25.65)
#          17: (351, 33.25)
#          22: (344, 42.9)
# SBTD - PR:
#      SBKP - SP:
#          13: (337, 35)
#          20: (193, 37.1833)
# SBTG - MS:
#      SBKP - SP:
#          22: (152, 33.9167)
#          18: (152, 27.3)
#          23: (145, 34.6833)
# SNCP - SC:
#      SBKP - SP:
#          17: (268, 45)
#          25: (183, 42.6833)
# SSGG - PR:
#      SBKP - SP:
#          11: (129, 16.4833)
#          14: (139, 20.5833)
#          25: (144, 37.8833)
# SWLC - GO:
#      SBKP - SP:
#          21: (181, 39.3)
#          26: (176, 48.4833)
#          29: (169, 54.5667)
#      SBRP - SP:
#          1: (126, 1.51667)
# SWKQ - PI:
#      SBPL - PE:
#          3: (824, 2.3)
#          4: (334, 2.85)
#          5: (674, 3.73333)
#      SBRF - PE:
#          5: (338, 11.2167)
#          3: (344, 10)
# SBUF - BA:
#      SBRF - PE:
#          1: (147, 1.06667)
#          11: (265, 24)
#      SBSV - BA:
#          7: (153, 8.26667)
#          3: (146, 3.48333)
#          4: (179, 4.51667)
# SBRB - AC:
#      SBBR - DF:
#          30: (437, 102.133)
#          1: (309, 3.13333)
#          29: (582, 145)
#          31: (339, 102.3)
#          2: (376, 6.41667)
#          28: (361, 91.45)
#          4: (372, 13.0)
#          27: (342, 86.5667)
#      SBCZ - AC:
#          13: (397, 16.2667)
#          11: (290, 13.4833)
#          14: (250, 16.7167)
#      SBEG - AM:
#          18: (173, 35.5333)
#          10: (168, 18.8833)
#          11: (192, 20.85)
#      SBGR - SP:
#          15: (410, 60.0167)
#          2: (642, 12)
#          28: (527, 111.4)
#          22: (470, 87.0667)
#          10: (472, 39.2)
#      SBCT - PR:
#          1: (1193, 4.03333)
# SBCZ - AC:
#      SBRB - AC:
#          12: (353, 15.0333)
#          11: (307, 13.05)
#          14: (268, 16.4333)
# SBOI - AP:
#      SBMQ - AP:
#          9: (354, 10.75)
#          20: (333, 25.25)
#          25: (408, 30.85)
# SBUY - AM:
#      SBEG - AM:
#          43: (301, 109)
#          1: (158, 1.63333)
#          46: (189, 76.0)
#      SBUY - AM:
#          1: (246, 2)
#      SWCA - AM:
#          13: (79, 7.5)
#          12: (66, 7.16667)
#          14: (88, 8.25)
#      SBSN - PA:
#          1: (161, 3.01667)
# SWCA - AM:
#      SBEG - AM:
#          1: (348, 3)
#          9: (258, 17.7333)
#          7: (218, 14.1167)
#          5: (193, 9.65)
#      SBUY - AM:
#          13: (98, 12)
#          12: (68, 7.56667)
#      SWKO - AM:
#          3: (789, 3.55)
#          4: (2364, 7)
# SWGN - TO:
#      SBBR - DF:
#          14: (336, 53)
#          11: (217, 27.65)
# SNTF - BA:
#      SBMK - MG:
#          6: (2390, 7.7)
#          8: (3367, 10.3167)
#          7: (3108, 8.83333)
#      SBSV - BA:
#          10: (188, 14.6833)
#          7: (241, 10.3333)
#          9: (225, 12.9167)
#      SBIP - MG:
#          2: (1093, 2.21667)
#      SBSP - SP:
#          1: (350, 2.88333)
# SBMH - PR:
#      SBCT - PR:
#          1: (323, 1.08333)

# %%
len(grafo.grafo)
# Out:
# 164

# %%
print("Vértices: ", grafo.quantidadeVertices)
print("Arestas: ",grafo.quantidadeArestas)
# Out:
# Vértices:  164
# Arestas:  5270

# %% [markdown]
# ## Conexão com o banco de dados
# Para a conexão com o banco de dados, vamos utilizar o Neo4j.<br>
# - Baixar a imagem oficial no Docker
# - Configurar as variáveis:
#     - portas: 0.0.0.0:7473, 0.0.0.0:7474, 0.0.0.0:7687
#     - volumes: /data e /logs
#     - vaiáveis de ambiente: NEO4J_AUTH: neo4j/test1234

# %% [markdown]
# ### Classe de Conexão com o Neo4j

# %%
pip install neo4j

# %%
from neo4j import GraphDatabase

class ConectionNeo4j:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    #GERENCIAMENTO DE AEROPORTOS ---------------------------------------------------------------------
    def createAirport(self, sigla, nome):
        with self.driver.session() as session:
            greeting = session.execute_write(self.createAirportTX, sigla, nome)
            print(greeting)

    def deleteAirport(self, sigla):
        with self.driver.session() as session:
            greeting = session.execute_write(self.deleteAirportTX, sigla)
            print(greeting)

    @staticmethod
    def deleteAirportTX(tx, sigla):
        result = tx.run("MATCH (o:Airport {sigla: $sigla})"
                        "DETACH DELETE o", 
                        sigla=sigla
                        )
        return "Aeroporto deletado"

    @staticmethod
    def createAirportTX(tx, sigla, nome):
        result = tx.run("CREATE (o:Airport {sigla: $sigla, nome: $nome})", 
                        sigla=sigla,
                        nome=nome
                        )
        return "Aeroporto Criado"

    #GERENCIAMENTO DE ROTAS ROUTES ---------------------------------------------------------------------
    def createRote(self, origem, destino, label, peso, tempo):
        with self.driver.session() as session:
            greeting = session.execute_write(self.createRoteTX, origem, destino, label, peso, tempo)
            print(greeting)

    @staticmethod
    def createRoteTX(tx, origem, destino, label, peso, tempo):
        result = tx.run("MATCH (o:Airport {sigla: $origem}) "
                        "MATCH (d:Airport {sigla: $destino}) "
                        "CREATE (o)-[r:Route]->(d)"
                        "SET r.label = $label "
                        "SET r.peso = $peso "
                        "SET r.tempo = $tempo ", 
                        origem=origem,
                        destino=destino,
                        label=label,
                        peso=peso,
                        tempo=tempo
                        )
        return "Rota Padrão Criada"
    
    def deleteAllRoutes(self):
        with self.driver.session() as session:
            greeting = session.execute_write(self.deleteAllRoutesTX)
            print(greeting)

    @staticmethod
    def deleteAllRoutesTX(tx):
        result = tx.run("MATCH ()-[r:Route]->()"
                        "DETACH DELETE r")
        return "Rotas Padrão Deletadas"
    
    #GERENCIAMENTO DE ROTAS PESO ---------------------------------------------------------------------
    def createRotePeso(self, origem, destino, peso, tempo, label):
        with self.driver.session() as session:
            greeting = session.execute_write(self.createRotePesoTX, origem, destino, peso, tempo, label)
            print(greeting)

    @staticmethod
    def createRotePesoTX(tx, origem, destino, label, peso, tempo):
        result = tx.run("MATCH (o:Airport {sigla: $origem}) "
                        "MATCH (d:Airport {sigla: $destino}) "
                        "CREATE (o)-[r:RoutePeso]->(d)"
                        "SET r.peso = $peso "
                        "SET r.tempo = $tempo "
                        "SET r.label = $label ",
                        origem=origem,
                        destino=destino,
                        label=label,
                        peso=peso,
                        tempo=tempo
                        )
        return "Rota Peso Criada"
    
    def deleteAllRoutesPeso(self):
        with self.driver.session() as session:
            greeting = session.execute_write(self.deleteAllRoutesPesoTX)
            print(greeting)

    @staticmethod
    def deleteAllRoutesPesoTX(tx):
        result = tx.run("MATCH ()-[r:RoutePeso]->()"
                        "DETACH DELETE r")
        return "Rotas Peso Deletadas"
    
    #GERENCIAMENTO DE ROTAS PRIM ---------------------------------------------------------------------
    def createRotePrim(self, origem, destino, peso, tempo, label):
        with self.driver.session() as session:
            greeting = session.execute_write(self.createRotePrimTX, origem, destino, peso, tempo, label)
            print(greeting)

    @staticmethod
    def createRotePrimTX(tx, origem, destino, label, peso, tempo):
        result = tx.run("MATCH (o:Airport {sigla: $origem}) "
                        "MATCH (d:Airport {sigla: $destino}) "
                        "CREATE (o)-[r:RoutePrim]->(d)"
                        "SET r.peso = $peso "
                        "SET r.tempo = $tempo "
                        "SET r.label = $label ",
                        origem=origem,
                        destino=destino,
                        label=label,
                        peso=peso,
                        tempo=tempo
                        )
        return "Rota Prim Criada"
    
    def deleteAllRoutesPrim(self):
        with self.driver.session() as session:
            greeting = session.execute_write(self.deleteAllRoutesPrimTX)
            print(greeting)

    @staticmethod
    def deleteAllRoutesPrimTX(tx):
        result = tx.run("MATCH ()-[r:RoutePrim]->()"
                        "DETACH DELETE r")
        return "Rotas Prim Deletadas"
    
    #GERENCIAMENTO DE ROTAS BUSCA ---------------------------------------------------------------------
    def createRoteBusca(self, origem, destino, peso, tempo, label):
        with self.driver.session() as session:
            greeting = session.execute_write(self.createRoteBuscaTX, origem, destino, peso, tempo, label)
            print(greeting)

    @staticmethod
    def createRoteBuscaTX(tx, origem, destino, label, peso, tempo):
        result = tx.run("MATCH (o:Airport {sigla: $origem}) "
                        "MATCH (d:Airport {sigla: $destino}) "
                        "CREATE (o)-[r:Busca]->(d)"
                        "SET r.peso = $peso "
                        "SET r.tempo = $tempo "
                        "SET r.label = $label ",
                        origem=origem,
                        destino=destino,
                        label=label,
                        peso=peso,
                        tempo=tempo
                        )
        return "Rota Busca Criada"
    
    def deleteAllRoutesBusca(self):
        with self.driver.session() as session:
            greeting = session.execute_write(self.deleteAllRoutesBuscaTX)
            print(greeting)

    @staticmethod
    def deleteAllRoutesBuscaTX(tx):
        result = tx.run("MATCH ()-[r:Busca]->()"
                        "DETACH DELETE r")
        return "Rotas Busca Deletadas"

# %% [markdown]
# ### Funções úteis

# %%
def criarAeroportos(grafo):
    conn = ConectionNeo4j("bolt://localhost:7687", "neo4j", "password")
    for x in grafo.grafo.keys():
        conn.createAirport(sigla=x, nome=grafo.aeroportos[x])
    conn.close()

def criarRotasRoutes(grafo):
    conn = ConectionNeo4j("bolt://localhost:7687", "neo4j", "password")
    for origem in grafo.grafo.keys():
        for destino in grafo.grafo[origem].keys():
            for label, value in grafo.grafo[origem][destino].items():
                conn.createRote(origem=origem,destino=destino, label=label, peso=value[0], tempo=value[1])
    conn.close()

def criarRotasPeso(grafo):
    conn = ConectionNeo4j("bolt://localhost:7687", "neo4j", "password")
    for origem in grafo.grafo.keys():
        for destino, value in grafo.grafo[origem].items():
            peso, tempo, label = value
            conn.createRotePeso(origem=origem,destino=destino, label=label, peso=peso, tempo=tempo)
    conn.close()

def criarRotasPrim(grafo):
    conn = ConectionNeo4j("bolt://localhost:7687", "neo4j", "password")
    for origem in grafo.grafo.keys():
        for destino, value in grafo.grafo[origem].items():
            peso, tempo, label = value
            conn.createRotePrim(origem=origem,destino=destino, label=label, peso=peso, tempo=tempo)
    conn.close()

def criarRotasBusca(grafo, rota):
    conn = ConectionNeo4j("bolt://localhost:7687", "neo4j", "password")
    for i in range(len(rota)-1):    
        origem = rota[i]
        destino = rota[i+1]
        peso, tempo, label = grafo.grafo[origem][destino]
        conn.createRoteBusca(origem=origem,destino=destino, label=label, peso=peso, tempo=tempo)
    conn.close()

def deletarAeroportos(grafo):
    conn = ConectionNeo4j("bolt://localhost:7687", "neo4j", "password")
    for x in grafo.grafo.keys():
        conn.deleteAirport(sigla=x)
    conn.close()    

def deletarAllRoutesRoutes():
    conn = ConectionNeo4j("bolt://localhost:7687", "neo4j", "password")
    conn.deleteAllRoutes()
    conn.close()

def deletarAllRoutesPeso():
    conn = ConectionNeo4j("bolt://localhost:7687", "neo4j", "password")
    conn.deleteAllRoutesPeso()
    conn.close()

def deletarAllRoutesPrim():
    conn = ConectionNeo4j("bolt://localhost:7687", "neo4j", "password")
    conn.deleteAllRoutesPrim()
    conn.close()

def deletarAllRoutesBusca():
    conn = ConectionNeo4j("bolt://localhost:7687", "neo4j", "password")
    conn.deleteAllRoutesBusca()
    conn.close()

# %%
criarAeroportos(grafo)
criarRotasRoutes(grafo)
# Out:
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Aeroporto Criado
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# ...
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada
# Rota Padrão Criada

# %% [markdown]
# ## Problemas
# Com essa maginitude de arestas é impossível trabalhar em tempo hábil. Precisaremos reduzir!<br>
# Para reduzir, vamos realizar uma *redução por peso* (ou seja, pelo preço da passagem) e depois realizar uma redução utilizando o algoritmo de **Prim**.

# %% [markdown]
# ### Grafo Reduzido

# %%
class GrafoReduzidoPeso:
    grafo = None
    aeroportos = None
    vertices = 0
    arestas = 0
    def __init__(self):
        self.grafo = {}
        self.aeroportos = {}
    
    def reduzGrafoPorPeso(self, g:Grafo):
        grafo = g.grafo
        aeroportos = g.aeroportos
        for origem in grafo.keys():

            if(not(origem in self.grafo.keys())):
                self.grafo[origem] = {}
                self.vertices +=1
            
            if(not(origem in self.aeroportos.keys())):
                self.aeroportos[origem] = aeroportos[origem]
            
            for destino in grafo[origem].keys():
                lista = [ (value[0], value[1], key) for key, value in grafo[origem][destino].items() ]
                lista.sort()
                self.grafo[origem][destino] = lista[0]
                self.arestas+=1
    
    def adicionarAresta(self, origem, nomeOrigem, destino, nomeDestino, rota):
        #existe origem?
        if(origem in self.grafo.keys()):
        #sim
            self.grafo[origem][destino] = rota
        #nao
        else:
            #adicionar [origem] = {"destino" : {"label" : peso}}
            self.grafo[origem] = {destino : rota}
            self.aeroportos[origem] = nomeOrigem
        
        if(not(destino in self.grafo.keys())):
            self.grafo[destino] = {}
            self.aeroportos[destino] = nomeDestino
    
    def adicionarVertice(self, origem, nomeOrigem):
        if(not(origem in self.grafo.keys())):
            self.grafo[origem] = {}
            self.aeroportos[origem] = nomeOrigem

# %%
grafoReduzidoPeso = GrafoReduzidoPeso()
grafoReduzidoPeso.reduzGrafoPorPeso(grafo)

# %%
grafoReduzidoPeso.grafo
# Out:
# {'SBSV - BA': {'SIRI - BA': (170, 3.699, 8),
#   'SNCL - BA': (112, 11.301, 31),
#   'SBBR - DF': (165, 174.183, 90),
#   'SBCF - MG': (155, 78.9, 46),
#   'SBCY - MT': (290, 2.83333, 1),
#   'SBFI - PR': (336, 3.43333, 1),
#   'SBGO - GO': (179, 47.85, 23),
#   'SBIL - BA': (61, 0.933333, 1),
#   'SBKP - SP': (216, 78.6833, 31),
#   'SBMK - MG': (251, 23.9667, 12),
#   'SBPS - BA': (95, 16.2, 15),
#   'SBRF - PE': (100, 31.35, 23),
#   'SBRJ - RJ': (215, 10.6167, 5),
#   'SBRP - SP': (216, 8.56667, 4),
#   'SBSR - SP': (374, 9.46667, 4),
#   'SBUL - MG': (393, 13, 4),
#   'SBVC - BA': (83, 1.11667, 1),
#   'SBGR - SP': (205, 7.48333, 3),
#   'SBCT - PR': (265, 8.41667, 3),
#   'SBFL - SC': (301, 14.8667, 5),
#   'SBFZ - CE': (138, 5.15, 3),
#   'SBGL - RJ': (174, 21.0833, 10),
#   'SBJP - PB': (105, 26.9833, 18),
#   'SBMG - PR': (346, 5.58333, 2),
#   'SBMO - AL': (77, 31.0167, 28),
#   'SBPA - RS': (357, 13.7667, 4),
#   'SBSG - RN': (134, 31.9, 20),
#   'SBSL - MA': (199, 38.45, 18),
#   'SBSP - SP': (208, 17.1833, 7),
#   'SBVT - ES': (156, 48.2833, 31),
#   'SBAR - SE': (70, 0.883333, 1),
#   'SBKG - PB': (208, 2.65, 2),
#   'SBLE - BA': (97, 2.18333, 2),
#   'SNBR - BA': (168, 32.5, 16),
#   'SBUF - BA': (122, 3.68333, 3),
#   'SNTF - BA': (246, 12.2, 8)},
#  'SIRI - BA': {'SBSV - BA': (183, 5.299, 10), 'SNCL - BA': (337, 0.567, 1)},
#  'SNCL - BA': {'SBSV - BA': (94, 25.268, 64)},
#  'SBAC - CE': {'SBFZ - CE': (527, 8.76667, 11)},
#  'SBFZ - CE': {'SBAC - CE': (2215, 8.46667, 11),
#   'SBJE - CE': (171, 4.73333, 5),
#   'SBMS - RN': (316, 3.23333, 3),
#   'SNIG - CE': (1411, 3.98333, 3),
#   'SNOB - CE': (1238, 8.06667, 8),
#   'SNWS - CE': (1800, 7.61667, 6),
#   'SWBE - CE': (514, 7.78333, 6),
#   'SBGR - SP': (21, 3.367, 1),
#   'SBBE - PA': (163, 47.3667, 24),
#   'SBCF - MG': (262, 78.0667, 29),
#   'SBCY - MT': (381, 20.5, 6),
#   'SBGL - RJ': (285, 293.15, 90),
#   'SBGO - GO': (272, 22.1167, 8),
#   'SBJU - CE': (171, 30.2333, 25),
#   'SBKP - SP': (295, 197.25, 57),
#   'SBPA - RS': (411, 4.56667, 1),
#   'SBRF - PE': (91, 2.36667, 2),
#   'SBRP - SP': (296, 15.9833, 5),
#   'SBSR - SP': (366, 16.6, 5),
#   'SBTE - PI': (137, 53.8833, 49),
#   'SBUL - MG': (292, 15.05, 5),
#   'SBAE - SP': (33766, 4.55, 1),
#   'SBMA - PA': (1468, 3.01667, 1),
#   'SBBR - DF': (236, 104.183, 38),
#   'SBEG - AM': (321, 90.5167, 26),
#   'SBSP - SP': (319, 195.117, 54),
#   'SBSV - BA': (145, 106.283, 59),
#   'SBFZ - CE': (91, 0.983333, 1),
#   'SBPB - PI': (360, 8.63333, 8),
#   'SBMO - AL': (150, 1.28333, 1),
#   'SBSG - RN': (116, 0.983333, 1),
#   'SBSL - MA': (150, 68.9833, 54),
#   'SBVT - ES': (322, 76.5, 28)},
#  'SBBE - PA': {'SBMD - PA': (989, 36.25, 20),
#   'SBSN - PA': (157, 65.3833, 49),
#   'SNEB - PA': (371, 12.7167, 11),
#   'SNSM - PA': (2860, 6.16667, 7),
#   'SNVS - PA': (243, 5.0, 5),
#   'SBTU - PA': (879, 10.3833, 8),
#   'SBBV - RR': (471, 37.7667, 17),
#   'SBCF - MG': (243, 191.8, 61),
#   'SBCJ - PA': (213, 31.9, 27),
#   'SBEG - AM': (177, 36.8667, 17),
#   'SBFZ - CE': (126, 3.75, 2),
#   'SBGL - RJ': (327, 89.1667, 25),
#   'SBHT - PA': (106, 31.9667, 30),
#   'SBKP - SP': (297, 216.933, 61),
#   'SBMA - PA': (133, 56.1667, 53),
#   'SBMQ - AP': (77, 54.15, 60),
#   'SBRF - PE': (317, 152.283, 60),
#   'SBSL - MA': (174, 55.2, 52),
#   'SBCT - PR': (62750, 4.21667, 1),
#   'SBPV - RO': (128, 3.35, 1),
#   'SBBR - DF': (244, 155.167, 59),
#   'SBGR - SP': (339, 70.05, 19)},
#  'SBMD - PA': {'SBBE - PA': (1141, 22.3833, 11), 'SNYA - PA': (340, 4.15, 9)},
#  'SBSN - PA': {'SBBE - PA': (137, 35.8, 25),
#   'SBEG - AM': (119, 16.5667, 13),
#   'SBIH - PA': (314, 11.2, 10),
#   'SBCF - MG': (498, 36.7833, 11),
#   'SBBR - DF': (292, 5.03333, 2)},
#  'SNEB - PA': {'SBBE - PA': (533, 10.65, 10)},
#  'SNSM - PA': {'SBBE - PA': (8497, 5.96667, 7)},
#  'SNVS - PA': {'SBBE - PA': (201, 5.66667, 5),
#   'SNMZ - PA': (996, 9.71667, 11)},
#  'SBBG - RS': {'SBPA - RS': (647, 22.05, 17)},
#  'SBPA - RS': {'SBBG - RS': (775, 24.7333, 17),
#   'SSCN - RS': (697, 6.83333, 11),
#   'SSLT - RS': (2927, 15.9167, 8),
#   'SSSC - RS': (1182, 7.08333, 9),
#   'SSZR - RS': (1502, 12.5333, 7),
#   'SBCF - MG': (207, 77.2, 36),
#   'SBCH - SC': (173, 15.1167, 12),
#   'SBCT - PR': (115, 25.4333, 22),
#   'SBFI - PR': (161, 47.3, 27),
#   'SBFL - SC': (99, 15.8667, 16),
#   'SBFZ - CE': (438, 4.8, 1),
#   'SBGL - RJ': (155, 6.7, 3),
#   'SBGR - SP': (174, 180.533, 99),
#   'SBKP - SP': (147, 396.167, 243),
#   'SBMO - AL': (381, 18.9833, 5),
#   'SBNF - SC': (121, 15.7833, 12),
#   'SBNM - RS': (125, 20.6167, 17),
#   'SBPK - RS': (102, 19.5, 22),
#   'SBPS - BA': (280, 2.66667, 1),
#   'SBRF - PE': (352, 4.01667, 1),
#   'SBRJ - RJ': (175, 137.283, 73),
#   'SBSM - RS': (136, 23.6667, 24),
#   'SBUG - RS': (198, 24.2667, 14),
#   'SBBR - DF': (237, 150.617, 60),
#   'SBRP - SP': (8296, 2.9, 1),
#   'SBPF - RS': (91, 1.18333, 1),
#   'SBSP - SP': (175, 20.6833, 13),
#   'SBCG - MS': (209, 7.61667, 4),
#   'SBSG - RN': (448, 51.7667, 12),
#   'SBSV - BA': (299, 13.5333, 4)},
#  'SBBW - MT': {'SBCY - MT': (989, 15.0, 9)},
#  'SBCY - MT': {'SBBW - MT': (979, 16.9333, 9),
#   'SBJI - RO': (184, 37.25, 25),
#   'SSOU - MT': (1308, 30.2, 10),
#   'SWHP - MT': (899, 16.0333, 8),
#   'SBAT - MT': (166, 27.4833, 22),
#   'SBBR - DF': (154, 46.4333, 28),
#   'SBCF - MG': (307, 99.6333, 46),
#   'SBCG - MS': (174, 20.85, 18),
#   'SBCH - SC': (484, 8.35, 4),
#   'SBCT - PR': (197, 7.9, 4),
#   'SBFI - PR': (364, 15.5833, 8),
#   'SBFL - SC': (759, 19.1667, 8),
#   'SBFZ - CE': (315, 6.63333, 2),
#   'SBGL - RJ': (350, 2.66667, 1),
#   'SBGO - GO': (238, 73.6, 52),
#   'SBGR - SP': (146, 2.25, 1),
#   'SBKP - SP': (195, 305.25, 149),
#   'SBLO - PR': (190, 6.75, 4),
#   'SBMO - AL': (311, 6.76667, 2),
#   'SBNF - SC': (219, 14.3167, 6),
#   'SBPS - BA': (624, 2.75, 1),
#   'SBPV - RO': (169, 64.1833, 35),
#   'SBRF - PE': (298, 3.45, 1),
#   'SBRJ - RJ': (359, 53.8667, 21),
#   'SBSG - RN': (515, 14.4833, 4),
#   'SBSI - MT': (89, 27.5667, 28),
#   'SBSO - MT': (108, 18.35, 20),
#   'SBSV - BA': (237, 5.85, 2),
#   'SBVH - RO': (144, 19.65, 18),
#   'SSKW - RO': (164, 33.9833, 25),
#   'SBSR - SP': (336, 2.16667, 1),
#   'SBMG - PR': (273, 6.3, 4),
#   'SBSP - SP': (247, 67.65, 30)},
#  'SBCF - MG': {'SBVG - MG': (344, 17.9667, 12),
#   'SBZM - MG': (90, 1.01667, 1),
#   'SNPD - MG': (347, 12.3833, 9),
#   'SNTO - MG': (340, 15.0333, 10),
#   'SNZR - MG': (908, 15.6333, 8),
#   'SBAR - SE': (205, 38.05, 19),
#   'SBBE - PA': (248, 186.517, 62),
#   'SBBR - DF': (124, 6.45, 5),
#   'SBCB - RJ': (111, 37.5333, 26),
#   'SBCJ - PA': (272, 72.6, 29),
#   'SBCN - GO': (159, 3.4, 3),
#   'SBCT - PR': (127, 54.0, 33),
#   'SBCY - MT': (280, 75.4833, 34),
#   'SBFI - PR': (232, 2.16667, 1),
#   'SBFL - SC': (184, 7.0, 4),
#   'SBFZ - CE': (249, 8.5, 3),
#   'SBGL - RJ': (106, 5.81667, 4),
#   'SBGO - GO': (169, 120.033, 87),
#   'SBGR - SP': (113, 116.833, 91),
#   'SBGV - MG': (59, 40.1833, 46),
#   'SBIL - BA': (144, 1.35, 1),
#   'SBIP - MG': (53, 88.05, 114),
#   'SBIZ - MA': (403, 63.8833, 26),
#   'SBJE - CE': (301, 49.85, 18),
#   'SBJP - PB': (297, 82.3167, 32),
#   'SBKP - SP': (107, 327.267, 262),
#   'SBLE - BA': (263, 21.5833, 9),
#   'SBMA - PA': (383, 64.35, 25),
#   'SBMK - MG': (104, 132.333, 109),
#   'SBMO - AL': (174, 22.2333, 10),
#   'SBNF - SC': (248, 26.0333, 15),
#   'SBPA - RS': (246, 9.26667, 4),
#   'SBPS - BA': (106, 28.7667, 22),
#   'SBRF - PE': (212, 4.71667, 2),
#   'SBRJ - RJ': (101, 124.983, 111),
#   'SBRP - SP': (148, 35.6833, 25),
#   'SBSG - RN': (243, 38.9667, 14),
#   'SBSL - MA': (265, 75.3667, 28),
#   'SBSN - PA': (480, 35.7333, 11),
#   'SBSP - SP': (131, 241.833, 174),
#   'SBSR - SP': (185, 9.28333, 5),
#   'SBSV - BA': (146, 96.2, 56),
#   'SBTC - BA': (114, 7.03333, 5),
#   'SBTE - PI': (936, 3.9, 1),
#   'SBUL - MG': (135, 181.283, 115),
#   'SBUR - MG': (130, 40.95, 27),
#   'SBVC - BA': (179, 32.8167, 26),
#   'SBVT - ES': (124, 2.05, 2),
#   'SNBR - BA': (183, 61.5167, 26),
#   'SNGI - BA': (170, 32.1333, 17),
#   'SBPJ - TO': (249, 34.5, 18),
#   'SBCF - MG': (369, 3.9, 2)},
#  'SBVG - MG': {'SBCF - MG': (284, 16.3667, 12)},
#  'SBZM - MG': {'SBCF - MG': (160, 1.65, 1),
#   'SBKP - SP': (131, 70.4333, 44),
#   'SBSP - SP': (152, 8.06667, 6),
#   'SBGR - SP': (172, 32.0, 29)},
#  'SNPD - MG': {'SBCF - MG': (327, 13.9, 11)},
#  'SNTO - MG': {'SBCF - MG': (330, 18.4333, 11)},
#  'SNZR - MG': {'SBCF - MG': (722, 12.9833, 7)},
#  'SBCP - RJ': {'SBRJ - RJ': (258, 20.65, 17), 'SBKP - SP': (227, 34.8833, 19)},
#  'SBRJ - RJ': {'SBCP - RJ': (326, 20.5833, 17),
#   'SBJD - SP': (1004, 21.5667, 11),
#   'SBME - RJ': (309, 15.6333, 18),
#   'SBBR - DF': (156, 96.8833, 54),
#   'SBCF - MG': (99, 94.6167, 86),
#   'SBCT - PR': (116, 76.3, 56),
#   'SBCY - MT': (232, 63.0, 25),
#   'SBFL - SC': (135, 30.3333, 20),
#   'SBGO - GO': (145, 88.4, 52),
#   'SBGR - SP': (105, 3.6, 3),
#   'SBIL - BA': (207, 43.6167, 26),
#   'SBKP - SP': (112, 1.33333, 1),
#   'SBMK - MG': (2364, 1.85, 1),
#   'SBMO - AL': (299, 65.6833, 26),
#   'SBNF - SC': (162, 103.0, 70),
#   'SBPA - RS': (181, 143.0, 72),
#   'SBPS - BA': (162, 26.4167, 17),
#   'SBRF - PE': (274, 329.517, 120),
#   'SBRP - SP': (176, 49.1833, 28),
#   'SBSP - SP': (88, 1.23333, 1),
#   'SBSV - BA': (229, 289.45, 141),
#   'SBVT - ES': (112, 6.08333, 6),
#   'SBCX - RS': (235, 24.6667, 13),
#   'SBFI - PR': (230, 7.9, 4),
#   'SBRJ - RJ': (280, 6.0, 3)},
#  'SBCT - PR': {'SBJD - SP': (454, 11.0333, 7),
#   'SSGY - PR': (1986, 30.1667, 13),
#   'SSUM - PR': (816, 21.5, 10),
#   'SSUV - PR': (1720, 12.2333, 12),
#   'SSVL - PR': (3512, 7.58333, 7),
#   'SBCA - PR': (130, 73.6167, 53),
#   'SBCF - MG': (119, 49.4167, 32),
#   'SBCG - MS': (174, 4.33333, 3),
#   'SBCY - MT': (224, 8.76667, 4),
#   'SBFI - PR': (154, 22.75, 20),
#   'SBFL - SC': (81, 28.8333, 30),
#   'SBGL - RJ': (179, 5.63333, 3),
#   'SBGR - SP': (94, 104.1, 90),
#   'SBKP - SP': (80, 213.967, 205),
#   'SBLO - PR': (122, 72.0333, 62),
#   'SBMG - PR': (125, 91.7667, 71),
#   'SBPA - RS': (102, 27.0833, 23),
#   'SBPO - PR': (129, 32.05, 27),
#   'SBPS - BA': (284, 8.98333, 4),
#   'SBRJ - RJ': (124, 78.5167, 56),
#   'SBSG - RN': (365, 14.7333, 4),
#   'SBSP - SP': (115, 193.767, 184),
#   'SBBR - DF': (170, 99.3167, 51),
#   'SBMO - AL': (299, 38.55, 12),
#   'SBSV - BA': (255, 8.1, 3),
#   'SBCT - PR': (204, 1.93333, 1),
#   'SBRB - AC': (1196, 4.08333, 1),
#   'SBMH - PR': (330, 1.03333, 1)},
#  'SBJD - SP': {'SBCT - PR': (628, 17, 7),
#   'SBJR - RJ': (1205, 5.26667, 3),
#   'SBRJ - RJ': (776, 17.1667, 10),
#   'SBSP - SP': (5566, 7, 5)},
#  'SSGY - PR': {'SBCT - PR': (1352, 27.15, 13)},
#  'SSUM - PR': {'SBCT - PR': (773, 21.4167, 12)},
#  'SSUV - PR': {'SBCT - PR': (2083, 11.65, 12)},
#  'SSVL - PR': {'SBCT - PR': (1079, 11.5833, 12)},
#  'SBJI - RO': {'SBCY - MT': (189, 1.38333, 1), 'SBPV - RO': (989, 1.41667, 1)},
#  'SSOU - MT': {'SWJN - MT': (199, 3.08333, 4)},
#  'SWHP - MT': {'SBCY - MT': (2015, 16.2667, 8)},
#  'SBEG - AM': {'SBMY - AM': (418, 14.9667, 10),
#   'SBSN - PA': (146, 29.25, 23),
#   'SBTF - AM': (189, 16.7, 14),
#   'SWBC - AM': (471, 12.25, 7),
#   'SWBR - AM': (635, 6.93333, 8),
#   'SWKO - AM': (479, 16.1833, 10),
#   'SWLB - AM': (1095, 8.56667, 3),
#   'SWMW - AM': (677, 12.2333, 10),
#   'SWYN - AM': (514, 22.2667, 11),
#   'SBBE - PA': (195, 37.05, 17),
#   'SBBV - RR': (144, 35.6, 28),
#   'SBIH - PA': (120, 18.7833, 13),
#   'SBKP - SP': (835, 571.8, 152),
#   'SBPV - RO': (137, 66.7833, 48),
#   'SBRF - PE': (284, 117.217, 30),
#   'SBTB - PA': (185, 12.8167, 10),
#   'SBTT - AM': (270, 54.15, 30),
#   'SBUA - AM': (188, 4.68333, 3),
#   'SWEI - AM': (312, 26.1167, 9),
#   'SWPI - AM': (139, 12.9833, 14),
#   'SBMQ - AP': (416, 2.88333, 1),
#   'SBBR - DF': (258, 158.333, 53),
#   'SBEG - AM': (121, 1.43333, 2),
#   'SBFZ - CE': (325, 6.71667, 2),
#   'SBGL - RJ': (354, 32.1, 8),
#   'SBGR - SP': (137, 3.91667, 1),
#   'SBRB - AC': (181, 18.4, 10),
#   'SBUY - AM': (179, 79.2, 47),
#   'SWCA - AM': (218, 22.7, 11),
#   'SBCF - MG': (47, 3.91667, 1)},
#  'SBMY - AM': {'SBEG - AM': (328, 14.1, 9)},
#  'SBTF - AM': {'SWTP - AM': (1150, 20, 9),
#   'SBEG - AM': (229, 29.6833, 25),
#   'SBUY - AM': (70, 0.666667, 1)},
#  'SWBC - AM': {'SBEG - AM': (652, 10.9667, 7)},
#  'SWBR - AM': {'SBEG - AM': (457, 9.43333, 10)},
#  'SWKO - AM': {'SBEG - AM': (723, 22.65, 14)},
#  'SWLB - AM': {'SBPV - RO': (1289, 2.6, 3), 'SWKO - AM': (1617, 3.21667, 2)},
#  'SWMW - AM': {'SBEG - AM': (726, 12.1333, 10)},
#  'SWYN - AM': {'SBEG - AM': (415, 18.4833, 9)},
#  'SBJE - CE': {'SBFZ - CE': (260, 10.75, 13),
#   'SBPB - PI': (628, 18.95, 24),
#   'SBCF - MG': (195, 22.4833, 8),
#   'SBGL - RJ': (55098, 3.73333, 1),
#   'SBKP - SP': (215, 17.8833, 5),
#   'SBGR - SP': (288, 10.7167, 3),
#   'SBSP - SP': (354, 29.1333, 8),
#   'SBTE - PI': (1447, 1.7, 1)},
#  'SBMS - RN': {'SBFZ - CE': (3008, 5, 3),
#   'SBSG - RN': (432, 3.63333, 3),
#   'SBRF - PE': (113, 37.4167, 29)},
#  'SNIG - CE': {'SBFZ - CE': (633, 5.23333, 4)},
#  'SNOB - CE': {'SBFZ - CE': (740, 10.4333, 10)},
#  'SNWS - CE': {'SBFZ - CE': (559, 7.61667, 6)},
#  'SWBE - CE': {'SBFZ - CE': (537, 7.46667, 6)},
#  'SBIH - PA': {'SBTB - PA': (1106, 7.01667, 6),
#   'SNRJ - PA': (872, 4.3, 4),
#   'SBEG - AM': (106, 17.9167, 13),
#   'SWPI - AM': (6349, 1.38333, 2)},
#  'SBTB - PA': {'SNOX - PA': (413, 5.48333, 11),
#   'SBEG - AM': (168, 11.8333, 9)},
#  'SBJR - RJ': {'SBJD - SP': (2496, 3.41667, 2),
#   'SBSP - SP': (600, 284.2, 167)},
#  'SBSP - SP': {'SBJD - SP': (2910, 7, 5),
#   'SBJR - RJ': (529, 262.383, 169),
#   'SBCF - MG': (118, 223.167, 174),
#   'SBGL - RJ': (163, 15.7833, 11),
#   'SBMO - AL': (264, 56.3333, 19),
#   'SBPS - BA': (181, 169.533, 87),
#   'SBRF - PE': (264, 41.1, 13),
#   'SBRJ - RJ': (105, 546.55, 509),
#   'SBTC - BA': (160, 2.01667, 1),
#   'SBGR - SP': (118, 1.31667, 1),
#   'SBBR - DF': (133, 1.61667, 1),
#   'SBCT - PR': (97, 265.517, 249),
#   'SBPA - RS': (159, 50.3, 30),
#   'SBAR - SE': (269, 72.9, 27),
#   'SBCG - MS': (169, 196.783, 110),
#   'SBCN - GO': (157, 13.5833, 9),
#   'SBCY - MT': (240, 13.5333, 6),
#   'SBDB - MS': (174, 13.9167, 7),
#   'SBFI - PR': (150, 62.3833, 36),
#   'SBFL - SC': (101, 183.317, 148),
#   'SBFZ - CE': (323, 188.417, 54),
#   'SBGO - GO': (156, 271.567, 163),
#   'SBIL - BA': (130, 2.03333, 1),
#   'SBJE - CE': (405, 27.3, 8),
#   'SBNF - SC': (93, 188.183, 164),
#   'SBSG - RN': (324, 91.25, 27),
#   'SBSV - BA': (207, 2.33333, 1),
#   'SBVT - ES': (154, 11.4833, 8),
#   'SBDN - SP': (120, 27.8667, 22),
#   'SBSP - SP': (284, 2, 1),
#   'SBCX - RS': (143, 10.2167, 6),
#   'SBMG - PR': (147, 7.73333, 6),
#   'SBUL - MG': (126, 8.78333, 6),
#   'SBZM - MG': (120, 7.61667, 6),
#   'SBAU - SP': (137, 57.8167, 37),
#   'SBIP - MG': (182, 46.5, 24),
#   'SBRP - SP': (151, 101.667, 82),
#   'SBSM - RS': (229, 11.0, 4),
#   'SBSR - SP': (118, 109.7, 76),
#   'SBUG - RS': (337, 32.4, 10),
#   'SBUR - MG': (142, 26.4667, 17),
#   'SBJA - SC': (193, 48.0667, 37),
#   'SBJV - SC': (137, 22.4333, 21),
#   'SBLO - PR': (108, 1.11667, 1)},
#  'SBPB - PI': {'SBJE - CE': (362, 2.65, 5),
#   'SSRS - MA': (527, 14.5833, 21),
#   'SBKP - SP': (271, 27.5667, 8),
#   'SBCF - MG': (726, 24.6667, 9),
#   'SBTE - PI': (359, 5.88333, 8)},
#  'SNYA - PA': {'SBBE - PA': (2478, 18.15, 9)},
#  'SBME - RJ': {'SBRJ - RJ': (271, 18.4833, 18),
#   'SBKP - SP': (160, 45.9167, 26)},
#  'SBSG - RN': {'SBMS - RN': (1615, 6, 3),
#   'SBRF - PE': (65, 21.9667, 30),
#   'SBCF - MG': (243, 13.55, 5),
#   'SBCT - PR': (359, 7.75, 2),
#   'SBCY - MT': (317, 10.5833, 3),
#   'SBFI - PR': (406, 8.55, 2),
#   'SBFN - PE': (166, 9, 4),
#   'SBGO - GO': (299, 32.3667, 11),
#   'SBGR - SP': (310, 279.667, 80),
#   'SBKP - SP': (256, 143.233, 42),
#   'SBRP - SP': (718, 23, 4),
#   'SBSR - SP': (557, 22, 4),
#   'SBUL - MG': (498, 20, 4),
#   'SBBR - DF': (247, 2.56667, 1),
#   'SBGL - RJ': (294, 73.3333, 23),
#   'SBJP - PB': (19407, 6, 4),
#   'SBPA - RS': (413, 17.9333, 4),
#   'SBSP - SP': (326, 37.45, 11),
#   'SBSV - BA': (137, 8.15, 5),
#   'SBFZ - CE': (113, 41.1333, 41)},
#  'SSCN - RS': {'SBPA - RS': (376, 6.58333, 11)},
#  'SSLT - RS': {'SBPA - RS': (1805, 7.43333, 4)},
#  'SSSC - RS': {'SBPA - RS': (829, 7.9, 12)},
#  'SSZR - RS': {'SBPA - RS': (1222, 10.7667, 7)},
#  'SSRS - MA': {'SBPB - PI': (2508, 16.3167, 24), 'SBSL - MA': (2862, 28, 21)},
#  'SBPV - RO': {'SBJI - RO': (2285, 3.28333, 2),
#   'SWLB - AM': (1550, 4, 3),
#   'SBCY - MT': (181, 67.3167, 35),
#   'SBEG - AM': (132, 1.41667, 1),
#   'SBKP - SP': (304, 98.1333, 29),
#   'SBRF - PE': (469, 17.45, 4),
#   'SBBE - PA': (1069, 2.71667, 1),
#   'SBBR - DF': (258, 5.65, 2),
#   'SBGR - SP': (360, 47.5167, 13),
#   'SBRB - AC': (132, 2.06667, 2)},
#  'SBRF - PE': {'SBSG - RN': (80, 25.3667, 28),
#   'SNAB - PE': (3168, 32, 9),
#   'SNGN - PE': (756, 5.41667, 6),
#   'SNHS - PE': (1021, 19.05, 12),
#   'SNRU - PE': (1114, 8.28333, 12),
#   'SNTS - PB': (483, 29.95, 24),
#   'SBAE - SP': (284, 12.65, 4),
#   'SBAR - SE': (135, 108.033, 94),
#   'SBBE - PA': (263, 150.833, 59),
#   'SBBR - DF': (220, 73.75, 28),
#   'SBCF - MG': (241, 2.55, 1),
#   'SBCY - MT': (356, 44.2667, 13),
#   'SBDN - SP': (317, 13.75, 4),
#   'SBEG - AM': (298, 97.6667, 25),
#   'SBFE - BA': (166, 34.65, 20),
#   'SBFI - PR': (261, 4.85, 1),
#   'SBFL - SC': (360, 45.15, 12),
#   'SBFN - PE': (128, 153.333, 92),
#   'SBFZ - CE': (119, 1.28333, 1),
#   'SBGO - GO': (236, 78.9, 29),
#   'SBGR - SP': (243, 562.067, 177),
#   'SBJP - PB': (56, 39.9333, 59),
#   'SBJU - CE': (180, 25.1667, 21),
#   'SBKG - PB': (73, 40.1667, 52),
#   'SBKP - SP': (250, 376.4, 119),
#   'SBMO - AL': (67, 0.933333, 1),
#   'SBMQ - AP': (350, 11.65, 4),
#   'SBMS - RN': (123, 39.3333, 29),
#   'SBPA - RS': (367, 8.43333, 2),
#   'SBPJ - TO': (209, 32.0667, 14),
#   'SBPL - PE': (151, 38.4, 28),
#   'SBPV - RO': (377, 16.9667, 4),
#   'SBRJ - RJ': (258, 306.267, 105),
#   'SBRP - SP': (422, 15.7167, 5),
#   'SBSL - MA': (204, 86.4834, 44),
#   'SBSP - SP': (257, 3.15, 1),
#   'SBSR - SP': (540, 22, 4),
#   'SBSV - BA': (106, 79.5667, 57),
#   'SBTE - PI': (202, 97.75, 59),
#   'SBUF - BA': (119, 15.0667, 12),
#   'SBUL - MG': (492, 19, 4),
#   'SBVT - ES': (378, 62.9833, 27),
#   'SWKQ - PI': (215, 8.68333, 4),
#   'SBGL - RJ': (255, 159.25, 54),
#   'SBRF - PE': (276, 3.33333, 1)},
#  'SNAB - PE': {'SBRF - PE': (3594, 30, 8)},
#  'SNGN - PE': {'SBRF - PE': (1617, 9.98333, 11)},
#  'SNHS - PE': {'SBRF - PE': (1018, 9.51667, 6)},
#  'SNRU - PE': {'SBRF - PE': (676, 5.3, 7)},
#  'SNTS - PB': {'SBRF - PE': (641, 29.2167, 23)},
#  'SBSL - MA': {'SSRS - MA': (352, 22.9167, 23),
#   'SBBE - PA': (118, 47.0833, 42),
#   'SBCF - MG': (269, 82.8, 29),
#   'SBIZ - MA': (130, 23.5333, 21),
#   'SBKP - SP': (280, 83.55, 25),
#   'SBRF - PE': (217, 84.2, 44),
#   'SBTE - PI': (226, 4.0, 5),
#   'SBPL - PE': (27027, 1.91667, 1),
#   'SBBR - DF': (222, 42.1833, 17),
#   'SBGR - SP': (277, 6.95, 2),
#   'SBSV - BA': (178, 25.8667, 12),
#   'SBCJ - PA': (231, 2.86667, 2),
#   'SBFZ - CE': (123, 2.55, 2),
#   'SBMO - AL': (288, 2.33333, 1)},
#  'SNOX - PA': {'SNMA - PA': (4852, 16, 11)},
#  'SWTP - AM': {'SBEG - AM': (1304, 26.9833, 10)},
#  'SNMZ - PA': {'SBBE - PA': (976, 20.25, 11)},
#  'SNTI - PA': {'SNMA - PA': (922, 3.21667, 4)},
#  'SNMA - PA': {'SBSN - PA': (8673, 6.31667, 12)},
#  'SWJN - MT': {'SBCY - MT': (17862, 31, 9)},
#  'SBTU - PA': {'SBBE - PA': (569, 10.5833, 8)},
#  'SNRJ - PA': {},
#  'SBGR - SP': {'SBBR - DF': (197, 254.2, 146),
#   'SBCF - MG': (108, 113.617, 91),
#   'SBCT - PR': (68, 4.36667, 2),
#   'SBCY - MT': (208, 278.75, 129),
#   'SBGL - RJ': (64, 28.05, 26),
#   'SBPA - RS': (164, 206.7, 118),
#   'SBRF - PE': (248, 530.8, 178),
#   'SBRJ - RJ': (102, 162.233, 157),
#   'SBSV - BA': (197, 279.75, 117),
#   'SBVT - ES': (150, 95.5667, 62),
#   'SBTC - BA': (362, 1.95, 1),
#   'SBAR - SE': (233, 198.133, 76),
#   'SBBE - PA': (324, 10.8, 3),
#   'SBCA - PR': (161, 40.5333, 28),
#   'SBCG - MS': (155, 54.7333, 30),
#   'SBCH - SC': (141, 83.1833, 53),
#   'SBCX - RS': (148, 1.48333, 1),
#   'SBDN - SP': (136, 33.3167, 25),
#   'SBEG - AM': (391, 85.5833, 22),
#   'SBFI - PR': (104, 3.68333, 2),
#   'SBFL - SC': (93, 2.55, 2),
#   'SBFZ - CE': (250, 6.55, 2),
#   'SBGO - GO': (110, 2, 1),
#   'SBGR - SP': (349, 9.05, 4),
#   'SBIL - BA': (199, 57.55, 29),
#   'SBJE - CE': (295, 3.51667, 1),
#   'SBJP - PB': (262, 18.8833, 6),
#   'SBJU - CE': (262, 166.883, 57),
#   'SBJV - SC': (100, 29.6, 26),
#   'SBKG - PB': (409, 83.9833, 27),
#   'SBLO - PR': (99, 1.18333, 1),
#   'SBMG - PR': (120, 102.867, 74),
#   'SBMK - MG': (174, 1.51667, 1),
#   'SBMO - AL': (240, 23.8167, 8),
#   'SBNF - SC': (90, 74.0666, 64),
#   'SBNM - RS': (249, 23.6833, 12),
#   'SBPF - RS': (189, 39.2, 24),
#   'SBPJ - TO': (192, 4.88333, 2),
#   'SBPK - RS': (263, 33.3, 16),
#   'SBPL - PE': (232, 43.1167, 17),
#   'SBPS - BA': (147, 7.1, 4),
#   'SBPV - RO': (360, 49.5333, 13),
#   'SBRB - AC': (363, 3.7, 1),
#   'SBSG - RN': (297, 273.717, 82),
#   'SBSI - MT': (282, 78.6, 31),
#   'SBSL - MA': (348, 3.26667, 1),
#   'SBTE - PI': (315, 2.95, 1),
#   'SBUL - MG': (103, 1.2, 1),
#   'SBVC - BA': (169, 126.35, 64),
#   'SBAU - SP': (290, 13.45, 8),
#   'SBRP - SP': (108, 2.81667, 3),
#   'SBSR - SP': (145, 38.55, 37),
#   'SBIP - MG': (153, 1.85, 1),
#   'SBUR - MG': (138, 1.43333, 1),
#   'SBIZ - MA': (409, 84.1667, 29),
#   'SBZM - MG': (182, 31.1667, 30),
#   'SBSP - SP': (72, 1.53333, 1)},
#  'SBAE - SP': {'SBKP - SP': (68, 26.1333, 29),
#   'SBMO - AL': (298, 11.4667, 4),
#   'SBPS - BA': (586, 12, 4),
#   'SBRF - PE': (346, 12.4167, 4)},
#  'SBKP - SP': {'SBAE - SP': (69, 27.2333, 29),
#   'SBAR - SE': (195, 79.6333, 31),
#   'SBAU - SP': (155, 64.1833, 46),
#   'SBBE - PA': (411, 293.767, 87),
#   'SBBR - DF': (134, 236.933, 146),
#   'SBBV - RR': (234, 21.9667, 5),
#   'SBCA - PR': (125, 55.65, 40),
#   'SBCB - RJ': (5341, 1.3, 1),
#   'SBCF - MG': (111, 318.483, 265),
#   'SBCG - MS': (115, 184.15, 115),
#   'SBCH - SC': (127, 119.7, 78),
#   'SBCN - GO': (193, 9.91667, 8),
#   'SBCP - RJ': (196, 29.2333, 16),
#   'SBCR - MS': (378, 53.65, 26),
#   'SBCT - PR': (73, 203.667, 206),
#   'SBCX - RS': (187, 33.8333, 22),
#   'SBCY - MT': (182, 264.983, 124),
#   'SBDB - MS': (107, 7.05, 4),
#   'SBDN - SP': (142, 105.283, 70),
#   'SBEG - AM': (632, 488.633, 130),
#   'SBFI - PR': (112, 124.65, 78),
#   'SBFL - SC': (90, 7.71667, 6),
#   'SBFZ - CE': (308, 270.117, 81),
#   'SBGL - RJ': (85, 166.05, 152),
#   'SBGO - GO': (114, 1.43333, 1),
#   'SBIL - BA': (156, 59.0167, 28),
#   'SBJA - SC': (185, 56.1667, 30),
#   'SBJE - CE': (252, 30.4833, 9),
#   'SBJP - PB': (291, 109.0, 34),
#   'SBJU - CE': (237, 92.0, 31),
#   'SBJV - SC': (100, 150.45, 116),
#   'SBLO - PR': (108, 121.05, 88),
#   'SBMA - PA': (3961, 2.76667, 1),
#   'SBME - RJ': (159, 44.2833, 26),
#   'SBMG - PR': (118, 140.467, 89),
#   'SBML - SP': (121, 25.8, 23),
#   'SBMO - AL': (239, 97.6167, 35),
#   'SBMQ - AP': (257, 32.3667, 9),
#   'SBNF - SC': (92, 123.183, 108),
#   'SBPA - RS': (151, 9.8, 6),
#   'SBPB - PI': (281, 26.7833, 8),
#   'SBPF - RS': (157, 6.7, 3),
#   'SBPG - PR': (109, 14.65, 11),
#   'SBPJ - TO': (194, 51.2, 23),
#   'SBPL - PE': (294, 69.7, 27),
#   'SBPP - MS': (122, 46.0833, 27),
#   'SBPS - BA': (143, 66.35, 35),
#   'SBPV - RO': (302, 101.55, 30),
#   'SBRD - MT': (222, 27.4, 14),
#   'SBRF - PE': (255, 372.867, 124),
#   'SBRJ - RJ': (117, 2.1, 2),
#   'SBRP - SP': (74, 136.2, 145),
#   'SBSG - RN': (262, 115.783, 35),
#   'SBSI - MT': (204, 2.26667, 1),
#   'SBSL - MA': (351, 87.0667, 27),
#   'SBSR - SP': (105, 168.183, 139),
#   'SBSV - BA': (199, 57.85, 24),
#   'SBTC - BA': (319, 10.1167, 5),
#   'SBTD - PR': (205, 41.5667, 20),
#   'SBTE - PI': (339, 146.617, 50),
#   'SBTG - MS': (150, 34.0, 21),
#   'SBUL - MG': (133, 159.067, 105),
#   'SBUR - MG': (116, 35.65, 26),
#   'SBVT - ES': (198, 222.233, 143),
#   'SBZM - MG': (122, 87.9667, 58),
#   'SNCP - SC': (194, 44.9333, 25),
#   'SSGG - PR': (115, 17.4, 11),
#   'SWLC - GO': (176, 61.2, 30)},
#  'SBMO - AL': {'SBAE - SP': (300, 11.5333, 4),
#   'SBAU - SP': (437, 12.1833, 4),
#   'SBCA - PR': (438, 14.35, 4),
#   'SBCF - MG': (188, 22.4833, 10),
#   'SBCY - MT': (274, 3.21667, 1),
#   'SBDN - SP': (433, 19, 4),
#   'SBFI - PR': (380, 7.56667, 2),
#   'SBGO - GO': (441, 18, 4),
#   'SBKP - SP': (247, 135.25, 46),
#   'SBLO - PR': (300, 16.75, 5),
#   'SBPA - RS': (404, 20.1167, 5),
#   'SBRF - PE': (55, 0.85, 1),
#   'SBRJ - RJ': (263, 69.0167, 26),
#   'SBRP - SP': (506, 22, 4),
#   'SBSP - SP': (230, 58.9833, 19),
#   'SBSR - SP': (288, 22.5, 8),
#   'SBUL - MG': (274, 5.41667, 2),
#   'SBUR - MG': (264, 10.3, 4),
#   'SBBR - DF': (211, 75.9167, 31),
#   'SBCT - PR': (315, 43.75, 13),
#   'SBGL - RJ': (192, 2.58333, 1),
#   'SBGR - SP': (218, 6.51667, 2),
#   'SBSV - BA': (83, 22.5833, 19),
#   'SBFZ - CE': (115, 2.86667, 2)},
#  'SBPS - BA': {'SBAE - SP': (510, 12, 4),
#   'SBAU - SP': (483, 13, 4),
#   'SBCA - PR': (729, 11.0667, 4),
#   'SBCF - MG': (110, 28.8667, 22),
#   'SBCT - PR': (207, 11.8, 5),
#   'SBCY - MT': (366, 2.7, 1),
#   'SBDN - SP': (546, 16, 4),
#   'SBFI - PR': (361, 11.5833, 4),
#   'SBGO - GO': (199, 27.9333, 16),
#   'SBJV - SC': (557, 9.41667, 4),
#   'SBKP - SP': (156, 6.08333, 3),
#   'SBLO - PR': (263, 11.7, 5),
#   'SBMG - PR': (709, 9.86667, 4),
#   'SBMK - MG': (118, 3.03333, 2),
#   'SBPA - RS': (250, 14.7667, 5),
#   'SBRJ - RJ': (160, 27.3333, 17),
#   'SBRP - SP': (315, 14, 4),
#   'SBSP - SP': (187, 173.233, 84),
#   'SBSR - SP': (164, 5.85, 3),
#   'SBSV - BA': (89, 15.6667, 15),
#   'SBUL - MG': (159, 4.96667, 3),
#   'SBUR - MG': (302, 9.66667, 5),
#   'SBVT - ES': (800, 1.0, 1),
#   'SBBR - DF': (144, 8.93333, 5),
#   'SBCG - MS': (232, 2.78333, 1),
#   'SBGL - RJ': (166, 51.0, 29),
#   'SBGR - SP': (154, 7.5, 4)},
#  'SBAR - SE': {'SBCF - MG': (199, 37.3667, 19),
#   'SBKP - SP': (197, 71.4667, 27),
#   'SBRF - PE': (118, 97.05, 93),
#   'SBGL - RJ': (228, 23.1167, 10),
#   'SBGR - SP': (221, 15.95, 6),
#   'SBSP - SP': (261, 62.5667, 22),
#   'SBSV - BA': (71, 1.01667, 1),
#   'SBBR - DF': (215, 2.08333, 1)},
#  'SBAT - MT': {'SBCY - MT': (182, 27.5833, 22)},
#  'SBAU - SP': {'SBKP - SP': (124, 64.8667, 52),
#   'SBMO - AL': (496, 8.86667, 3),
#   'SBPS - BA': (681, 12, 4),
#   'SBAE - SP': (248, 2.03333, 1),
#   'SBGR - SP': (167, 11.9, 8),
#   'SBSP - SP': (140, 56.0667, 38)},
#  'SBBV - RR': {'SBBE - PA': (279, 38.3333, 17),
#   'SBEG - AM': (108, 37.6, 30),
#   'SBKP - SP': (372, 27, 4),
#   'SBBR - DF': (310, 88.5833, 24),
#   'SBCT - PR': (525, 33.4333, 7),
#   'SBGR - SP': (554, 8, 1),
#   'SBCG - MS': (541, 7.91667, 2)},
#  'SBCJ - PA': {'SBBE - PA': (221, 26.05, 24),
#   'SBCF - MG': (321, 69.2167, 29),
#   'SBSL - MA': (194, 2.75, 2)},
#  'SBGL - RJ': {'SBBR - DF': (137, 10.8833, 6),
#   'SBCF - MG': (160, 3.96667, 4),
#   'SBCT - PR': (180, 2, 1),
#   'SBCY - MT': (248, 2.63333, 1),
#   'SBKP - SP': (85, 199.6, 156),
#   'SBPA - RS': (259, 3, 1),
#   'SBRF - PE': (237, 41.65, 15),
#   'SBSP - SP': (169, 1.31667, 1),
#   'SBVT - ES': (398, 2, 1),
#   'SBFL - SC': (151, 1.4, 1),
#   'SBGO - GO': (158, 35.4833, 20),
#   'SBGR - SP': (87, 30.3333, 27),
#   'SBAR - SE': (235, 55.8333, 24),
#   'SBBE - PA': (338, 48.8667, 14),
#   'SBCG - MS': (211, 13.3333, 6),
#   'SBEG - AM': (370, 52.6, 13),
#   'SBFI - PR': (199, 56.5333, 26),
#   'SBFZ - CE': (190, 6.43333, 2),
#   'SBIL - BA': (207, 4.6, 2),
#   'SBJP - PB': (257, 144.75, 49),
#   'SBMO - AL': (218, 131.267, 51),
#   'SBNF - SC': (144, 3.46667, 2),
#   'SBPS - BA': (147, 44.0833, 28),
#   'SBSG - RN': (278, 149.733, 49),
#   'SBSV - BA': (147, 2.03333, 1),
#   'SBGL - RJ': (202, 2.28333, 1),
#   'SBUL - MG': (204, 5.91667, 4),
#   'SBRP - SP': (181, 1.75, 1)},
#  'SBHT - PA': {'SBBE - PA': (118, 27.3667, 28), 'SBSL - MA': (324, 1.9, 1)},
#  'SBMA - PA': {'SBBE - PA': (132, 54.7667, 53),
#   'SBCF - MG': (362, 64.45, 25),
#   'SBKP - SP': (650, 3.08333, 1),
#   'SBBR - DF': (203, 47.75, 24)},
#  'SBMQ - AP': {'SBBE - PA': (78, 54.2167, 56),
#   'SBKP - SP': (67, 3.83333, 1),
#   'SBRF - PE': (672, 12.0667, 4),
#   'SBBR - DF': (247, 50.0167, 18),
#   'SBMQ - AP': (3995, 1.11667, 2),
#   'SBOI - AP': (347, 28.8667, 24)},
#  'SBBR - DF': {'SBCF - MG': (115, 64.15, 48),
#   'SBCY - MT': (156, 6.63333, 4),
#   'SBGL - RJ': (155, 62.0, 34),
#   'SBGR - SP': (142, 19.0167, 11),
#   'SBKP - SP': (155, 326.767, 195),
#   'SBRF - PE': (216, 147.083, 57),
#   'SBRJ - RJ': (183, 228.1, 129),
#   'SBSV - BA': (155, 163.067, 86),
#   'SBSP - SP': (146, 2.01667, 1),
#   'SBBE - PA': (243, 131.167, 52),
#   'SBBV - RR': (316, 10.65, 3),
#   'SBCT - PR': (167, 111.05, 58),
#   'SBEG - AM': (261, 153.033, 52),
#   'SBFL - SC': (180, 30.95, 14),
#   'SBFZ - CE': (230, 125.75, 48),
#   'SBGO - GO': (52, 38.6, 50),
#   'SBIL - BA': (201, 5.5, 3),
#   'SBJP - PB': (218, 73.25, 27),
#   'SBMA - PA': (185, 3.86667, 2),
#   'SBMO - AL': (195, 70.7667, 30),
#   'SBMQ - AP': (278, 45.6833, 17),
#   'SBPA - RS': (243, 142.517, 55),
#   'SBPJ - TO': (122, 51.1333, 38),
#   'SBPS - BA': (154, 21.15, 12),
#   'SBPV - RO': (267, 65.5333, 23),
#   'SBRB - AC': (333, 3.26667, 1),
#   'SBSG - RN': (223, 82.85, 30),
#   'SBSL - MA': (218, 62.7167, 27),
#   'SBTE - PI': (218, 25.8833, 12),
#   'SBFI - PR': (157, 2.35, 1),
#   'SBLE - BA': (726, 2.45, 1),
#   'SBUL - MG': (90, 33.85, 28),
#   'SNBR - BA': (125, 1.6, 1),
#   'SBMK - MG': (253, 23, 11),
#   'SBRP - SP': (140, 11.7667, 7),
#   'SBSR - SP': (139, 29.5167, 18),
#   'SWGN - TO': (218, 28.7667, 11),
#   'SBAR - SE': (253, 4.18333, 2),
#   'SBCG - MS': (177, 6.26667, 4),
#   'SBIZ - MA': (233, 3.63333, 2),
#   'SBNF - SC': (265, 4.08333, 2),
#   'SBSI - MT': (194, 46.6833, 28),
#   'SBSN - PA': (351, 71.95, 29),
#   'SBVT - ES': (246, 74.3, 43),
#   'SBJV - SC': (355, 2.73333, 1)},
#  'SBCA - PR': {'SBCT - PR': (141, 68.6167, 52),
#   'SBKP - SP': (123, 56.7667, 40),
#   'SBMO - AL': (503, 13.9833, 4),
#   'SBPS - BA': (557, 8.31667, 3),
#   'SBRP - SP': (32290, 2.23333, 1),
#   'SBGR - SP': (168, 39.6667, 25)},
#  'SBRP - SP': {'SBCF - MG': (144, 1.03333, 1),
#   'SBFZ - CE': (293, 12.1, 4),
#   'SBJP - PB': (335, 9.01667, 3),
#   'SBKP - SP': (71, 131.25, 143),
#   'SBMO - AL': (463, 21, 4),
#   'SBPS - BA': (299, 14, 4),
#   'SBRF - PE': (273, 14.4333, 5),
#   'SBSG - RN': (637, 9.58333, 3),
#   'SBSV - BA': (185, 6.48333, 3),
#   'SBMK - MG': (340, 2.9, 1),
#   'SBSR - SP': (214, 0.616667, 1),
#   'SBBR - DF': (149, 12.1667, 7),
#   'SBGL - RJ': (260, 1.91667, 1),
#   'SBGO - GO': (223, 31.35, 21),
#   'SBGR - SP': (88, 1.16667, 1),
#   'SBRJ - RJ': (170, 40.1833, 26),
#   'SBRP - SP': (390, 3, 1),
#   'SBSP - SP': (131, 10.35, 11)},
#  'SBCB - RJ': {'SBCF - MG': (118, 39.3167, 29),
#   'SBKP - SP': (1114, 1.11667, 1)},
#  'SBCN - GO': {'SBCF - MG': (177, 3.41667, 3),
#   'SBKP - SP': (217, 11.0667, 8),
#   'SBGR - SP': (273, 2.63333, 1),
#   'SBSP - SP': (324, 20, 8)},
#  'SBFI - PR': {'SBCF - MG': (146, 1.96667, 1),
#   'SBCT - PR': (121, 2.2, 2),
#   'SBCY - MT': (248, 14.9833, 8),
#   'SBFL - SC': (113, 2.88333, 2),
#   'SBKP - SP': (112, 132.233, 87),
#   'SBMO - AL': (358, 7.41667, 2),
#   'SBNF - SC': (93, 5.06667, 4),
#   'SBPA - RS': (157, 49.2833, 28),
#   'SBPS - BA': (715, 13.4333, 5),
#   'SBRF - PE': (333, 12.05, 3),
#   'SBSG - RN': (386, 8.46667, 2),
#   'SBSV - BA': (307, 22.2333, 7),
#   'SBGL - RJ': (155, 94.5167, 50),
#   'SBGR - SP': (121, 4.81667, 3),
#   'SBRJ - RJ': (181, 7.7, 4),
#   'SBSP - SP': (148, 141.267, 86),
#   'SBBR - DF': (159, 2.0, 1)},
#  'SBFL - SC': {'SBCF - MG': (177, 8.86667, 5),
#   'SBCH - SC': (84, 28.2333, 27),
#   'SBCT - PR': (82, 30.0167, 30),
#   'SBCY - MT': (418, 21.5833, 9),
#   'SBFI - PR': (115, 2.8, 2),
#   'SBGO - GO': (425, 22.3333, 11),
#   'SBGR - SP': (117, 135.167, 94),
#   'SBKP - SP': (100, 4.81667, 4),
#   'SBNM - RS': (177, 13.4, 8),
#   'SBPA - RS': (91, 18.3167, 17),
#   'SBPF - RS': (104, 15.7833, 12),
#   'SBPK - RS': (170, 13.55, 8),
#   'SBRF - PE': (454, 42.75, 12),
#   'SBRJ - RJ': (131, 32.5667, 23),
#   'SBRP - SP': (4258, 1.93333, 1),
#   'SBSM - RS': (212, 20.8333, 12),
#   'SBUG - RS': (326, 28.2, 12),
#   'SBVT - ES': (2038, 2.43333, 1),
#   'SBBR - DF': (191, 54.9167, 25),
#   'SBCG - MS': (173, 11.0333, 6),
#   'SBGL - RJ': (195, 4.6, 3),
#   'SBSP - SP': (104, 269.8, 227),
#   'SBSV - BA': (280, 14.7833, 5)},
#  'SBGO - GO': {'SBCF - MG': (173, 111.533, 85),
#   'SBCY - MT': (201, 68.0, 50),
#   'SBFL - SC': (431, 26.1, 13),
#   'SBFZ - CE': (249, 8.18333, 3),
#   'SBGL - RJ': (141, 1.6, 1),
#   'SBJP - PB': (492, 11.55, 4),
#   'SBKP - SP': (158, 229.35, 157),
#   'SBMO - AL': (419, 17, 4),
#   'SBPJ - TO': (182, 5.38333, 4),
#   'SBPS - BA': (201, 5.7, 3),
#   'SBRF - PE': (276, 81.2667, 31),
#   'SBRJ - RJ': (170, 85.0833, 49),
#   'SBRP - SP': (189, 2.1, 1),
#   'SBSG - RN': (243, 8.35, 3),
#   'SBSV - BA': (167, 6.13333, 3),
#   'SBVT - ES': (396, 23.2667, 13),
#   'SBGR - SP': (140, 4.76667, 3),
#   'SBBR - DF': (54, 22.3, 31),
#   'SBSP - SP': (162, 259.5, 160)},
#  'SBGV - MG': {'SBCF - MG': (60, 44.4, 52)},
#  'SBIL - BA': {'SBCF - MG': (163, 1.28333, 1),
#   'SBKP - SP': (154, 59.4333, 28),
#   'SBRJ - RJ': (159, 44.9667, 25),
#   'SBSV - BA': (54, 0.75, 1),
#   'SBBR - DF': (204, 3.78333, 2),
#   'SBGL - RJ': (205, 5.51667, 3),
#   'SBGR - SP': (196, 61.6333, 29),
#   'SBSP - SP': (266, 4.46667, 2)},
#  'SBIP - MG': {'SBCF - MG': (49, 79.0667, 110),
#   'SBSP - SP': (208, 46.8833, 23),
#   'SBRP - SP': (210, 2.18333, 1),
#   'SNTF - BA': (314, 2.23333, 2)},
#  'SBIZ - MA': {'SBCF - MG': (422, 63.0833, 26),
#   'SBSL - MA': (164, 25.8667, 26),
#   'SBBR - DF': (276, 3.83333, 2),
#   'SBGR - SP': (354, 3.05, 1)},
#  'SBJP - PB': {'SBCF - MG': (226, 10.2, 4),
#   'SBGO - GO': (728, 17, 4),
#   'SBKP - SP': (297, 104.85, 32),
#   'SBRF - PE': (25, 0.583333, 1),
#   'SBRP - SP': (352, 11.9333, 4),
#   'SBSR - SP': (315, 13.0, 4),
#   'SBUL - MG': (603, 20, 4),
#   'SBBR - DF': (237, 80.3833, 30),
#   'SBGL - RJ': (274, 121.0, 39),
#   'SBGR - SP': (216, 6.35, 2),
#   'SBSG - RN': (8756, 5, 4),
#   'SBSV - BA': (118, 47.8, 30)},
#  'SBLE - BA': {'SBCF - MG': (212, 26.4, 12),
#   'SBSV - BA': (117, 1.9, 2),
#   'SNBR - BA': (249, 8.33333, 7)},
#  'SBMK - MG': {'SBCF - MG': (93, 114.817, 109),
#   'SBPS - BA': (142, 11.5667, 8),
#   'SBSV - BA': (144, 12, 4),
#   'SBGR - SP': (57, 1.35, 1),
#   'SBBR - DF': (183, 16.1667, 11),
#   'SNTF - BA': (434, 7.45, 6)},
#  'SBNF - SC': {'SBCF - MG': (278, 24.25, 15),
#   'SBCH - SC': (184, 16.1833, 11),
#   'SBCT - PR': (425, 1, 1),
#   'SBCY - MT': (230, 13.8667, 6),
#   'SBFI - PR': (100, 5.08333, 4),
#   'SBGL - RJ': (241, 7.03333, 5),
#   'SBKP - SP': (95, 125.65, 106),
#   'SBPA - RS': (134, 16.1667, 11),
#   'SBRJ - RJ': (145, 75.2167, 54),
#   'SBGR - SP': (107, 86.1833, 65),
#   'SBFL - SC': (2410, 2.13333, 1),
#   'SBSP - SP': (104, 161.067, 146),
#   'SBBR - DF': (324, 58.6, 29)},
#  'SBSR - SP': {'SBCF - MG': (137, 11.5833, 7),
#   'SBFZ - CE': (378, 12.7667, 4),
#   'SBGR - SP': (150, 4.13333, 4),
#   'SBJP - PB': (331, 12.1833, 4),
#   'SBKP - SP': (98, 150.75, 136),
#   'SBMO - AL': (284, 22.6333, 8),
#   'SBPS - BA': (355, 13, 4),
#   'SBRF - PE': (478, 21, 4),
#   'SBSG - RN': (548, 22, 4),
#   'SBSV - BA': (491, 9.11667, 4),
#   'SBBR - DF': (134, 1.7, 1),
#   'SBGO - GO': (202, 2.66667, 2),
#   'SBSP - SP': (119, 101.4, 75),
#   'SBRP - SP': (142, 1.61667, 1),
#   'SBSR - SP': (287, 2.96667, 1)},
#  'SBTC - BA': {'SBCF - MG': (118, 6.8, 5),
#   'SBKP - SP': (580, 8.0, 4),
#   'SBSP - SP': (171, 2.03333, 1),
#   'SBGR - SP': (261, 2.43333, 1)},
#  'SBTE - PI': {'SBBE - PA': (256, 24.5833, 18),
#   'SBFZ - CE': (130, 3.18333, 3),
#   'SBKP - SP': (298, 155.267, 50),
#   'SBRF - PE': (172, 89.8333, 56),
#   'SBBR - DF': (197, 26.35, 12),
#   'SBGR - SP': (291, 79.3, 25),
#   'SBPB - PI': (845, 6.93333, 8),
#   'SBSL - MA': (224, 4.1, 5)},
#  'SBUL - MG': {'SBCF - MG': (124, 184.15, 139),
#   'SBFZ - CE': (267, 14.1833, 5),
#   'SBJP - PB': (616, 20, 4),
#   'SBKP - SP': (129, 151.3, 104),
#   'SBMO - AL': (247, 7.9, 3),
#   'SBPS - BA': (293, 13, 4),
#   'SBRF - PE': (572, 19, 4),
#   'SBSG - RN': (568, 21, 4),
#   'SBSV - BA': (424, 12, 4),
#   'SBGR - SP': (115, 99.05, 70),
#   'SBGL - RJ': (130, 5.21667, 4),
#   'SBSP - SP': (161, 9.06667, 6),
#   'SBBR - DF': (92, 25.9333, 22)},
#  'SBUR - MG': {'SBCF - MG': (106, 37.75, 29),
#   'SBKP - SP': (136, 1.15, 1),
#   'SBMO - AL': (269, 9.9, 4),
#   'SBPS - BA': (500, 10, 4),
#   'SBSP - SP': (138, 23.1667, 16),
#   'SBGR - SP': (226, 1.4, 1)},
#  'SBVC - BA': {'SBCF - MG': (157, 24.1833, 20),
#   'SBSV - BA': (99, 2.61667, 3),
#   'SBGR - SP': (172, 126.783, 64),
#   'SBGL - RJ': (234, 2.21667, 1)},
#  'SBVT - ES': {'SBCF - MG': (132, 126.5, 127),
#   'SBGL - RJ': (501, 6, 2),
#   'SBGO - GO': (296, 22.75, 13),
#   'SBKP - SP': (182, 230.85, 140),
#   'SBRF - PE': (290, 2.25, 1),
#   'SBRJ - RJ': (123, 84.4833, 76),
#   'SBGR - SP': (122, 6.56667, 4),
#   'SBSP - SP': (170, 200.383, 124),
#   'SBSV - BA': (130, 2.68333, 2),
#   'SBVT - ES': (446, 5.05, 2),
#   'SBBR - DF': (233, 3.48333, 2),
#   'SBFZ - CE': (242, 5.33333, 2)},
#  'SNBR - BA': {'SBCF - MG': (170, 57.4, 26),
#   'SBBR - DF': (146, 34.1333, 22),
#   'SBLE - BA': (526, 6.15, 5),
#   'SBSV - BA': (151, 23.7833, 12)},
#  'SNGI - BA': {'SBCF - MG': (136, 28.4833, 17)},
#  'SBCG - MS': {'SBCR - MS': (367, 3.61667, 4),
#   'SBCT - PR': (235, 38.6333, 27),
#   'SBCY - MT': (182, 23.6, 21),
#   'SBKP - SP': (122, 186.0, 117),
#   'SBFL - SC': (132, 10.2, 6),
#   'SBGL - RJ': (159, 11.8167, 6),
#   'SBGR - SP': (154, 52.4833, 30),
#   'SBPA - RS': (168, 7.08333, 4),
#   'SBPS - BA': (225, 2.48333, 1),
#   'SBSP - SP': (165, 181.783, 109),
#   'SBBR - DF': (218, 83.4, 54)},
#  'SBCR - MS': {'SBCG - MS': (121, 3.2, 4), 'SBKP - SP': (34, 1.93333, 1)},
#  'SBCH - SC': {'SBCY - MT': (392, 10.7333, 5),
#   'SBFL - SC': (72, 0.966667, 1),
#   'SBKP - SP': (108, 111.367, 79),
#   'SBNF - SC': (181, 13.5, 11),
#   'SBPA - RS': (200, 14.0833, 12),
#   'SBGR - SP': (136, 84.4833, 53)},
#  'SBLO - PR': {'SBCT - PR': (116, 61.05, 62),
#   'SBCY - MT': (173, 10.3167, 6),
#   'SBKP - SP': (103, 117.6, 89),
#   'SBMO - AL': (600, 19, 4),
#   'SBPS - BA': (249, 11.1667, 5),
#   'SBGR - SP': (110, 54.3167, 46),
#   'SBSP - SP': (153, 47.25, 41)},
#  'SBMG - PR': {'SBCT - PR': (121, 83.0667, 71),
#   'SBKP - SP': (114, 134.817, 88),
#   'SBPS - BA': (488, 9.23333, 4),
#   'SBRP - SP': (236, 2.56667, 1),
#   'SBCY - MT': (147, 6.58333, 4),
#   'SBGR - SP': (79, 1.36667, 1),
#   'SBSV - BA': (308, 5.75, 2),
#   'SBSP - SP': (159, 7.63333, 6)},
#  'SBPO - PR': {'SBCT - PR': (113, 17.25, 16)},
#  'SBCX - RS': {'SBKP - SP': (203, 38.9667, 25),
#   'SBGR - SP': (166, 62.85, 39),
#   'SBGL - RJ': (361, 1.88333, 1),
#   'SBRJ - RJ': (217, 20.7667, 12),
#   'SBSP - SP': (145, 8.98333, 6)},
#  'SBSI - MT': {'SBCY - MT': (100, 31.1667, 30),
#   'SBKP - SP': (205, 54.5333, 23),
#   'SBGR - SP': (256, 67.0333, 26),
#   'SBBR - DF': (207, 48.85, 30)},
#  'SBSO - MT': {'SBCY - MT': (117, 20.3333, 23)},
#  'SBVH - RO': {'SBCY - MT': (145, 24.8167, 22)},
#  'SSKW - RO': {'SBCY - MT': (183, 34.0667, 25)},
#  'SBDB - MS': {'SBKP - SP': (664, 27.1167, 16), 'SBSP - SP': (208, 14.7, 8)},
#  'SBDN - SP': {'SBKP - SP': (129, 1.36667, 1),
#   'SBMO - AL': (492, 19, 4),
#   'SBPS - BA': (530, 15, 4),
#   'SBRF - PE': (360, 13.25, 4),
#   'SBRP - SP': (2809, 2.3, 1),
#   'SBGR - SP': (123, 33.4, 26),
#   'SBSP - SP': (131, 25.8667, 20)},
#  'SBTT - AM': {'SBEG - AM': (289, 51.4667, 29)},
#  'SBUA - AM': {'SBEG - AM': (199, 7.0, 5)},
#  'SWEI - AM': {'SBTT - AM': (867, 6.18333, 7)},
#  'SWPI - AM': {'SBEG - AM': (117, 18.5333, 22)},
#  'SBFE - BA': {'SBRF - PE': (183, 34.1167, 19)},
#  'SBNM - RS': {'SBFL - SC': (138, 12.7333, 8),
#   'SBPA - RS': (96, 18.3333, 16),
#   'SBGR - SP': (225, 22.3167, 12)},
#  'SBPF - RS': {'SBFL - SC': (86, 14.4, 12),
#   'SBKP - SP': (156, 5.98333, 3),
#   'SBGR - SP': (181, 38.35, 24),
#   'SBPA - RS': (77, 0.916667, 1),
#   'SBGL - RJ': (390, 2.71667, 1)},
#  'SBPK - RS': {'SBFL - SC': (196, 12.7167, 8),
#   'SBPA - RS': (111, 18.2667, 22),
#   'SBGR - SP': (241, 35.05, 17)},
#  'SBSM - RS': {'SBFL - SC': (169, 18.3333, 12),
#   'SBPA - RS': (109, 19.65, 24),
#   'SBSP - SP': (301, 26.0167, 10)},
#  'SBUG - RS': {'SBFL - SC': (255, 26.1, 12),
#   'SBPA - RS': (162, 20.9667, 14),
#   'SBSM - RS': (115, 10.0833, 10),
#   'SBSP - SP': (369, 12.7, 4)},
#  'SBFN - PE': {'SBRF - PE': (110, 139.05, 92),
#   'SBSG - RN': (182, 9, 4),
#   'SBMO - AL': (333, 2.6, 1)},
#  'SBJU - CE': {'SBFZ - CE': (171, 2.13333, 2),
#   'SBKP - SP': (217, 90.6667, 30),
#   'SBRF - PE': (143, 22.5, 22),
#   'SBGR - SP': (269, 175.167, 57)},
#  'SBPJ - TO': {'SBBR - DF': (136, 47.2833, 36),
#   'SBGO - GO': (158, 7.08333, 5),
#   'SBKP - SP': (254, 53.75, 23),
#   'SBRF - PE': (240, 31.7333, 14),
#   'SBCF - MG': (231, 30.9167, 17),
#   'SBGR - SP': (240, 30.9, 13)},
#  'SBJA - SC': {'SBKP - SP': (158, 47.4167, 25),
#   'SBGR - SP': (199, 4.01667, 2),
#   'SBSP - SP': (173, 31.9667, 26)},
#  'SBJV - SC': {'SBKP - SP': (112, 154.633, 115),
#   'SBPS - BA': (1072, 9.21667, 4),
#   'SBGR - SP': (122, 27.4333, 23),
#   'SBSP - SP': (104, 12.3833, 13)},
#  'SBKG - PB': {'SBRF - PE': (49, 31.4333, 52),
#   'SBGR - SP': (404, 84.4167, 26),
#   'SBSV - BA': (176, 25.5333, 19)},
#  'SBML - SP': {'SBKP - SP': (95, 30.1333, 31), 'SBRP - SP': (146, 1.06667, 1)},
#  'SBPG - PR': {'SBKP - SP': (101, 13.9167, 11)},
#  'SBPL - PE': {'SBKP - SP': (194, 75.4167, 29),
#   'SBRF - PE': (155, 34.3167, 26),
#   'SWKQ - PI': (3020, 4, 3),
#   'SBGR - SP': (259, 120.817, 44)},
#  'SBPP - MS': {'SBCF - MG': (180, 2.43333, 1), 'SBKP - SP': (140, 39.85, 26)},
#  'SBRD - MT': {'SBKP - SP': (238, 25.65, 14)},
#  'SBTD - PR': {'SBKP - SP': (193, 37.1833, 20)},
#  'SBTG - MS': {'SBKP - SP': (145, 34.6833, 23)},
#  'SNCP - SC': {'SBKP - SP': (183, 42.6833, 25)},
#  'SSGG - PR': {'SBKP - SP': (129, 16.4833, 11)},
#  'SWLC - GO': {'SBKP - SP': (169, 54.5667, 29),
#   'SBRP - SP': (126, 1.51667, 1)},
#  'SWKQ - PI': {'SBPL - PE': (334, 2.85, 4), 'SBRF - PE': (338, 11.2167, 5)},
#  'SBUF - BA': {'SBRF - PE': (147, 1.06667, 1), 'SBSV - BA': (146, 3.48333, 3)},
#  'SBRB - AC': {'SBBR - DF': (309, 3.13333, 1),
#   'SBCZ - AC': (250, 16.7167, 14),
#   'SBEG - AM': (168, 18.8833, 10),
#   'SBGR - SP': (410, 60.0167, 15),
#   'SBCT - PR': (1193, 4.03333, 1)},
#  'SBCZ - AC': {'SBRB - AC': (268, 16.4333, 14)},
#  'SBOI - AP': {'SBMQ - AP': (333, 25.25, 20)},
#  'SBUY - AM': {'SBEG - AM': (158, 1.63333, 1),
#   'SBUY - AM': (246, 2, 1),
#   'SWCA - AM': (66, 7.16667, 12),
#   'SBSN - PA': (161, 3.01667, 1)},
#  'SWCA - AM': {'SBEG - AM': (193, 9.65, 5),
#   'SBUY - AM': (68, 7.56667, 12),
#   'SWKO - AM': (789, 3.55, 3)},
#  'SWGN - TO': {'SBBR - DF': (217, 27.65, 11)},
#  'SNTF - BA': {'SBMK - MG': (2390, 7.7, 6),
#   'SBSV - BA': (188, 14.6833, 10),
#   'SBIP - MG': (1093, 2.21667, 2),
#   'SBSP - SP': (350, 2.88333, 1)},
#  'SBMH - PR': {'SBCT - PR': (323, 1.08333, 1)}}

# %%
print("Vértices: ", grafoReduzidoPeso.vertices)
print("Arestas: ",grafoReduzidoPeso.arestas)
# Out:
# Vértices:  164
# Arestas:  1160

# %%
grafoReduzidoPeso.aeroportos
# Out:
# {'SBSV - BA': 'SALVADOR',
#  'SIRI - BA': 'MARAÚ',
#  'SNCL - BA': 'CAIRU',
#  'SBAC - CE': 'ARACATI',
#  'SBFZ - CE': 'FORTALEZA',
#  'SBBE - PA': 'BELÉM',
#  'SBMD - PA': 'ALMEIRIM',
#  'SBSN - PA': 'SANTARÉM',
#  'SNEB - PA': 'PARAGOMINAS',
#  'SNSM - PA': 'SALINÓPOLIS',
#  'SNVS - PA': 'BREVES',
#  'SBBG - RS': 'BAGÉ',
#  'SBPA - RS': 'PORTO ALEGRE',
#  'SBBW - MT': 'BARRA DO GARÇAS',
#  'SBCY - MT': 'VÁRZEA GRANDE',
#  'SBCF - MG': 'CONFINS',
#  'SBVG - MG': 'VARGINHA',
#  'SBZM - MG': 'GOIANÁ',
#  'SNPD - MG': 'PATOS DE MINAS',
#  'SNTO - MG': 'TEÓFILO OTONI',
#  'SNZR - MG': 'PARACATU',
#  'SBCP - RJ': 'CAMPOS DOS GOYTACAZES',
#  'SBRJ - RJ': 'RIO DE JANEIRO',
#  'SBCT - PR': 'SÃO JOSÉ DOS PINHAIS',
#  'SBJD - SP': 'JUNDIAÍ',
#  'SSGY - PR': 'GUAÍRA',
#  'SSUM - PR': 'UMUARAMA',
#  'SSUV - PR': 'UNIÃO DA VITÓRIA',
#  'SSVL - PR': 'TELÊMACO BORBA',
#  'SBJI - RO': 'JI-PARANÁ',
#  'SSOU - MT': 'ARIPUANÃ',
#  'SWHP - MT': 'ÁGUA BOA',
#  'SBEG - AM': 'MANAUS',
#  'SBMY - AM': 'MANICORÉ',
#  'SBTF - AM': 'TEFÉ',
#  'SWBC - AM': 'BARCELOS',
#  'SWBR - AM': 'BORBA',
#  'SWKO - AM': 'COARI',
#  'SWLB - AM': 'LÁBREA',
#  'SWMW - AM': 'MAUÉS',
#  'SWYN - AM': 'APUÍ',
#  'SBJE - CE': 'CRUZ',
#  'SBMS - RN': 'MOSSORÓ',
#  'SNIG - CE': 'IGUATU',
#  'SNOB - CE': 'SOBRAL',
#  'SNWS - CE': 'CRATEÚS',
#  'SWBE - CE': 'SÃO BENEDITO',
#  'SBIH - PA': 'ITAITUBA',
#  'SBTB - PA': 'ORIXIMINÁ',
#  'SBJR - RJ': 'RIO DE JANEIRO',
#  'SBSP - SP': 'SÃO PAULO',
#  'SBPB - PI': 'PARNAÍBA',
#  'SNYA - PA': 'ALMEIRIM',
#  'SBME - RJ': 'MACAÉ',
#  'SBSG - RN': 'SÃO GONÇALO DO AMARANTE',
#  'SSCN - RS': 'CANELA',
#  'SSLT - RS': 'ALEGRETE',
#  'SSSC - RS': 'SANTA CRUZ DO SUL',
#  'SSZR - RS': 'SANTA ROSA',
#  'SSRS - MA': 'BARREIRINHAS',
#  'SBPV - RO': 'PORTO VELHO',
#  'SBRF - PE': 'RECIFE',
#  'SNAB - PE': 'ARARIPINA',
#  'SNGN - PE': 'GARANHUNS',
#  'SNHS - PE': 'SERRA TALHADA',
#  'SNRU - PE': 'CARUARU',
#  'SNTS - PB': 'PATOS',
#  'SBSL - MA': 'SÃO LUÍS',
#  'SNOX - PA': 'ORIXIMINÁ',
#  'SWTP - AM': 'SANTA ISABEL DO RIO NEGRO',
#  'SNMZ - PA': 'PORTO DE MOZ',
#  'SNTI - PA': 'ÓBIDOS',
#  'SNMA - PA': 'MONTE ALEGRE',
#  'SWJN - MT': 'JUÍNA',
#  'SBTU - PA': 'TUCURUÍ',
#  'SNRJ - PA': 'BREJO',
#  'SBGR - SP': 'GUARULHOS',
#  'SBAE - SP': 'AREALVA',
#  'SBKP - SP': 'CAMPINAS',
#  'SBMO - AL': 'RIO LARGO',
#  'SBPS - BA': 'PORTO SEGURO',
#  'SBAR - SE': 'ARACAJU',
#  'SBAT - MT': 'ALTA FLORESTA',
#  'SBAU - SP': 'ARAÇATUBA',
#  'SBBV - RR': 'BOA VISTA',
#  'SBCJ - PA': 'PARAUAPEBAS',
#  'SBGL - RJ': 'RIO DE JANEIRO',
#  'SBHT - PA': 'ALTAMIRA',
#  'SBMA - PA': 'MARABÁ',
#  'SBMQ - AP': 'MACAPÁ',
#  'SBBR - DF': 'BRASÍLIA',
#  'SBCA - PR': 'CASCAVEL',
#  'SBRP - SP': 'RIBEIRÃO PRETO',
#  'SBCB - RJ': 'CABO FRIO',
#  'SBCN - GO': 'CALDAS NOVAS',
#  'SBFI - PR': 'FOZ DO IGUAÇU',
#  'SBFL - SC': 'FLORIANÓPOLIS',
#  'SBGO - GO': 'GOIÂNIA',
#  'SBGV - MG': 'GOVERNADOR VALADARES',
#  'SBIL - BA': 'ILHÉUS',
#  'SBIP - MG': 'SANTANA DO PARAÍSO',
#  'SBIZ - MA': 'IMPERATRIZ',
#  'SBJP - PB': 'SANTA RITA',
#  'SBLE - BA': 'LENÇÓIS',
#  'SBMK - MG': 'MONTES CLAROS',
#  'SBNF - SC': 'NAVEGANTES',
#  'SBSR - SP': 'SÃO JOSÉ DO RIO PRETO',
#  'SBTC - BA': 'UNA',
#  'SBTE - PI': 'TERESINA',
#  'SBUL - MG': 'UBERLÂNDIA',
#  'SBUR - MG': 'UBERABA',
#  'SBVC - BA': 'VITÓRIA DA CONQUISTA',
#  'SBVT - ES': 'VITÓRIA',
#  'SNBR - BA': 'BARREIRAS',
#  'SNGI - BA': 'GUANAMBI',
#  'SBCG - MS': 'CAMPO GRANDE',
#  'SBCR - MS': 'CORUMBÁ',
#  'SBCH - SC': 'CHAPECÓ',
#  'SBLO - PR': 'LONDRINA',
#  'SBMG - PR': 'MARINGÁ',
#  'SBPO - PR': 'PATO BRANCO',
#  'SBCX - RS': 'CAXIAS DO SUL',
#  'SBSI - MT': 'SINOP',
#  'SBSO - MT': 'SORRISO',
#  'SBVH - RO': 'VILHENA',
#  'SSKW - RO': 'CACOAL',
#  'SBDB - MS': 'BONITO',
#  'SBDN - SP': 'PRESIDENTE PRUDENTE',
#  'SBTT - AM': 'TABATINGA',
#  'SBUA - AM': 'SÃO GABRIEL DA CACHOEIRA',
#  'SWEI - AM': 'EIRUNEPÉ',
#  'SWPI - AM': 'PARINTINS',
#  'SBFE - BA': 'FEIRA DE SANTANA',
#  'SBNM - RS': 'SANTO ÂNGELO',
#  'SBPF - RS': 'PASSO FUNDO',
#  'SBPK - RS': 'PELOTAS',
#  'SBSM - RS': 'SANTA MARIA',
#  'SBUG - RS': 'URUGUAIANA',
#  'SBFN - PE': 'FERNANDO DE NORONHA',
#  'SBJU - CE': 'JUAZEIRO DO NORTE',
#  'SBPJ - TO': 'PALMAS',
#  'SBJA - SC': 'JAGUARUNA',
#  'SBJV - SC': 'JOINVILLE',
#  'SBKG - PB': 'CAMPINA GRANDE',
#  'SBML - SP': 'MARÍLIA',
#  'SBPG - PR': 'PONTA GROSSA',
#  'SBPL - PE': 'PETROLINA',
#  'SBPP - MS': 'PONTA PORÃ',
#  'SBRD - MT': 'RONDONÓPOLIS',
#  'SBTD - PR': 'TOLEDO',
#  'SBTG - MS': 'TRÊS LAGOAS',
#  'SNCP - SC': 'CORREIA PINTO',
#  'SSGG - PR': 'GUARAPUAVA',
#  'SWLC - GO': 'RIO VERDE',
#  'SWKQ - PI': 'SÃO RAIMUNDO NONATO',
#  'SBUF - BA': 'PAULO AFONSO',
#  'SBRB - AC': 'RIO BRANCO',
#  'SBCZ - AC': 'CRUZEIRO DO SUL',
#  'SBOI - AP': 'OIAPOQUE',
#  'SBUY - AM': 'COARI',
#  'SWCA - AM': 'CARAUARI',
#  'SWGN - TO': 'ARAGUAÍNA',
#  'SNTF - BA': 'TEIXEIRA DE FREITAS',
#  'SBMH - PR': 'MARINGÁ'}

# %%
deletarAllRoutesRoutes()
# Out:
# Rotas Padrão Deletadas

# %%
criarRotasPeso(grafoReduzidoPeso)
# Out:
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada
# Rota Peso Criada

# %% [markdown]
# ### Redução por Prim

# %% [markdown]
# Feito a redução, utilizaremos o algortimo de Prim para reduzir ainda mais nossas arestas.

# %%
from math import inf
def algoritmoPrim(g:GrafoReduzidoPeso):
    grafo = g.grafo
    aeroportos = g.aeroportos
    novoGrafo = GrafoReduzidoPeso()
    inicial = list(grafo.keys())[0]
    novoGrafo.adicionarVertice(origem=inicial, nomeOrigem=aeroportos[inicial])
    for n in range(len(grafo)):
        #escolher a melhor aresta
        origem, destino = "", ""
        menorAresta = (inf, inf, inf)
        for v in novoGrafo.grafo.keys(): #dentre os vértices do novo grafo
            for dest, aresta in grafo[v].items(): #veja todas as arestas desses vértices
                if (not(dest in novoGrafo.grafo.keys())): #se o vertice de destino, não está nos vértices que recebem
                  if(aresta[0] < menorAresta[0]): #verifica os pesos
                      menorAresta = aresta
                      origem = v
                      destino = dest 
        if(origem != ""):
            novoGrafo.adicionarAresta(origem=origem, nomeOrigem=aeroportos[origem], destino=destino, nomeDestino=aeroportos[destino], rota=menorAresta)
            origemVolta = destino
            destinoVolta = origem
            if(destinoVolta in grafo[origemVolta].keys()):
                rota = grafo[origemVolta][destinoVolta]
            novoGrafo.adicionarAresta(origem=origemVolta, nomeOrigem=aeroportos[origemVolta], destino=destinoVolta, nomeDestino=aeroportos[destinoVolta], rota=rota)
            # origemVolta = destino
            #dentre as arestas do vértice de destino, qual a menor peso para a volta?
            # destinoVolta = ""
            # menorAresta = (inf, inf, inf)
            # for vertice, aresta in grafo[origemVolta].items():
            #     if(aresta[0] < menorAresta[0]):
            #         menorAresta = aresta
            #         destinoVolta = vertice
            # if(destinoVolta != ""):         
            #     novoGrafo.adicionarAresta(origem=origemVolta, nomeOrigem=aeroportos[origemVolta], destino=destinoVolta, nomeDestino=aeroportos[destinoVolta], rota=menorAresta)
            #     recebidos.append(destinoVolta)
    return novoGrafo

# %%
novoGrafo = algoritmoPrim(grafoReduzidoPeso)

# %%
len(novoGrafo.grafo)
# Out:
# 163

# %%
novoGrafo.grafo
# Out:
# {'SBSV - BA': {'SBIL - BA': (61, 0.933333, 1),
#   'SBAR - SE': (70, 0.883333, 1),
#   'SBMO - AL': (77, 31.0167, 28),
#   'SBVC - BA': (83, 1.11667, 1),
#   'SBPS - BA': (95, 16.2, 15),
#   'SBLE - BA': (97, 2.18333, 2),
#   'SNCL - BA': (112, 11.301, 31),
#   'SIRI - BA': (170, 3.699, 8),
#   'SNTF - BA': (246, 12.2, 8)},
#  'SBIL - BA': {'SBSV - BA': (54, 0.75, 1)},
#  'SBAR - SE': {'SBSV - BA': (71, 1.01667, 1)},
#  'SBMO - AL': {'SBSV - BA': (83, 22.5833, 19), 'SBRF - PE': (55, 0.85, 1)},
#  'SBRF - PE': {'SBMO - AL': (67, 0.933333, 1),
#   'SBJP - PB': (56, 39.9333, 59),
#   'SBKG - PB': (73, 40.1667, 52),
#   'SBSG - RN': (80, 25.3667, 28),
#   'SBUF - BA': (119, 15.0667, 12),
#   'SBMS - RN': (123, 39.3333, 29),
#   'SBFN - PE': (128, 153.333, 92),
#   'SBPL - PE': (151, 38.4, 28),
#   'SBFE - BA': (166, 34.65, 20),
#   'SWKQ - PI': (215, 8.68333, 4),
#   'SNTS - PB': (483, 29.95, 24),
#   'SNGN - PE': (756, 5.41667, 6),
#   'SNHS - PE': (1021, 19.05, 12),
#   'SNRU - PE': (1114, 8.28333, 12),
#   'SNAB - PE': (3168, 32, 9)},
#  'SBJP - PB': {'SBRF - PE': (25, 0.583333, 1)},
#  'SBKG - PB': {'SBRF - PE': (49, 31.4333, 52)},
#  'SBSG - RN': {'SBRF - PE': (65, 21.9667, 30),
#   'SBFZ - CE': (113, 41.1333, 41)},
#  'SBVC - BA': {'SBSV - BA': (99, 2.61667, 3)},
#  'SBPS - BA': {'SBSV - BA': (89, 15.6667, 15),
#   'SBCF - MG': (110, 28.8667, 22)},
#  'SBLE - BA': {'SBSV - BA': (117, 1.9, 2)},
#  'SBCF - MG': {'SBPS - BA': (106, 28.7667, 22),
#   'SBIP - MG': (53, 88.05, 114),
#   'SBGV - MG': (59, 40.1833, 46),
#   'SBZM - MG': (90, 1.01667, 1),
#   'SBRJ - RJ': (101, 124.983, 111),
#   'SBMK - MG': (104, 132.333, 109),
#   'SBCB - RJ': (111, 37.5333, 26),
#   'SBTC - BA': (114, 7.03333, 5),
#   'SNGI - BA': (170, 32.1333, 17),
#   'SNTO - MG': (340, 15.0333, 10),
#   'SBVG - MG': (344, 17.9667, 12),
#   'SNPD - MG': (347, 12.3833, 9),
#   'SNZR - MG': (908, 15.6333, 8)},
#  'SBIP - MG': {'SBCF - MG': (49, 79.0667, 110)},
#  'SBGV - MG': {'SBCF - MG': (60, 44.4, 52)},
#  'SBZM - MG': {'SBCF - MG': (160, 1.65, 1)},
#  'SBRJ - RJ': {'SBCF - MG': (99, 94.6167, 86),
#   'SBSP - SP': (88, 1.23333, 1),
#   'SBVT - ES': (112, 6.08333, 6)},
#  'SBSP - SP': {'SBRJ - RJ': (105, 546.55, 509),
#   'SBNF - SC': (93, 188.183, 164),
#   'SBDN - SP': (120, 27.8667, 22),
#   'SBAU - SP': (137, 57.8167, 37),
#   'SBCX - RS': (143, 10.2167, 6),
#   'SBCN - GO': (157, 13.5833, 9),
#   'SBJR - RJ': (529, 262.383, 169)},
#  'SBNF - SC': {'SBSP - SP': (104, 161.067, 146),
#   'SBKP - SP': (95, 125.65, 106),
#   'SBFI - PR': (100, 5.08333, 4)},
#  'SBKP - SP': {'SBNF - SC': (92, 123.183, 108),
#   'SBAE - SP': (69, 27.2333, 29),
#   'SBCT - PR': (73, 203.667, 206),
#   'SBRP - SP': (74, 136.2, 145),
#   'SBGL - RJ': (85, 166.05, 152),
#   'SBJV - SC': (100, 150.45, 116),
#   'SBSR - SP': (105, 168.183, 139),
#   'SBDB - MS': (107, 7.05, 4),
#   'SBPG - PR': (109, 14.65, 11),
#   'SBCG - MS': (115, 184.15, 115),
#   'SSGG - PR': (115, 17.4, 11),
#   'SBUR - MG': (116, 35.65, 26),
#   'SBMG - PR': (118, 140.467, 89),
#   'SBML - SP': (121, 25.8, 23),
#   'SBPP - MS': (122, 46.0833, 27),
#   'SBCA - PR': (125, 55.65, 40),
#   'SBTG - MS': (150, 34.0, 21),
#   'SBME - RJ': (159, 44.2833, 26),
#   'SWLC - GO': (176, 61.2, 30),
#   'SBJA - SC': (185, 56.1667, 30),
#   'SNCP - SC': (194, 44.9333, 25),
#   'SBCP - RJ': (196, 29.2333, 16),
#   'SBTD - PR': (205, 41.5667, 20),
#   'SBRD - MT': (222, 27.4, 14),
#   'SBPB - PI': (281, 26.7833, 8)},
#  'SBAE - SP': {'SBKP - SP': (68, 26.1333, 29)},
#  'SBCT - PR': {'SBKP - SP': (80, 213.967, 205),
#   'SBFL - SC': (81, 28.8333, 30),
#   'SBPO - PR': (129, 32.05, 27),
#   'SBMH - PR': (330, 1.03333, 1),
#   'SBJD - SP': (454, 11.0333, 7),
#   'SSUM - PR': (816, 21.5, 10),
#   'SSUV - PR': (1720, 12.2333, 12),
#   'SSGY - PR': (1986, 30.1667, 13),
#   'SSVL - PR': (3512, 7.58333, 7)},
#  'SBRP - SP': {'SBKP - SP': (71, 131.25, 143)},
#  'SBFL - SC': {'SBCT - PR': (82, 30.0167, 30),
#   'SBCH - SC': (84, 28.2333, 27),
#   'SBPA - RS': (91, 18.3167, 17)},
#  'SBCH - SC': {'SBFL - SC': (72, 0.966667, 1)},
#  'SBGL - RJ': {'SBKP - SP': (85, 199.6, 156), 'SBGR - SP': (87, 30.3333, 27)},
#  'SBGR - SP': {'SBGL - RJ': (64, 28.05, 26),
#   'SBLO - PR': (99, 1.18333, 1),
#   'SBUL - MG': (103, 1.2, 1)},
#  'SBPA - RS': {'SBFL - SC': (99, 15.8667, 16),
#   'SBPF - RS': (91, 1.18333, 1),
#   'SBPK - RS': (102, 19.5, 22),
#   'SBNM - RS': (125, 20.6167, 17),
#   'SBSM - RS': (136, 23.6667, 24),
#   'SBUG - RS': (198, 24.2667, 14),
#   'SSCN - RS': (697, 6.83333, 11),
#   'SBBG - RS': (775, 24.7333, 17),
#   'SSSC - RS': (1182, 7.08333, 9),
#   'SSZR - RS': (1502, 12.5333, 7),
#   'SSLT - RS': (2927, 15.9167, 8)},
#  'SBPF - RS': {'SBPA - RS': (77, 0.916667, 1)},
#  'SBLO - PR': {'SBGR - SP': (110, 54.3167, 46)},
#  'SBFI - PR': {'SBNF - SC': (93, 5.06667, 4)},
#  'SBJV - SC': {'SBKP - SP': (112, 154.633, 115)},
#  'SBPK - RS': {'SBPA - RS': (111, 18.2667, 22)},
#  'SBUL - MG': {'SBGR - SP': (115, 99.05, 70), 'SBBR - DF': (92, 25.9333, 22)},
#  'SBBR - DF': {'SBUL - MG': (90, 33.85, 28),
#   'SBGO - GO': (52, 38.6, 50),
#   'SBPJ - TO': (122, 51.1333, 38),
#   'SNBR - BA': (125, 1.6, 1),
#   'SWGN - TO': (218, 28.7667, 11)},
#  'SBGO - GO': {'SBBR - DF': (54, 22.3, 31)},
#  'SBMK - MG': {'SBCF - MG': (93, 114.817, 109)},
#  'SBSR - SP': {'SBKP - SP': (98, 150.75, 136)},
#  'SBDB - MS': {'SBKP - SP': (664, 27.1167, 16)},
#  'SBPG - PR': {'SBKP - SP': (101, 13.9167, 11)},
#  'SBCB - RJ': {'SBCF - MG': (118, 39.3167, 29)},
#  'SNCL - BA': {'SBSV - BA': (94, 25.268, 64)},
#  'SBVT - ES': {'SBRJ - RJ': (123, 84.4833, 76)},
#  'SBFZ - CE': {'SBSG - RN': (116, 0.983333, 1),
#   'SBTE - PI': (137, 53.8833, 49),
#   'SBSL - MA': (150, 68.9833, 54),
#   'SBJE - CE': (171, 4.73333, 5),
#   'SBJU - CE': (171, 30.2333, 25),
#   'SWBE - CE': (514, 7.78333, 6),
#   'SNOB - CE': (1238, 8.06667, 8),
#   'SNIG - CE': (1411, 3.98333, 3),
#   'SNWS - CE': (1800, 7.61667, 6),
#   'SBAC - CE': (2215, 8.46667, 11)},
#  'SBTC - BA': {'SBCF - MG': (118, 6.8, 5)},
#  'SBCG - MS': {'SBKP - SP': (122, 186.0, 117), 'SBCR - MS': (367, 3.61667, 4)},
#  'SSGG - PR': {'SBKP - SP': (129, 16.4833, 11)},
#  'SBUR - MG': {'SBKP - SP': (136, 1.15, 1)},
#  'SBMG - PR': {'SBKP - SP': (114, 134.817, 88),
#   'SBCY - MT': (147, 6.58333, 4)},
#  'SBUF - BA': {'SBRF - PE': (147, 1.06667, 1)},
#  'SBDN - SP': {'SBSP - SP': (131, 25.8667, 20)},
#  'SBML - SP': {'SBKP - SP': (95, 30.1333, 31)},
#  'SBPP - MS': {'SBKP - SP': (140, 39.85, 26)},
#  'SBPJ - TO': {'SBBR - DF': (136, 47.2833, 36)},
#  'SBMS - RN': {'SBRF - PE': (113, 37.4167, 29)},
#  'SBCA - PR': {'SBKP - SP': (123, 56.7667, 40)},
#  'SBNM - RS': {'SBPA - RS': (96, 18.3333, 16)},
#  'SNBR - BA': {'SBBR - DF': (146, 34.1333, 22)},
#  'SBFN - PE': {'SBRF - PE': (110, 139.05, 92)},
#  'SBPO - PR': {'SBCT - PR': (113, 17.25, 16)},
#  'SBSM - RS': {'SBPA - RS': (109, 19.65, 24)},
#  'SBAU - SP': {'SBSP - SP': (140, 56.0667, 38)},
#  'SBTE - PI': {'SBFZ - CE': (130, 3.18333, 3)},
#  'SBCX - RS': {'SBSP - SP': (145, 8.98333, 6)},
#  'SBCY - MT': {'SBMG - PR': (273, 6.3, 4),
#   'SBSI - MT': (89, 27.5667, 28),
#   'SBSO - MT': (108, 18.35, 20),
#   'SBVH - RO': (144, 19.65, 18),
#   'SSKW - RO': (164, 33.9833, 25),
#   'SBAT - MT': (166, 27.4833, 22),
#   'SBJI - RO': (184, 37.25, 25),
#   'SWHP - MT': (899, 16.0333, 8),
#   'SBBW - MT': (979, 16.9333, 9),
#   'SSOU - MT': (1308, 30.2, 10)},
#  'SBSI - MT': {'SBCY - MT': (100, 31.1667, 30)},
#  'SBSO - MT': {'SBCY - MT': (117, 20.3333, 23)},
#  'SBVH - RO': {'SBCY - MT': (145, 24.8167, 22)},
#  'SBTG - MS': {'SBKP - SP': (145, 34.6833, 23)},
#  'SBSL - MA': {'SBFZ - CE': (123, 2.55, 2),
#   'SBBE - PA': (118, 47.0833, 42),
#   'SBIZ - MA': (130, 23.5333, 21),
#   'SSRS - MA': (352, 22.9167, 23)},
#  'SBBE - PA': {'SBSL - MA': (174, 55.2, 52),
#   'SBMQ - AP': (77, 54.15, 60),
#   'SBHT - PA': (106, 31.9667, 30),
#   'SBPV - RO': (128, 3.35, 1),
#   'SBMA - PA': (133, 56.1667, 53),
#   'SBCJ - PA': (213, 31.9, 27),
#   'SNVS - PA': (243, 5.0, 5),
#   'SNEB - PA': (371, 12.7167, 11),
#   'SBTU - PA': (879, 10.3833, 8),
#   'SBMD - PA': (989, 36.25, 20),
#   'SNSM - PA': (2860, 6.16667, 7)},
#  'SBMQ - AP': {'SBBE - PA': (78, 54.2167, 56),
#   'SBOI - AP': (347, 28.8667, 24)},
#  'SBHT - PA': {'SBBE - PA': (118, 27.3667, 28)},
#  'SBPV - RO': {'SBBE - PA': (1069, 2.71667, 1),
#   'SBEG - AM': (132, 1.41667, 1),
#   'SBRB - AC': (132, 2.06667, 2)},
#  'SBIZ - MA': {'SBSL - MA': (164, 25.8667, 26)},
#  'SBEG - AM': {'SBPV - RO': (137, 66.7833, 48),
#   'SBIH - PA': (120, 18.7833, 13),
#   'SWPI - AM': (139, 12.9833, 14),
#   'SBBV - RR': (144, 35.6, 28),
#   'SBSN - PA': (146, 29.25, 23),
#   'SBUY - AM': (179, 79.2, 47),
#   'SBTB - PA': (185, 12.8167, 10),
#   'SBUA - AM': (188, 4.68333, 3),
#   'SBTF - AM': (189, 16.7, 14),
#   'SBTT - AM': (270, 54.15, 30),
#   'SWEI - AM': (312, 26.1167, 9),
#   'SBMY - AM': (418, 14.9667, 10),
#   'SWBC - AM': (471, 12.25, 7),
#   'SWKO - AM': (479, 16.1833, 10),
#   'SWYN - AM': (514, 22.2667, 11),
#   'SWBR - AM': (635, 6.93333, 8),
#   'SWMW - AM': (677, 12.2333, 10),
#   'SWLB - AM': (1095, 8.56667, 3)},
#  'SBIH - PA': {'SBEG - AM': (106, 17.9167, 13), 'SNRJ - PA': (872, 4.3, 4)},
#  'SBRB - AC': {'SBPV - RO': (106, 17.9167, 13),
#   'SBCZ - AC': (250, 16.7167, 14)},
#  'SBMA - PA': {'SBBE - PA': (132, 54.7667, 53)},
#  'SWPI - AM': {'SBEG - AM': (117, 18.5333, 22)},
#  'SBBV - RR': {'SBEG - AM': (108, 37.6, 30)},
#  'SBSN - PA': {'SBEG - AM': (119, 16.5667, 13)},
#  'SBPL - PE': {'SBRF - PE': (155, 34.3167, 26)},
#  'SBCN - GO': {'SBSP - SP': (324, 20, 8)},
#  'SBME - RJ': {'SBKP - SP': (160, 45.9167, 26)},
#  'SSKW - RO': {'SBCY - MT': (183, 34.0667, 25)},
#  'SBFE - BA': {'SBRF - PE': (183, 34.1167, 19)},
#  'SBAT - MT': {'SBCY - MT': (182, 27.5833, 22)},
#  'SIRI - BA': {'SBSV - BA': (183, 5.299, 10)},
#  'SNGI - BA': {'SBCF - MG': (136, 28.4833, 17)},
#  'SBJE - CE': {'SBFZ - CE': (260, 10.75, 13)},
#  'SBJU - CE': {'SBFZ - CE': (171, 2.13333, 2)},
#  'SWLC - GO': {'SBKP - SP': (169, 54.5667, 29)},
#  'SBUY - AM': {'SBEG - AM': (158, 1.63333, 1), 'SWCA - AM': (66, 7.16667, 12)},
#  'SWCA - AM': {'SBUY - AM': (68, 7.56667, 12)},
#  'SBJI - RO': {'SBCY - MT': (189, 1.38333, 1)},
#  'SBJA - SC': {'SBKP - SP': (158, 47.4167, 25)},
#  'SBTB - PA': {'SBEG - AM': (168, 11.8333, 9),
#   'SNOX - PA': (413, 5.48333, 11)},
#  'SBUA - AM': {'SBEG - AM': (199, 7.0, 5)},
#  'SBTF - AM': {'SBEG - AM': (229, 29.6833, 25), 'SWTP - AM': (1150, 20, 9)},
#  'SNCP - SC': {'SBKP - SP': (183, 42.6833, 25)},
#  'SBCP - RJ': {'SBKP - SP': (227, 34.8833, 19)},
#  'SBUG - RS': {'SBPA - RS': (162, 20.9667, 14)},
#  'SBTD - PR': {'SBKP - SP': (193, 37.1833, 20)},
#  'SBCJ - PA': {'SBBE - PA': (221, 26.05, 24)},
#  'SWKQ - PI': {'SBRF - PE': (338, 11.2167, 5)},
#  'SWGN - TO': {'SBBR - DF': (217, 27.65, 11)},
#  'SBRD - MT': {'SBKP - SP': (238, 25.65, 14)},
#  'SNVS - PA': {'SBBE - PA': (201, 5.66667, 5),
#   'SNMZ - PA': (996, 9.71667, 11)},
#  'SNTF - BA': {'SBSV - BA': (188, 14.6833, 10)},
#  'SBCZ - AC': {'SBRB - AC': (268, 16.4333, 14)},
#  'SBTT - AM': {'SBEG - AM': (289, 51.4667, 29)},
#  'SBPB - PI': {'SBKP - SP': (271, 27.5667, 8)},
#  'SWEI - AM': {'SBEG - AM': (271, 27.5667, 8)},
#  'SBMH - PR': {'SBCT - PR': (323, 1.08333, 1)},
#  'SNTO - MG': {'SBCF - MG': (330, 18.4333, 11)},
#  'SBVG - MG': {'SBCF - MG': (284, 16.3667, 12)},
#  'SNPD - MG': {'SBCF - MG': (327, 13.9, 11)},
#  'SBOI - AP': {'SBMQ - AP': (333, 25.25, 20)},
#  'SSRS - MA': {'SBSL - MA': (2862, 28, 21)},
#  'SBCR - MS': {'SBCG - MS': (121, 3.2, 4)},
#  'SNEB - PA': {'SBBE - PA': (533, 10.65, 10)},
#  'SNOX - PA': {'SBTB - PA': (533, 10.65, 10), 'SNMA - PA': (4852, 16, 11)},
#  'SBMY - AM': {'SBEG - AM': (328, 14.1, 9)},
#  'SBJD - SP': {'SBCT - PR': (628, 17, 7)},
#  'SWBC - AM': {'SBEG - AM': (652, 10.9667, 7)},
#  'SWKO - AM': {'SBEG - AM': (723, 22.65, 14)},
#  'SNTS - PB': {'SBRF - PE': (641, 29.2167, 23)},
#  'SWBE - CE': {'SBFZ - CE': (537, 7.46667, 6)},
#  'SWYN - AM': {'SBEG - AM': (415, 18.4833, 9)},
#  'SBJR - RJ': {'SBSP - SP': (600, 284.2, 167)},
#  'SWBR - AM': {'SBEG - AM': (457, 9.43333, 10)},
#  'SWMW - AM': {'SBEG - AM': (726, 12.1333, 10)},
#  'SSCN - RS': {'SBPA - RS': (376, 6.58333, 11)},
#  'SNGN - PE': {'SBRF - PE': (1617, 9.98333, 11)},
#  'SBBG - RS': {'SBPA - RS': (647, 22.05, 17)},
#  'SSUM - PR': {'SBCT - PR': (773, 21.4167, 12)},
#  'SNRJ - PA': {'SBIH - PA': (773, 21.4167, 12)},
#  'SBTU - PA': {'SBBE - PA': (569, 10.5833, 8)},
#  'SWHP - MT': {'SBCY - MT': (2015, 16.2667, 8)},
#  'SNZR - MG': {'SBCF - MG': (722, 12.9833, 7)},
#  'SBBW - MT': {'SBCY - MT': (989, 15.0, 9)},
#  'SBMD - PA': {'SBBE - PA': (1141, 22.3833, 11), 'SNYA - PA': (340, 4.15, 9)},
#  'SNYA - PA': {'SBMD - PA': (1141, 22.3833, 11)},
#  'SNMZ - PA': {'SNVS - PA': (1141, 22.3833, 11)},
#  'SNHS - PE': {'SBRF - PE': (1018, 9.51667, 6)},
#  'SWLB - AM': {'SBEG - AM': (1018, 9.51667, 6)},
#  'SNRU - PE': {'SBRF - PE': (676, 5.3, 7)},
#  'SWTP - AM': {'SBTF - AM': (676, 5.3, 7)},
#  'SSSC - RS': {'SBPA - RS': (829, 7.9, 12)},
#  'SNOB - CE': {'SBFZ - CE': (740, 10.4333, 10)},
#  'SSOU - MT': {'SBCY - MT': (740, 10.4333, 10),
#   'SWJN - MT': (199, 3.08333, 4)},
#  'SWJN - MT': {'SSOU - MT': (740, 10.4333, 10)},
#  'SNIG - CE': {'SBFZ - CE': (633, 5.23333, 4)},
#  'SSZR - RS': {'SBPA - RS': (1222, 10.7667, 7)},
#  'SSUV - PR': {'SBCT - PR': (2083, 11.65, 12)},
#  'SNWS - CE': {'SBFZ - CE': (559, 7.61667, 6)},
#  'SSGY - PR': {'SBCT - PR': (1352, 27.15, 13)},
#  'SBAC - CE': {'SBFZ - CE': (527, 8.76667, 11)},
#  'SNSM - PA': {'SBBE - PA': (8497, 5.96667, 7)},
#  'SSLT - RS': {'SBPA - RS': (1805, 7.43333, 4)},
#  'SNAB - PE': {'SBRF - PE': (3594, 30, 8)},
#  'SSVL - PR': {'SBCT - PR': (1079, 11.5833, 12)},
#  'SNMA - PA': {'SNOX - PA': (1079, 11.5833, 12)}}

# %%
deletarAllRoutesPeso()
# Out:
# Rotas Peso Deletadas

# %%
criarRotasPrim(novoGrafo)
# Out:
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada
# Rota Prim Criada

# %% [markdown]
# ## Ir de um canto a outro - qual o custo?
# Busca em profundidade escolhendo o menor custo. <br>
# Guardar o caminho feito, custo em reais e horas.

# %%
def busca(grafo, origem, destino, custo, horas, caminho:list, visitado):
    
    visitado.append(origem)
    if(origem == destino):
        return (custo, horas, caminho)
    aVisitar = [(value[0], value[1], value[2], key) for key, value in grafo[origem].items()]
    aVisitar.sort()
    for u in aVisitar:
        if(not(u[3] in visitado)):
            custo += u[0]
            horas += u[1]
            caminho.append(u[3])
            achou = busca(grafo, u[3], destino, custo, horas, caminho, visitado)
            if(achou != False):
                return achou
            custo -= u[0]
            horas -= u[1]
            caminho.pop(-1)
    return False
            #
inicial = "SBMO - AL"
caminho = [inicial]
custo = 0
horas = 0
final = "SWCA - AM"
visitado = []
preco,horas, rota = busca(novoGrafo.grafo, inicial, final, custo, horas, caminho, visitado)

# %%
rota
# Out:
# ['SBMO - AL',
#  'SBRF - PE',
#  'SBSG - RN',
#  'SBFZ - CE',
#  'SBSL - MA',
#  'SBBE - PA',
#  'SBPV - RO',
#  'SBEG - AM',
#  'SBUY - AM',
#  'SWCA - AM']

# %%
horas
# Out:
# 274.54994000000005

# %%
preco
# Out:
# 1021

# %%
criarRotasBusca(novoGrafo, rota)
# Out:
# Rota Busca Criada
# Rota Busca Criada
# Rota Busca Criada
# Rota Busca Criada
# Rota Busca Criada
# Rota Busca Criada
# Rota Busca Criada
# Rota Busca Criada
# Rota Busca Criada
